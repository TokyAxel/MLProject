# %%
from bs4 import BeautifulSoup
from urllib.error import HTTPError
import urllib.request
import requests
import pandas as pd
import re
import csv

def crawl_page(link=''):
    # req = urllib.request.Request(
    #         link, 
    #         data=None, 
    #         headers={
    #             'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
    #             'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.79 Safari/537.36 Edge/14.14393'
    #         }
    # )
    # try:
    #     page= urllib.request.urlopen(req)
    #     return_code= page.getcode()
    #     soup_page= BeautifulSoup(page,'html.parser')
    #     return {'page':soup_page, 'status': return_code}
    # except HTTPError as err:
    #     if err.code == 404:
    #         return_code=404
    #         return {'page':'no page', 'status': return_code}
    #     else:
    #         raise
    try:
        response = requests.get(
            url='http://api.scraperapi.com', #scrapeapi
            params={
                'api_key': 'fa9b49e2d89dc81fd7808deefca5c790',
                'url': link,  
            },
            
        )
        return_code= 200
        soup_page= BeautifulSoup(response.content,'html.parser')
        return {'page':soup_page, 'status': return_code}
    except requests.exceptions.HTTPError as err:
        if err.response.status_code == 404:
            return_code=404
            return {'page':'no page', 'status': return_code}
    

def write_csv(line=[], file=''):
    with open(file, 'a', newline='') as csvfile:
        spamwriter = csv.writer(csvfile, delimiter=' ',
                                quotechar='|', quoting=csv.QUOTE_MINIMAL)
        spamwriter.writerow(line)

def remove_row_csv():
    with open('temp_27.csv') as inp:
        for link in csv.reader(inp):
            count=0
            temp=link
            with open('used_estate.txt') as out:
                for estate in csv.reader(out):
                    if re.match("(.*)/"+estate[0],temp[1]) is not None:
                        count+=1
            if count==0:
                new_row= [link[0]+','+link[1]]
                write_csv(new_row,"temp_28.csv")

def create_urls(file=''):
    with open(file) as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')
        line_count = 1
        for row in csv_reader:
            new_row= [str(line_count)+','+row[0]]
            write_csv(new_row,'property_url_v2.csv')
            line_count+=1

# %%
class DataCollect():
    def __init__(self):
        self.__url_to_open='https://www.property24.com'
        self.__soup=crawl_page(self.__url_to_open)['page']
        self.__area_url=[]
        self.__list_url=[]
        self.__urls=pd.read_csv("tmp_4_v7.csv",usecols= ['id','url']) 
    
    def collect_all_first_page_url(self):
        other_links= self.__soup.find('div',class_='p24_popular').find(class_='col-8').find_all('a',class_='p24_bold')
        for link in other_links:
            self.__area_url.append(self.__url_to_open+link.get('href'))
        first_element_tag= self.__soup.find('div',class_='p24_popular').find(class_='col-8').find_all(class_='row')[1]
        first_link=first_element_tag.find('a').get('href')
        temp_soup= crawl_page(self.__url_to_open+first_link)['page']
        parent_link= temp_soup.find(id='breadCrumbContainer').find_all('a')[1]
        self.__area_url.append(self.__url_to_open+parent_link.get('href'))
    
    def collect_all_url(self):
        self.collect_all_first_page_url()
        for link in self.__area_url:
            soup= crawl_page(link)['page']
            link_house_tag= soup.find('ul',class_='p24_relatedSales').find(href=re.compile("houses-for-sale")).get('href')
            link_apart_tag= soup.find('ul',class_='p24_relatedSales').find(href=re.compile("apartments-for-sale")).get('href')
            link_townhouse_tag= soup.find('ul',class_='p24_relatedSales').find(href=re.compile("townhouses-for-sale")).get('href')
            self.__list_url.append(link_house_tag)
            self.__list_url.append(link_apart_tag)
            self.__list_url.append(link_townhouse_tag)

    def get_property_data(self, link=''):
        data={}

        estate_id= link.split('/')[-1].split('?')[0]

        prop_soup_element= crawl_page(self.__url_to_open+link)

        
        if prop_soup_element['status'] !=200:
            print('heres')
            return False
        
        prop_soup= prop_soup_element['page']

        if prop_soup is None:
            print('here')
            return False

        #check if page not found
        check_page_not_found_msg= prop_soup.select_one('.p24_not_found')
        if check_page_not_found_msg is not None:
            print("====> Page not found !!")
            return False
        
        #check page expired
        check_page_expired = prop_soup.select_one('.p24_results.p24_expired')
        if check_page_expired is not None:
            print("====> Page expired !!")
            return False
        

        name= prop_soup.find('div',class_='p24_listingFeaturesWrapper').find('h1').get_text()
        data['name']=name

        price= prop_soup.find('div',class_='p24_listingFeaturesWrapper').find('div',class_="p24_price").get_text()
        data['price']=price

        province= link.split('/')[4]
        data['province']=province

        city= link.split('/')[3]
        data['city']=city


        is_adress= len(prop_soup.find('div',class_='p24_listingFeaturesWrapper').find_all('div',class_="p24_mBM")) >= 3
        if is_adress:
            if len(prop_soup.find('div',class_='p24_listingFeaturesWrapper').find_all('div',class_="p24_mBM")) == 3:
                index=-1
            else:
                index=3
            address= prop_soup.find('div',class_='p24_listingFeaturesWrapper').find_all('div',class_="p24_mBM")[index].get_text()
            data['address']=address
        else:
            address=  prop_soup.select_one('.p24_addressPropOverview').get_text()
            data['address']=address

        #property overview
        if type(prop_soup.select_one('.p24_propertyOverview')) is not None:
            prop_overview_panel= prop_soup.find('div',class_='p24_propertyOverview').find('div',class_='panel-body')
            prop_overview_row= prop_overview_panel.find_all('div',class_='p24_propertyOverviewRow')
            for prop in prop_overview_row:
                key= prop.find('div',class_='p24_propertyOverviewKey').get_text()
                # value= prop.select_one('.noPadding > .p24_info').get_text()
                value= prop.find('div',class_='noPadding').contents[1].get_text()
                data[key]=value

        #rooms
        rooms_panel=prop_soup.select_one('#js_accordion_rooms')
        if rooms_panel is not None:
            prop_overview_row= rooms_panel.find_all('div',class_='p24_propertyOverviewRow')
            for prop in prop_overview_row:
                key= prop.find('div',class_='p24_propertyOverviewKey').get_text()
                # value= prop.select_one('.noPadding > .p24_info').get_text()
                value= prop.find('div',class_='noPadding').contents[1].get_text()
                data[key]=value

        #external_features
        external_features_panel=prop_soup.select_one('#js_accordion_externalfeatures')
        if external_features_panel is not None:
            prop_overview_row= external_features_panel.find_all('div',class_='p24_propertyOverviewRow')
            for prop in prop_overview_row:
                key= prop.find('div',class_='p24_propertyOverviewKey').get_text()
                # value= prop.select_one('.noPadding > .p24_info').get_text()
                value= prop.find('div',class_='noPadding').contents[1].get_text()
                data[key]=value
        
        #other_features
        other_features_panel=prop_soup.select_one('#js_accordion_otherfeatures')
        if other_features_panel is not None:
            prop_overview_row= other_features_panel.find_all('div',class_='p24_propertyOverviewRow')
            for prop in prop_overview_row:
                key= prop.find('div',class_='p24_propertyOverviewKey').get_text()
                # value= prop.select_one('.noPadding > .p24_info').get_text()
                value= prop.find('div',class_='noPadding').contents[1].get_text()
                data[key]=value

        #building_features
        building_features_panel=prop_soup.select_one('#js_accordion_building')
        if building_features_panel is not None:
            prop_overview_row= building_features_panel.find_all('div',class_='p24_propertyOverviewRow')
            for prop in prop_overview_row:
                key= prop.find('div',class_='p24_propertyOverviewKey').get_text()
                # value= prop.select_one('.noPadding > .p24_info').get_text()
                value= prop.find('div',class_='noPadding').contents[1].get_text()
                data[key]=value

        #points_interest
        interest_soup= crawl_page(self.__url_to_open+'/ListingReadOnly/PointsOfInterestForListing?ListingNumber=P24-'+estate_id)
        # points_interest_panel=prop_soup.select_one('#accordian-points-of-interest')
        # print(points_interest_panel)
        if interest_soup['status'] == 200:
            categories= interest_soup['page'].select('.js_P24_POICategory')
            for cat in categories:
                interest= cat.select_one('.row > .col-6 > .p24_semibold')
                distances= cat.select('.row > .col-6.noPadding.p24_semibold')
                dist_tab=[]
                for dist in distances:
                    dist_tab.append(dist.get_text())
                data[interest.get_text()]=dist_tab

        print(str(data))
        write_csv([str(data)],'data_property_v2.csv')

        
        return True

    def crawl_property_per_page(self,city,page,number_properties):
        link=self.__url_to_open+city+'/p'+str(page)
        print('==>Page link: ',link)
        cur_soup= crawl_page(link)['page']
        properties= cur_soup.find_all('div',class_='js_resultTile')
        for prop_index in range(len(properties)-1):
            prop_link= properties[prop_index].find('a').get('href')
            write_csv([prop_link],'data_property_url.csv')

        number_properties+= len(properties)
        return number_properties

    def crawl_property_per_city(self,city,cur_page):
        soup= crawl_page(self.__url_to_open+city)['page']
        pagination= soup.find('div',class_='p24_pager').find_all('li')[-1].find('a').get('data-pagenumber')
        page_number= int(pagination)
        number_properties=0
        print("City url: ",city)
        for page in range(cur_page, page_number+1):
            print("=>Page number: ",page)
            number_properties = self.crawl_property_per_page(city,page,number_properties)
        print(number_properties)
    
    def crawl_properties(self):
        #shuffle
        self.__urls = self.__urls.sample(frac = 1).reset_index(drop=True)
        for i in range(self.__urls.size):
            prop_link= self.__urls.iloc[i]['url']
            
            print('==>Property link: ', prop_link)
            check_property_crawl = self.get_property_data(prop_link)
            if check_property_crawl:
                self.__urls= self.__urls.drop(self.__urls.index[i])
                self.__urls.to_csv('tmp_5_v7.csv',index=False)

    def crawl_property_url(self):
        self.__list_url=['/townhouses-for-sale/gauteng/1']
        for link in self.__list_url:
            self.crawl_property_per_city(link,1)

# %%
dc= DataCollect()
try:
    dc.crawl_properties()
except:
    dc.crawl_properties()
# Out:
# ==>Property link:  /for-sale/seshego-d/polokwane/limpopo/11150/109105061
# {'name': '5 Bedroom House for Sale in Seshego D', 'price': 'R 790 000', 'province': 'limpopo', 'city': 'polokwane', 'address': 'Seshego D, Polokwane', 'Listing Number': '109105061', 'Type of Property': 'House', 'Listing Date': '11 September 2020', 'Erf Size': '600 m²', 'Pets Allowed': 'Yes', 'Bedrooms': '5', 'Bathrooms': '2', 'Kitchen': '1', 'Lounge': '1', 'Dining Room': '1', 'Family/TV Room': '1', 'Garage': '2', 'Security': '24 Hour Access', 'Education': ['0.15km', '0.26km', '0.44km', '0.45km', '1.13km', '1.13km', '1.23km', '1.25km', '1.29km', '1.33km', '1.39km', '1.40km', '1.57km', '1.63km', '1.68km', '1.75km', '1.81km', '1.92km', '1.97km', '2.09km', '2.10km', '2.14km', '2.18km', '2.24km', '2.26km', '2.43km', '2.71km', '2.96km', '2.97km', '3.50km']}
# ==>Property link:  /for-sale/umhlanga-ridge/umhlanga/kwazulu-natal/6383/110223486
# {'name': '1 Bedroom Apartment / Flat for Sale in Umhlanga Ridge', 'price': 'R 1 090 000', 'province': 'kwazulu-natal', 'city': 'umhlanga', 'address': 'Umhlanga Ridge, Umhlanga', 'Listing Number': '110223486', 'Type of Property': 'Apartment / Flat', 'Listing Date': '22 July 2021', 'Floor Size': '48 m²', 'Price per m²': 'R 22 708', 'Levies': 'R 890', 'Rates and Taxes': 'R 770', 'Pets Allowed': 'No', 'Bedroom': '1', 'Bathrooms': '1', 'Kitchens': '1', 'Lounges': '1', 'Dining Rooms': '1', 'Rooms': 'Balcony', 'Parking': '2', 'Pool': 'Yes', 'Food and Entertainment': ['0.16km', '0.17km', '0.17km', '0.19km', '0.19km', '0.19km', '0.19km', '0.19km', '0.19km', '0.20km', '0.22km', '0.26km', '0.27km', '0.37km', '0.37km', '0.37km', '0.38km', '0.38km', '0.39km', '0.39km', '0.39km', '0.40km', '0.41km'], 'Shopping': ['0.17km', '0.20km', '0.22km', '0.23km', '0.23km', '0.40km'], 'Sports and Leisure': ['0.20km']}
# ==>Property link:  /for-sale/de-beers/kimberley/northern-cape/11037/110189364
# {'name': '4 Bedroom House for Sale in De Beers', 'price': 'R 1 060 000', 'province': 'northern-cape', 'city': 'kimberley', 'address': 'De Beers, Kimberley', 'Listing Number': '110189364', 'Type of Property': 'House', 'Listing Date': '12 July 2021', 'Bedrooms': '4', 'Bedroom 1': 'Tiled Floors, Air Conditioner, Curtain Rails, TV Port, Built-in Cupboards, Walk-in-closet, Double Bed', 'Bedroom 2': 'Tiled Floors, Curtain Rails, TV Port, Double Bed', 'Bedroom 3': 'Tiled Floors, Curtain Rails, TV Port, Double Bed', 'Bedroom 4': 'Tiled Floors, Curtain Rails, TV Port, Double Bed', 'Bathrooms': '2', 'Bathroom 1': 'Main en Suite', 'Bathroom 2': 'Tiled Floors, Basin, Shower, Curtain Rails, Toilet', 'Kitchen': 'Breakfast Nook, Open Plan, Eye Level Oven, Granite Tops, Tiled Floors, Built-in Cupboards', 'Lounge': 'Tiled Floors, Air Conditioner, Curtain Rails', 'Dining Room': 'Tiled Floors, Curtain Rails', 'Parking': 'Carport', 'Security': 'Totally Fenced, Alarm System, Burglar Bars', 'Transport and Public Services': ['0.34km', '0.42km', '0.65km', '0.76km', '0.93km', '1.16km', '1.22km', '1.68km', '1.70km'], 'Education': ['0.66km', '0.82km', '0.82km', '1.08km', '1.62km', '1.70km', '1.71km', '1.83km', '1.87km'], 'Food and Entertainment': ['1.08km', '1.09km', '1.33km', '1.46km', '1.78km', '1.80km', '1.84km', '1.85km'], 'Health': ['1.26km', '1.32km', '1.46km'], 'Sports and Leisure': ['1.40km']}
# ==>Property link:  /for-sale/sylviavale/vanderbijlpark/gauteng/3625/110123998
# {'name': '3 Bedroom Apartment / Flat for Sale in Sylviavale', 'price': 'R 1 095 000', 'province': 'gauteng', 'city': 'vanderbijlpark', 'address': '\n3 Bedroom Apartment / Flat for Sale in Sylviavale\n', 'Listing Number': '110123998', 'Type of Property': 'Apartment / Flat', 'Street Address': ' Door 22, Unit 24 Le Voile, 13 Vaal Drive, Sylviavale', 'Description': 'Simplex', 'Lifestyle': 'Security Complex', 'Listing Date': '23 June 2021', 'Floor Size': '176 m²', 'Price per m²': 'R 6 222', 'Levies': 'R 1 745', 'Rates and Taxes': 'R 1 000', 'Pets Allowed': 'Yes', 'Bedrooms': '3', 'Bedroom 1': 'Carpets, Blinds, Built-in Cupboards, Queen Bed', 'Bedroom 2': 'Carpets, Blinds, Built-in Cupboards, Double Bed', 'Bedroom 3': 'Carpets, Blinds, Built-in Cupboards, Queen Bed', 'Bathrooms': '2', 'Bathroom 1': 'Tiled Floors, Basin, Guest Toilet, Bath, Blinds, Toilet', 'Bathroom 2': 'Tiled Floors, Basin, Main en Suite, Bath, Shower, Toilet', 'Kitchen': 'Breakfast Nook, Open Plan, Extractor Fan, Dishwasher Connection, Tiled Floors, Blinds, Open Plan, Built-in Cupboards, Under Counter Oven, Hob', 'Family/TV Room': 'Tiled Floors, Open Plan', 'Garage': 'Double, Electric Door', 'Parking': 'Visitors Parking', 'Gardens': '1', 'Security': 'Totally Fenced, Electric Garage, Intercom, Guard House, Guard, Safe', 'Special Features': 'Paveway, Open Plan', 'Style': 'Modern, Open Plan', 'Roof': 'Tile', 'Wall': 'Plaster', 'Education': ['1.19km', '1.41km', '1.94km', '1.99km', '2.20km', '2.21km', '2.45km', '2.82km', '2.84km', '2.85km', '2.87km', '2.97km', '3.57km', '3.76km', '3.84km', '3.92km', '3.98km', '4.06km', '4.07km', '4.28km', '4.46km', '4.59km', '4.64km', '4.78km', '4.84km', '4.88km', '4.91km', '4.99km'], 'Sports and Leisure': ['2.05km', '2.24km']}
# ==>Property link:  /for-sale/brooklands-lifestyle-estate/centurion/gauteng/10810/106370863
# {'name': '4 Bedroom House for Sale in Brooklands Lifestyle Estate', 'price': 'R 3 149 000', 'province': 'gauteng', 'city': 'centurion', 'address': 'Brooklands Lifestyle Estate, Centurion', 'Listing Number': '106370863', 'Type of Property': 'House', 'Listing Date': '24 May 2018', 'Erf Size': '729 m²', 'Floor Size': '290 m²', 'Levies': 'R 850', 'Rates and Taxes': 'R 1 200', 'Pets Allowed': 'No', 'Bedrooms': '4', 'Bathrooms': '4.5', 'Kitchens': '1', 'Office': '1', 'Domestic Rooms': '1', 'Lounges': '2', 'Dining Rooms': '1', 'Garage': '2', 'Transport and Public Services': ['1.01km', '1.14km', '1.50km', '2.21km', '2.25km', '2.49km', '2.63km'], 'Food and Entertainment': ['1.03km', '1.09km', '1.10km', '2.07km', '2.09km', '2.12km', '2.16km', '2.17km', '2.18km', '2.18km', '2.18km', '2.69km', '2.70km'], 'Shopping': ['1.05km', '2.15km', '2.44km', '2.62km'], 'Health': ['1.10km', '2.60km'], 'Education': ['2.10km', '2.20km', '2.36km', '2.45km']}
# ==>Property link:  /for-sale/tlhabane-west/rustenburg/north-west/15707/102998205
# {'name': '2 Bedroom House for Sale in Tlhabane West', 'price': 'R 750 000', 'province': 'north-west', 'city': 'rustenburg', 'address': 'Tlhabane West, Rustenburg', 'Listing Number': '102998205', 'Type of Property': 'House', 'Listing Date': '23 June 2015', 'Erf Size': '338 m²', 'Pets Allowed': 'Yes', 'Bedrooms': '2', 'Bedroom 1': 'Tiled Walls, Main en-suit.', 'Bedroom 2': 'Tiled Walls', 'Bathrooms': '2', 'Bathroom 1': 'Tiled Floors, Basin, Guest Toilet, Bath, Blinds, Curtain Rails', 'Bathroom 2': 'Basin, Main en Suite, Bath, Shower, Toilet', 'Kitchen': 'Built-in- cupboards,Tiled walls', 'Lounge': 'Tiled walls', 'Dining Room': 'Tiled Walls', 'Garage': 'Double, Electric Door', 'Parking': 'Shade net covered', 'Outbuilding': 'Wendy  House', 'Security': 'Totally Fenced, Electric Gate, Security Gate', 'Education': ['0.91km', '1.12km', '1.15km', '1.23km', '1.46km', '1.65km', '1.79km', '2.01km', '2.05km', '2.08km', '2.09km', '2.25km', '2.31km', '2.34km', '2.60km', '2.70km', '2.71km', '2.86km', '2.92km', '3.02km', '3.26km', '3.32km', '3.51km'], 'Health': ['1.33km', '1.75km'], 'Food and Entertainment': ['1.54km', '1.91km'], 'Shopping': ['1.60km'], 'Transport and Public Services': ['3.02km', '3.38km']}
# ==>Property link:  /for-sale/margate/margate/kwazulu-natal/6360/109609206
# {'name': '6 Bedroom House for Sale in Margate', 'price': 'R 1 350 000', 'province': 'kwazulu-natal', 'city': 'margate', 'address': 'Margate', 'Listing Number': '109609206', 'Type of Property': 'House', 'Listing Date': '08 February 2021', 'Erf Size': '929 m²', 'Rates and Taxes': 'R 850', 'Pets Allowed': 'Yes', 'Bedrooms': '6', 'Bathrooms': '4', 'Kitchens': '1', 'Lounges': '2', 'Dining Rooms': '2', 'Garage': '2', 'Garden': 'Yes', 'Flatlet': 'Yes', 'Sports and Leisure': ['0.59km'], 'Education': ['0.69km', '0.69km', '0.90km', '2.17km', '2.79km', '3.91km', '4.27km', '5.18km', '5.36km', '5.51km', '5.72km', '6.07km', '6.46km', '6.91km', '7.03km', '7.17km', '7.26km', '7.27km', '7.66km', '7.79km', '8.00km', '8.65km', '8.78km', '9.27km', '9.47km', '9.56km', '9.73km'], 'Transport and Public Services': ['1.35km', '7.33km']}
# ==>Property link:  /for-sale/witbank-ext-8/witbank/mpumalanga/2585/110034801
# {'name': '3 Bedroom House for Sale in Witbank Ext 8', 'price': 'R 1 080 000', 'province': 'mpumalanga', 'city': 'witbank', 'address': 'Witbank Ext 8, Witbank', 'Listing Number': '110034801', 'Type of Property': 'House', 'Description': 'Single Storey', 'Listing Date': '31 May 2021', 'Erf Size': '996 m²', 'Floor Size': '300 m²', 'Rates and Taxes': 'R 1 000', 'Pets Allowed': 'Yes', 'Bedrooms': '3', 'Bathrooms': '2', 'Kitchen': '1', 'Lounge': '1', 'Dining Room': '1', 'Family/TV Room': '1', 'Braai Room': '1', 'Garage': '1', 'Parking': '1', 'Garden': '1', 'Special Feature': 'Built in Braai', 'Flatlet': 'Yes', 'Education': ['1.48km', '1.63km', '1.81km', '1.86km', '1.91km', '1.92km', '1.97km', '2.20km', '2.69km', '2.74km', '2.82km', '2.89km', '2.90km', '3.01km', '3.04km', '3.05km', '3.43km', '3.46km', '3.68km', '3.78km', '3.98km', '4.07km', '4.17km', '4.24km', '4.26km', '4.37km'], 'Sports and Leisure': ['2.53km'], 'Shopping': ['4.27km', '4.44km'], 'Food and Entertainment': ['4.34km']}
# ==>Property link:  /for-sale/witbank-ext-10/witbank/mpumalanga/2554/110071784
# {'name': '2 Bedroom House for Sale in Witbank Ext 10', 'price': 'R 695 000', 'province': 'mpumalanga', 'city': 'witbank', 'address': 'Witbank Ext 10, Witbank', 'Listing Number': '110071784', 'Type of Property': 'House', 'Listing Date': '14 June 2021', 'Bedrooms': '2', 'Bathrooms': '1', 'Kitchens': '1', 'Lounges': '1', 'Garage': '1', 'Gardens': '1', 'Education': ['0.40km', '0.50km', '0.84km', '1.31km', '1.31km', '1.40km', '1.54km', '1.68km', '1.68km', '1.72km', '1.85km', '2.36km', '3.55km', '3.66km', '3.90km', '3.96km', '3.98km', '4.00km', '4.08km', '4.14km', '4.32km', '4.39km', '4.39km', '4.53km', '4.64km', '5.26km', '5.27km', '5.27km'], 'Sports and Leisure': ['1.57km'], 'Shopping': ['4.40km']}
# ==>Property link:  /for-sale/three-rivers/vereeniging/gauteng/3754/109360910
# ==>Property link:  /for-sale/cape-town-city-centre/cape-town/western-cape/9138/110078686
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-205986050037> in <module>
#       3     dc.crawl_properties()
#       4 except:
# ----> 5     dc.crawl_properties()
#
# <ipython-input-10-b8fe5b0f25ad> in crawl_properties(self)
#     184
#     185             print('==>Property link: ', prop_link)
# --> 186             check_property_crawl = self.get_property_data(prop_link)
#     187             if check_property_crawl:
#     188                 self.__urls= self.__urls.drop(self.__urls.index[i])
#
# <ipython-input-10-b8fe5b0f25ad> in get_property_data(self, link)
#      33         estate_id= link.split('/')[-1].split('?')[0]
#      34
# ---> 35         prop_soup_element= crawl_page(self.__url_to_open+link)
#      36
#      37
#
# <ipython-input-1-2c761ae6086f> in crawl_page(link)
#      28     #         raise
#      29     try:
# ---> 30         response = requests.get(
#      31             url='http://api.scraperapi.com', #scrapeapi
#      32             params={
#
# ~/.local/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/.local/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/.local/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~/.local/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~/.local/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     663
#     664             # Make the request on the httplib connection object.
# --> 665             httplib_response = self._make_request(
#     666                 conn,
#     667                 method,
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                     # Python 3 (including for exceptions like SystemExit).
#     420                     # Otherwise it looks like a bug in the code.
# --> 421                     six.raise_from(e, None)
#     422         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     423             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/lib/python3/dist-packages/six.py in raise_from(value, from_value)
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     414                 # Python 3
#     415                 try:
# --> 416                     httplib_response = conn.getresponse()
#     417                 except BaseException as e:
#     418                     # Remove the TypeError from the exception chain in
#
# /usr/lib/python3.8/http/client.py in getresponse(self)
#    1342         try:
#    1343             try:
# -> 1344                 response.begin()
#    1345             except ConnectionError:
#    1346                 self.close()
#
# /usr/lib/python3.8/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# /usr/lib/python3.8/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# /usr/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# KeyboardInterrupt:
