# %%
import pandas as pd
import re

# %%
def to_snake_case(string):
    string = re.sub('\s+', r'_', string)   
    return string.lower()

# %%
data= pd.read_csv("../../Data/Dataset_v1.csv",sep=";")

data= data.rename(to_snake_case, axis='columns')

data['sampling']=0

# %%
(data['type_of_property'].value_counts() / len(data), data['province'].value_counts() / len(data))
# Out:
# (House                 0.524733
#  Apartment / Flat      0.334260
#  Townhouse             0.140934
#  Vacant Land / Plot    0.000073
#  Name: type_of_property, dtype: float64,
#  gauteng          0.449949
#  western-cape     0.161496
#  kwazulu-natal    0.139982
#  north-west       0.076248
#  mpumalanga       0.056856
#  eastern-cape     0.039734
#  free-state       0.038636
#  limpopo          0.029197
#  northern-cape    0.007903
#  Name: province, dtype: float64)

# %%
def get_type_property_per_province_proportion(data=pd.DataFrame):
    total_house=  data[(data['type_of_property']=="House")].shape[0]
    total_apartement=  data[(data['type_of_property']=="Apartment / Flat")].shape[0]
    total_townhouse=  data[(data['type_of_property']=="Townhouse")].shape[0]
    provinces= data['province'].sort_values(ascending=True).unique().tolist()
    houses=[]
    houses_percentage=[]
    houses_all_percentage=[]
    apartments_percentage=[]
    apartments_all_percentage=[]
    apartments=[]
    townhouses=[]
    townhouses_percentage=[]
    townhouses_all_percentage=[]
    for province in provinces:
        temp_house= data[(data['type_of_property']=="House") & (data['province']==province)].shape[0]
        temp_apartement= data[(data['type_of_property']=="Apartment / Flat") & (data['province']==province)].shape[0]
        temp_townhouse= data[(data['type_of_property']=="Townhouse") & (data['province']==province)].shape[0]

        houses.append(temp_house)
        houses_percentage.append(temp_house*100/total_house)
        houses_all_percentage.append(temp_house*100/len(data))
        apartments.append(temp_apartement)
        apartments_percentage.append(temp_apartement*100/total_apartement)
        apartments_all_percentage.append(temp_apartement*100/len(data))
        townhouses.append(temp_townhouse)
        townhouses_percentage.append(temp_townhouse*100/total_townhouse)
        townhouses_all_percentage.append(temp_townhouse*100/len(data))

    provinces_data=pd.DataFrame([houses,houses_percentage,houses_all_percentage,apartments,apartments_percentage,apartments_all_percentage,townhouses,townhouses_percentage,townhouses_all_percentage],\
        index=["House","House %","House % over all properties","Apartment / Flat","Apartment / Flat %","Apartment / Flat % over all properties","Townhouse","Townhouse %","Townhouse % over all properties"],columns=provinces)

    return provinces_data

# %% [markdown]
# Utilisation de la fonction stratified_sample venant du site https://www.kaggle.com/flaviobossolan/stratified-sampling-python avec modification selon le besoin

# %%
def stratified_sample(df, strata, size=None, seed=None, keep_index= True, sampling_code=0):
    '''
    It samples data from a pandas dataframe using strata. These functions use
    proportionate stratification:
    n1 = (N1/N) * n
    where:
        - n1 is the sample size of stratum 1
        - N1 is the population size of stratum 1
        - N is the total population size
        - n is the sampling size
    Parameters
    ----------
    :df: pandas dataframe from which data will be sampled.
    :strata: list containing columns that will be used in the stratified sampling.
    :size: sampling size. If not informed, a sampling size will be calculated
        using Cochran adjusted sampling formula:
        cochran_n = (Z**2 * p * q) /e**2
        where:
            - Z is the z-value. In this case we use 1.96 representing 95%
            - p is the estimated proportion of the population which has an
                attribute. In this case we use 0.5
            - q is 1-p
            - e is the margin of error
        This formula is adjusted as follows:
        adjusted_cochran = cochran_n / 1+((cochran_n -1)/N)
        where:
            - cochran_n = result of the previous formula
            - N is the population size
    :seed: sampling seed
    :keep_index: if True, it keeps a column with the original population index indicator
    
    Returns
    -------
    A sampled pandas dataframe based in a set of strata.
    Examples
    --------
    >> df.head()
    	id  sex age city 
    0	123 M   20  XYZ
    1	456 M   25  XYZ
    2	789 M   21  YZX
    3	987 F   40  ZXY
    4	654 M   45  ZXY
    ...
    # This returns a sample stratified by sex and city containing 30% of the size of
    # the original data
    >> stratified = stratified_sample(df=df, strata=['sex', 'city'], size=0.3)
    Requirements
    ------------
    - pandas
    - numpy
    '''
    population = len(df[df['sampling']==0])
    tmp = df[strata].where(data['sampling']==0)

    tmp['size'] = 1
    tmp_grpd = tmp.groupby(strata).count().reset_index()

    tmp_grpd['samp_size'] = round(size/population * tmp_grpd['size']).astype(int)


    # controlling variable to create the dataframe or append to it
    first = True 
    for i in range(len(tmp_grpd)):
        # query generator for each iteration
        qry=''
        for s in range(len(strata)):
            stratum = strata[s]
            value = tmp_grpd.iloc[i][stratum]
            n = tmp_grpd.iloc[i]['samp_size']


            if type(value) == str:
                value = "'" + str(value) + "'"
            
            if s != len(strata)-1:
                qry = qry + stratum + ' == ' + str(value) +' & '
            else:
                qry = qry + stratum + ' == ' + str(value)
        
        qry = qry + ' & sampling==0' #using only the data that were not yet sampled
        
        # final dataframe
        if first:
            stratified_df = df.query(qry).sample(n=n, random_state=seed).reset_index(drop=(not keep_index))
            selected_index= stratified_df['index'].tolist()
            first = False
        else:
            tmp_df = df.query(qry).sample(n=n, random_state=seed).reset_index(drop=(not keep_index))
            selected_index= tmp_df['index'].tolist()

            # stratified_df = stratified_df.append(tmp_df, ignore_index=True)
        
        df.loc[selected_index,'sampling']=sampling_code
        
    
    return df

# %%
data= pd.read_csv("../../Data/Dataset_v1.csv",sep=";")

data= data.rename(to_snake_case, axis='columns')

data['sampling']=0

sampling={"Train": {"code": 1, "size": round(len(data)*70 /100)}, 
            "Test": {"code": 2, "size": round(len(data)*15 /100)+1}, 
            "Validation": {"code": 3, "size": round(len(data)*15 /100)+1 }
        }


#generate sampling
for elt in sampling:
    sample= sampling[elt]
    print("size:",sample['size'], "population: ", len(data[data['sampling'] == 0]) )
    sample_df = stratified_sample(data, ['province','type_of_property'], size=sample['size'], seed=123, keep_index= True,sampling_code=sample['code'])  
    print("sample size:", len(sample_df[sample_df['sampling']==sample['code']]))

#verify if there are data that are not sampled
if len(data[data['sampling'] == 0]) > 0:
    sample_df = stratified_sample(data, ['province','type_of_property'], size=len(data[data['sampling'] == 0]), seed=123, keep_index= True,sampling_code=1)
# Out:
# size: 9566 population:  13666
# sample size: 9564
# size: 2051 population:  4102
# sample size: 2053
# size: 2051 population:  2049
# sample size: 2049

# %%
len(data[data['sampling'] == 3])
# Out:
# 2049

# %%
get_type_property_per_province_proportion(data)
# Out:
#                                         eastern-cape  free-state      gauteng  \
# House                                     365.000000  340.000000  3149.000000
# House %                                     5.089946    4.741319    43.912983
# House % over all properties                 2.670862    2.487926    23.042587
# Apartment / Flat                          130.000000   84.000000  1986.000000
# Apartment / Flat %                          2.845884    1.838879    43.476357
# Apartment / Flat % over all properties      0.951266    0.614664    14.532416
# Townhouse                                  48.000000  104.000000  1014.000000
# Townhouse %                                 2.492212    5.399792    52.647975
# Townhouse % over all properties             0.351237    0.761013     7.419874
#
#                                         kwazulu-natal     limpopo  mpumalanga  \
# House                                      709.000000  289.000000  547.000000
# House %                                      9.887045    4.030121    7.627946
# House % over all properties                  5.188058    2.114737    4.002634
# Apartment / Flat                           905.000000   60.000000  100.000000
# Apartment / Flat %                          19.811734    1.313485    2.189142
# Apartment / Flat % over all properties       6.622274    0.439046    0.731743
# Townhouse                                  299.000000   50.000000  130.000000
# Townhouse %                                 15.524403    2.596054    6.749740
# Townhouse % over all properties              2.187912    0.365872    0.951266
#
#                                         north-west  northern-cape  \
# House                                   545.000000      95.000000
# House %                                   7.600056       1.324780
# House % over all properties               3.987999       0.695156
# Apartment / Flat                        352.000000       7.000000
# Apartment / Flat %                        7.705779       0.153240
# Apartment / Flat % over all properties    2.575735       0.051222
# Townhouse                               144.000000       6.000000
# Townhouse %                               7.476636       0.311526
# Townhouse % over all properties           1.053710       0.043905
#
#                                         western-cape
# House                                    1132.000000
# House %                                    15.785804
# House % over all properties                 8.283331
# Apartment / Flat                          944.000000
# Apartment / Flat %                         20.665499
# Apartment / Flat % over all properties      6.907654
# Townhouse                                 131.000000
# Townhouse %                                 6.801661
# Townhouse % over all properties             0.958583

# %%
get_type_property_per_province_proportion(data[data['sampling']==1])
# Out:
#                                         eastern-cape  free-state      gauteng  \
# House                                     255.000000  238.000000  2204.000000
# House %                                     5.082719    4.743871    43.930636
# House % over all properties                 2.666248    2.488499    23.044751
# Apartment / Flat                           91.000000   59.000000  1390.000000
# Apartment / Flat %                          2.846419    1.845480    43.478261
# Apartment / Flat % over all properties      0.951485    0.616897    14.533668
# Townhouse                                  34.000000   73.000000   710.000000
# Townhouse %                                 2.520385    5.411416    52.631579
# Townhouse % over all properties             0.355500    0.763279     7.423672
#
#                                         kwazulu-natal     limpopo  mpumalanga  \
# House                                      496.000000  202.000000  383.000000
# House %                                      9.886386    4.026311    7.634044
# House % over all properties                  5.186115    2.112087    4.004601
# Apartment / Flat                           633.000000   42.000000   70.000000
# Apartment / Flat %                          19.799812    1.313732    2.189553
# Apartment / Flat % over all properties       6.618570    0.439147    0.731911
# Townhouse                                  209.000000   35.000000   91.000000
# Townhouse %                                 15.492958    2.594514    6.745738
# Townhouse % over all properties              2.185278    0.365956    0.951485
#
#                                         north-west  northern-cape  \
# House                                   381.000000      66.000000
# House %                                   7.594180       1.315527
# House % over all properties               3.983689       0.690088
# Apartment / Flat                        246.000000       5.000000
# Apartment / Flat %                        7.694714       0.156397
# Apartment / Flat % over all properties    2.572146       0.052279
# Townhouse                               101.000000       4.000000
# Townhouse %                               7.487027       0.296516
# Townhouse % over all properties           1.056043       0.041824
#
#                                         western-cape
# House                                     792.000000
# House %                                    15.786326
# House % over all properties                 8.281054
# Apartment / Flat                          661.000000
# Apartment / Flat %                         20.675633
# Apartment / Flat % over all properties      6.911334
# Townhouse                                  92.000000
# Townhouse %                                 6.819867
# Townhouse % over all properties             0.961941

# %%
get_type_property_per_province_proportion(data[data['sampling']==2])
# Out:
#                                         eastern-cape  free-state     gauteng  \
# House                                      55.000000   51.000000  472.000000
# House %                                     5.111524    4.739777   43.866171
# House % over all properties                 2.679006    2.484170   22.990745
# Apartment / Flat                           20.000000   12.000000  298.000000
# Apartment / Flat %                          2.915452    1.749271   43.440233
# Apartment / Flat % over all properties      0.974184    0.584510   14.515343
# Townhouse                                   7.000000   16.000000  152.000000
# Townhouse %                                 2.405498    5.498282   52.233677
# Townhouse % over all properties             0.340964    0.779347    7.403799
#
#                                         kwazulu-natal    limpopo  mpumalanga  \
# House                                      106.000000  44.000000   82.000000
# House %                                      9.851301   4.089219    7.620818
# House % over all properties                  5.163176   2.143205    3.994155
# Apartment / Flat                           136.000000   9.000000   15.000000
# Apartment / Flat %                          19.825073   1.311953    2.186589
# Apartment / Flat % over all properties       6.624452   0.438383    0.730638
# Townhouse                                   45.000000   8.000000   20.000000
# Townhouse %                                 15.463918   2.749141    6.872852
# Townhouse % over all properties              2.191914   0.389674    0.974184
#
#                                         north-west  northern-cape  \
# House                                    82.000000      14.000000
# House %                                   7.620818       1.301115
# House % over all properties               3.994155       0.681929
# Apartment / Flat                         53.000000       1.000000
# Apartment / Flat %                        7.725948       0.145773
# Apartment / Flat % over all properties    2.581588       0.048709
# Townhouse                                22.000000       1.000000
# Townhouse %                               7.560137       0.343643
# Townhouse % over all properties           1.071603       0.048709
#
#                                         western-cape
# House                                     170.000000
# House %                                    15.799257
# House % over all properties                 8.280565
# Apartment / Flat                          142.000000
# Apartment / Flat %                         20.699708
# Apartment / Flat % over all properties      6.916707
# Townhouse                                  20.000000
# Townhouse %                                 6.872852
# Townhouse % over all properties             0.974184

# %%
get_type_property_per_province_proportion(data[data['sampling']==3])
# Out:
#                                         eastern-cape  free-state     gauteng  \
# House                                      55.000000   51.000000  473.000000
# House %                                     5.102041    4.730983   43.877551
# House % over all properties                 2.684236    2.489019   23.084431
# Apartment / Flat                           19.000000   13.000000  298.000000
# Apartment / Flat %                          2.773723    1.897810   43.503650
# Apartment / Flat % over all properties      0.927282    0.634456   14.543680
# Townhouse                                   7.000000   15.000000  152.000000
# Townhouse %                                 2.447552    5.244755   53.146853
# Townhouse % over all properties             0.341630    0.732064    7.418253
#
#                                         kwazulu-natal    limpopo  mpumalanga  \
# House                                      107.000000  43.000000   82.000000
# House %                                      9.925788   3.988868    7.606679
# House % over all properties                  5.222060   2.098585    4.001952
# Apartment / Flat                           136.000000   9.000000   15.000000
# Apartment / Flat %                          19.854015   1.313869    2.189781
# Apartment / Flat % over all properties       6.637384   0.439239    0.732064
# Townhouse                                   45.000000   7.000000   19.000000
# Townhouse %                                 15.734266   2.447552    6.643357
# Townhouse % over all properties              2.196193   0.341630    0.927282
#
#                                         north-west  northern-cape  \
# House                                    82.000000      15.000000
# House %                                   7.606679       1.391466
# House % over all properties               4.001952       0.732064
# Apartment / Flat                         53.000000       1.000000
# Apartment / Flat %                        7.737226       0.145985
# Apartment / Flat % over all properties    2.586628       0.048804
# Townhouse                                21.000000       1.000000
# Townhouse %                               7.342657       0.349650
# Townhouse % over all properties           1.024890       0.048804
#
#                                         western-cape
# House                                     170.000000
# House %                                    15.769944
# House % over all properties                 8.296730
# Apartment / Flat                          141.000000
# Apartment / Flat %                         20.583942
# Apartment / Flat % over all properties      6.881406
# Townhouse                                  19.000000
# Townhouse %                                 6.643357
# Townhouse % over all properties             0.927282

# %%
#adding to csv
data.to_csv("../../Data/Dataset_v2.csv",sep=";",index=False)
