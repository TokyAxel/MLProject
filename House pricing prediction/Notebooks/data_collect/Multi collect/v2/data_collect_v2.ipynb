# %%
from bs4 import BeautifulSoup
from urllib.error import HTTPError
import urllib.request
import requests
import pandas as pd
import re
import csv

def crawl_page(link=''):
    # req = urllib.request.Request(
    #         link, 
    #         data=None, 
    #         headers={
    #             'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
    #             'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.79 Safari/537.36 Edge/14.14393'
    #         }
    # )
    # try:
    #     page= urllib.request.urlopen(req)
    #     return_code= page.getcode()
    #     soup_page= BeautifulSoup(page,'html.parser')
    #     return {'page':soup_page, 'status': return_code}
    # except HTTPError as err:
    #     if err.code == 404:
    #         return_code=404
    #         return {'page':'no page', 'status': return_code}
    #     else:
    #         raise
    try:
        response = requests.get(
            url='http://api.scraperapi.com', #scrapeapi
            params={
                'api_key': 'e3458ff579ef5c1369f185af0ceaecfb',
                'url': link,  
            },
            
        )
        return_code= 200
        soup_page= BeautifulSoup(response.content,'html.parser')
        return {'page':soup_page, 'status': return_code}
    except requests.exceptions.HTTPError as err:
        if err.response.status_code == 404:
            return_code=404
            return {'page':'no page', 'status': return_code}
    

def write_csv(line=[], file=''):
    with open(file, 'a', newline='') as csvfile:
        spamwriter = csv.writer(csvfile, delimiter=' ',
                                quotechar='|', quoting=csv.QUOTE_MINIMAL)
        spamwriter.writerow(line)

def remove_row_csv():
    with open('temp_27.csv') as inp:
        for link in csv.reader(inp):
            count=0
            temp=link
            with open('used_estate.txt') as out:
                for estate in csv.reader(out):
                    if re.match("(.*)/"+estate[0],temp[1]) is not None:
                        count+=1
            if count==0:
                new_row= [link[0]+','+link[1]]
                write_csv(new_row,"temp_28.csv")

def create_urls(file=''):
    with open(file) as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')
        line_count = 1
        for row in csv_reader:
            new_row= [str(line_count)+','+row[0]]
            write_csv(new_row,'property_url_v2.csv')
            line_count+=1

# %%
class DataCollect():
    def __init__(self):
        self.__url_to_open='https://www.property24.com'
        self.__soup=crawl_page(self.__url_to_open)['page']
        self.__area_url=[]
        self.__list_url=[]
        self.__urls=pd.read_csv("temp_46_v2.csv",usecols= ['id','url']) 
    
    def collect_all_first_page_url(self):
        other_links= self.__soup.find('div',class_='p24_popular').find(class_='col-8').find_all('a',class_='p24_bold')
        for link in other_links:
            self.__area_url.append(self.__url_to_open+link.get('href'))
        first_element_tag= self.__soup.find('div',class_='p24_popular').find(class_='col-8').find_all(class_='row')[1]
        first_link=first_element_tag.find('a').get('href')
        temp_soup= crawl_page(self.__url_to_open+first_link)['page']
        parent_link= temp_soup.find(id='breadCrumbContainer').find_all('a')[1]
        self.__area_url.append(self.__url_to_open+parent_link.get('href'))
    
    def collect_all_url(self):
        self.collect_all_first_page_url()
        for link in self.__area_url:
            soup= crawl_page(link)['page']
            link_house_tag= soup.find('ul',class_='p24_relatedSales').find(href=re.compile("houses-for-sale")).get('href')
            link_apart_tag= soup.find('ul',class_='p24_relatedSales').find(href=re.compile("apartments-for-sale")).get('href')
            link_townhouse_tag= soup.find('ul',class_='p24_relatedSales').find(href=re.compile("townhouses-for-sale")).get('href')
            self.__list_url.append(link_house_tag)
            self.__list_url.append(link_apart_tag)
            self.__list_url.append(link_townhouse_tag)

    def get_property_data(self, link=''):
        data={}

        estate_id= link.split('/')[-1].split('?')[0]

        prop_soup_element= crawl_page(self.__url_to_open+link)

        
        if prop_soup_element['status'] !=200:
            print('heres')
            return False
        
        prop_soup= prop_soup_element['page']

        if prop_soup is None:
            print('here')
            return False

        #check if page not found
        check_page_not_found_msg= prop_soup.select_one('.p24_not_found')
        if check_page_not_found_msg is not None:
            print("====> Page not found !!")
            return False
        
        #check page expired
        check_page_expired = prop_soup.select_one('.p24_results.p24_expired')
        if check_page_expired is not None:
            print("====> Page expired !!")
            return False
        

        name= prop_soup.find('div',class_='p24_listingFeaturesWrapper').find('h1').get_text()
        data['name']=name

        price= prop_soup.find('div',class_='p24_listingFeaturesWrapper').find('div',class_="p24_price").get_text()
        data['price']=price

        province= link.split('/')[4]
        data['province']=province

        city= link.split('/')[3]
        data['city']=city


        is_adress= len(prop_soup.find('div',class_='p24_listingFeaturesWrapper').find_all('div',class_="p24_mBM")) >= 3
        if is_adress:
            if len(prop_soup.find('div',class_='p24_listingFeaturesWrapper').find_all('div',class_="p24_mBM")) == 3:
                index=-1
            else:
                index=3
            address= prop_soup.find('div',class_='p24_listingFeaturesWrapper').find_all('div',class_="p24_mBM")[index].get_text()
            data['address']=address
        else:
            address=  prop_soup.select_one('.p24_addressPropOverview').get_text()
            data['address']=address

        #property overview
        if type(prop_soup.select_one('.p24_propertyOverview')) is not None:
            prop_overview_panel= prop_soup.find('div',class_='p24_propertyOverview').find('div',class_='panel-body')
            prop_overview_row= prop_overview_panel.find_all('div',class_='p24_propertyOverviewRow')
            for prop in prop_overview_row:
                key= prop.find('div',class_='p24_propertyOverviewKey').get_text()
                # value= prop.select_one('.noPadding > .p24_info').get_text()
                value= prop.find('div',class_='noPadding').contents[1].get_text()
                data[key]=value

        #rooms
        rooms_panel=prop_soup.select_one('#js_accordion_rooms')
        if rooms_panel is not None:
            prop_overview_row= rooms_panel.find_all('div',class_='p24_propertyOverviewRow')
            for prop in prop_overview_row:
                key= prop.find('div',class_='p24_propertyOverviewKey').get_text()
                # value= prop.select_one('.noPadding > .p24_info').get_text()
                value= prop.find('div',class_='noPadding').contents[1].get_text()
                data[key]=value

        #external_features
        external_features_panel=prop_soup.select_one('#js_accordion_externalfeatures')
        if external_features_panel is not None:
            prop_overview_row= external_features_panel.find_all('div',class_='p24_propertyOverviewRow')
            for prop in prop_overview_row:
                key= prop.find('div',class_='p24_propertyOverviewKey').get_text()
                # value= prop.select_one('.noPadding > .p24_info').get_text()
                value= prop.find('div',class_='noPadding').contents[1].get_text()
                data[key]=value
        
        #other_features
        other_features_panel=prop_soup.select_one('#js_accordion_otherfeatures')
        if other_features_panel is not None:
            prop_overview_row= other_features_panel.find_all('div',class_='p24_propertyOverviewRow')
            for prop in prop_overview_row:
                key= prop.find('div',class_='p24_propertyOverviewKey').get_text()
                # value= prop.select_one('.noPadding > .p24_info').get_text()
                value= prop.find('div',class_='noPadding').contents[1].get_text()
                data[key]=value

        #building_features
        building_features_panel=prop_soup.select_one('#js_accordion_building')
        if building_features_panel is not None:
            prop_overview_row= building_features_panel.find_all('div',class_='p24_propertyOverviewRow')
            for prop in prop_overview_row:
                key= prop.find('div',class_='p24_propertyOverviewKey').get_text()
                # value= prop.select_one('.noPadding > .p24_info').get_text()
                value= prop.find('div',class_='noPadding').contents[1].get_text()
                data[key]=value

        #points_interest
        interest_soup= crawl_page(self.__url_to_open+'/ListingReadOnly/PointsOfInterestForListing?ListingNumber=P24-'+estate_id)
        # points_interest_panel=prop_soup.select_one('#accordian-points-of-interest')
        # print(points_interest_panel)
        if interest_soup['status'] == 200:
            categories= interest_soup['page'].select('.js_P24_POICategory')
            for cat in categories:
                interest= cat.select_one('.row > .col-6 > .p24_semibold')
                distances= cat.select('.row > .col-6.noPadding.p24_semibold')
                dist_tab=[]
                for dist in distances:
                    dist_tab.append(dist.get_text())
                data[interest.get_text()]=dist_tab

        print(str(data))
        write_csv([str(data)],'data_property_v2.csv')

        
        return True

    def crawl_property_per_page(self,city,page,number_properties):
        link=self.__url_to_open+city+'/p'+str(page)
        print('==>Page link: ',link)
        cur_soup= crawl_page(link)['page']
        properties= cur_soup.find_all('div',class_='js_resultTile')
        for prop_index in range(len(properties)-1):
            prop_link= properties[prop_index].find('a').get('href')
            write_csv([prop_link],'data_property_url.csv')

        number_properties+= len(properties)
        return number_properties

    def crawl_property_per_city(self,city,cur_page):
        soup= crawl_page(self.__url_to_open+city)['page']
        pagination= soup.find('div',class_='p24_pager').find_all('li')[-1].find('a').get('data-pagenumber')
        page_number= int(pagination)
        number_properties=0
        print("City url: ",city)
        for page in range(cur_page, page_number+1):
            print("=>Page number: ",page)
            number_properties = self.crawl_property_per_page(city,page,number_properties)
        print(number_properties)
    
    def crawl_properties(self):
        #shuffle
        self.__urls = self.__urls.sample(frac = 1).reset_index(drop=True)
        for i in range(self.__urls.size):
            prop_link= self.__urls.iloc[i]['url']
            
            print('==>Property link: ', prop_link)
            check_property_crawl = self.get_property_data(prop_link)
            if check_property_crawl:
                self.__urls= self.__urls.drop(self.__urls.index[i])
                self.__urls.to_csv('temp_47_v2.csv',index=False)

    def crawl_property_url(self):
        self.__list_url=['/townhouses-for-sale/gauteng/1']
        for link in self.__list_url:
            self.crawl_property_per_city(link,1)

# %%
dc= DataCollect()
try:
    dc.crawl_properties()
except:
    dc.crawl_properties()
# Out:
# ==>Property link:  /for-sale/vaalpark/sasolburg/free-state/9917/109283225
# {'name': '1 Bedroom Apartment / Flat for Sale in Vaalpark', 'price': 'R 695 000', 'province': 'free-state', 'city': 'sasolburg', 'address': 'Vaalpark, Sasolburg', 'Listing Number': '109283225', 'Type of Property': 'Apartment / Flat', 'Listing Date': '16 July 2021', 'Levies': 'R 1 500', 'Rates and Taxes': 'R 600', 'Bedroom': 'Tiled Floors, Curtain Rails, Built-in Cupboards', 'Bathroom': 'Tiled Floors, Full, Blinds', 'Kitchen': 'Tiled Floors, Blinds, Under Counter Oven, Hob', 'Office/study': 'Tiled Floors, Blinds', 'Lounge': 'Tiled Floors, Balcony, Open Plan', 'Dining Room': 'Tiled Floors, Blinds, Open Plan', 'Garage': 'Single', 'Security': 'Electric Gate, Intercom, Closed Circuit TV, 24 Hour Access', 'Special Features': 'Satellite Dish, Boat Launch', 'Internet Access': 'Fibre', 'Education': ['0.37km', '0.96km', '1.14km', '3.55km', '4.30km', '4.68km', '4.77km', '4.83km', '4.94km', '5.04km', '5.22km', '5.25km', '5.49km', '5.50km', '5.62km', '5.65km', '5.78km', '5.87km', '6.22km', '6.24km', '6.32km', '6.52km', '6.84km', '7.05km', '7.11km', '7.13km', '7.19km', '7.20km'], 'Sports and Leisure': ['4.19km', '4.26km']}
# ==>Property link:  /for-sale/stilfontein/stilfontein/north-west/5110/109833210
# {'name': '3 Bedroom House for Sale in Stilfontein', 'price': 'R 450 722', 'province': 'north-west', 'city': 'stilfontein', 'address': 'Stilfontein', 'Listing Number': '109833210', 'Type of Property': 'House', 'Listing Date': '08 April 2021', 'Floor Size': '84 m²', 'Levies': 'R 200', 'Rates and Taxes': 'R 300', 'Bedrooms': '3', 'Bathrooms': '1', 'Kitchen': 'Pantry', 'Dining Rooms': '1', 'Family/TV Rooms': '1', 'Garage': '1', 'Security': 'Alarm System', 'Education': ['0.58km', '0.62km', '0.70km', '0.87km', '0.90km', '1.69km', '3.38km', '6.51km', '7.15km', '7.48km', '7.54km', '8.11km', '8.11km', '8.12km', '8.17km', '8.43km', '8.53km', '8.55km', '8.97km', '9.06km', '9.10km', '9.35km'], 'Transport and Public Services': ['2.29km']}
# ==>Property link:  /for-sale/boitekong/rustenburg/north-west/3113/110042203
# {'name': '2 Bedroom House for Sale in Boitekong', 'price': 'R 490 000', 'province': 'north-west', 'city': 'rustenburg', 'address': 'Boitekong, Rustenburg', 'Listing Number': '110042203', 'Type of Property': 'House', 'Description': 'Freestanding', 'Listing Date': '01 June 2021', 'Erf Size': '255 m²', 'Rates and Taxes': 'R 1 500', 'Pets Allowed': 'Yes', 'Bedrooms': '2', 'Bedroom 1': ' ', 'Bedroom 2': ' ', 'Bathrooms': '1', 'Lounge': ' ', 'Parking': '5', 'Parking 2': 'Visitors Parking', 'Parking 3': 'Visitors Parking', 'Parking 4': 'Visitors Parking', 'Parking 5': 'Visitors Parking', 'Garden': 'Yes', 'Wheelchair Accessible': 'Yes', 'Education': ['0.57km', '1.69km', '1.79km', '2.75km', '3.24km', '3.54km', '3.72km', '3.84km', '4.93km', '4.94km', '5.18km', '5.18km', '5.34km', '5.37km', '5.84km', '6.01km', '6.02km', '6.12km', '6.15km', '6.41km', '6.41km', '6.42km'], 'Health': ['5.33km'], 'Transport and Public Services': ['5.34km', '5.75km', '6.35km', '6.36km'], 'Food and Entertainment': ['6.10km', '6.19km', '6.49km']}
# ==>Property link:  /for-sale/lotus-river/cape-town/western-cape/10212/110196622
# {'name': '2 Bedroom Apartment / Flat for Sale in Lotus River', 'price': 'R 825 000', 'province': 'western-cape', 'city': 'cape-town', 'address': 'Lotus River, Cape Town', 'Listing Number': '110196622', 'Type of Property': 'Apartment / Flat', 'Listing Date': '14 July 2021', 'Floor Size': '50 m²', 'Price per m²': 'R 16 500', 'Levies': 'R 1 590', 'Pets Allowed': 'No', 'Bedrooms': '2', 'Bedroom 1': ' ', 'Bedroom 2': ' ', 'Bathrooms': '1', 'Kitchen': ' ', 'Lounge': ' ', 'Security': 'Electric fencing', 'Education': ['0.24km', '0.68km', '0.83km', '0.88km', '0.89km', '0.90km', '0.96km', '1.06km', '1.08km', '1.09km', '1.14km', '1.28km', '1.34km', '1.44km', '1.48km', '1.63km', '1.64km', '1.89km', '1.90km', '2.10km', '2.13km', '2.23km', '2.42km', '2.49km', '2.58km', '2.60km', '2.70km', '2.75km'], 'Transport and Public Services': ['2.12km', '2.35km']}
# ==>Property link:  /for-sale/honeydew/roodepoort/gauteng/716/109910593
# {'name': '2 Bedroom Apartment / Flat for Sale in Honeydew', 'price': 'R 550 000', 'province': 'gauteng', 'city': 'roodepoort', 'address': 'Honeydew, Roodepoort', 'Listing Number': '109910593', 'Type of Property': 'Apartment / Flat', 'Listing Date': '28 April 2021', 'Floor Size': '61 m²', 'Price per m²': 'R 9 016', 'Levies': 'R 650', 'Rates and Taxes': 'R 98', 'Bedrooms': '2', 'Bathrooms': '1', 'Kitchens': '1', 'Lounges': '1', 'Dining Rooms': '1', 'Parking': 'Carport', 'Nearby Public Transport': 'Minibus Taxi', 'Shopping': ['0.06km', '0.18km', '2.10km'], 'Food and Entertainment': ['0.20km', '0.20km', '0.21km', '1.21km', '1.23km', '1.67km', '1.81km', '1.82km', '1.82km', '1.84km', '1.84km', '1.85km', '1.94km', '1.99km'], 'Education': ['0.31km', '0.40km', '0.55km', '0.94km', '0.96km', '1.01km', '1.82km', '1.82km'], 'Transport and Public Services': ['0.31km', '0.94km', '1.71km', '2.07km'], 'Health': ['2.02km']}
# ==>Property link:  /for-sale/olievenhoutbosch/centurion/gauteng/592/109977908
# {'name': '2 Bedroom Apartment / Flat for Sale in Olievenhoutbosch', 'price': 'R 580 000', 'province': 'gauteng', 'city': 'centurion', 'address': 'Olievenhoutbosch, Centurion', 'Listing Number': '109977908', 'Type of Property': 'Apartment / Flat', 'Listing Date': '14 May 2021', 'No Transfer Duty': 'Yes', 'Rates and Taxes': 'R 200', 'Bedrooms': '2', 'Bathrooms': '1', 'Kitchens': '1', 'Parking': 'Shade net covered', 'Garden': 'Children Playground', 'Education': ['0.17km', '0.21km', '0.64km', '0.88km', '1.68km', '2.11km', '2.45km', '3.13km', '4.09km', '4.18km', '4.77km'], 'Transport and Public Services': ['2.66km', '2.97km', '3.32km', '3.34km', '3.63km', '4.67km'], 'Food and Entertainment': ['3.21km', '4.69km', '4.70km', '4.71km', '4.72km', '4.73km', '4.76km', '4.77km'], 'Sports and Leisure': ['3.56km'], 'Health': ['4.70km', '4.75km'], 'Shopping': ['4.74km', '4.77km']}
# ==>Property link:  /for-sale/sabie-park/bushbuckridge/mpumalanga/2832/108924788
# ==>Property link:  /for-sale/potchefstroom-central/potchefstroom/north-west/5025/107448938
# {'name': '2 Bedroom Apartment / Flat for Sale in Potchefstroom Central', 'price': 'R 495 000', 'province': 'north-west', 'city': 'potchefstroom', 'address': 'Potchefstroom Central, Potchefstroom', 'Listing Number': '107448938', 'Type of Property': 'Apartment / Flat', 'Listing Date': '30 April 2019', 'Erf Size': '2 361 m²', 'Floor Size': '65 m²', 'Price per m²': 'R 7 615', 'Levies': 'R 721', 'Rates and Taxes': 'R 270', 'Pets Allowed': 'No', 'Bedrooms': '2', 'Bathrooms': '1', 'Kitchens': '1', 'Parking': '1', 'Food and Entertainment': ['0.37km'], 'Education': ['0.52km', '0.59km', '0.64km', '0.79km', '1.03km', '1.06km', '1.28km', '1.34km', '1.57km', '1.57km', '1.61km', '1.64km', '1.71km', '1.90km', '2.23km', '2.68km', '2.79km', '3.89km', '4.08km', '4.22km', '4.29km', '4.35km', '4.38km', '4.59km', '4.67km'], 'Transport and Public Services': ['1.00km', '2.42km', '2.61km', '4.76km']}
# ==>Property link:  /for-sale/pretoria-central/pretoria/gauteng/27/110117214
# {'name': '3.5 Bedroom Apartment / Flat for Sale in Pretoria Central', 'price': 'R 550 000', 'province': 'gauteng', 'city': 'pretoria', 'address': 'Pretoria Central, Pretoria', 'Listing Number': '110117214', 'Type of Property': 'Apartment / Flat', 'Description': 'Single Storey', 'Listing Date': '22 June 2021', 'Levies': 'R 1 630', 'Bedroom': '3.5', 'Bathrooms': '1', 'Kitchen': '1', 'Reception Rooms': '1', 'Dining Room': '1', 'Braai Room': '1', 'Entrance Hall': '1', 'Garage': '1', 'Parking': '2', 'Security': 'Security Gate, Alarm System, Intercom, 24 Hour Access', 'Special Feature': 'Built in Braai, Satellite Dish, Balcony', 'Food and Entertainment': ['0.10km', '0.17km', '0.27km', '0.35km', '0.39km', '0.43km', '0.47km', '0.50km', '0.51km', '0.52km', '0.54km'], 'Shopping': ['0.13km', '0.26km', '0.29km', '0.30km', '0.41km'], 'Education': ['0.20km', '0.31km', '0.32km', '0.44km', '0.50km', '0.51km', '0.52km', '0.53km', '0.53km', '0.53km'], 'Transport and Public Services': ['0.29km', '0.47km', '0.50km', '0.54km']}
# ==>Property link:  /for-sale/morningside/sandton/gauteng/4258/109703456
# {'name': '2 Bedroom Apartment / Flat for Sale in Morningside', 'price': 'R 1 625 000', 'province': 'gauteng', 'city': 'sandton', 'address': '\n2 Bedroom Apartment / Flat for Sale in Morningside\n', 'Listing Number': '109703456', 'Type of Property': 'Apartment / Flat', 'Street Address': ' The Space\n16 Nerina Road, Morningside', 'Listing Date': '03 March 2021', 'Levies': 'R 2 439', 'Rates and Taxes': 'R 1 421', 'Bedrooms': '2', 'Bathrooms': '2', 'Kitchens': '1', 'Lounges': '1', 'Dining Rooms': '1', 'Parking': '2', 'Pool': 'Communal Pool', 'Security': '1', 'Internet Access': 'Fibre', 'Transport and Public Services': ['0.45km', '0.89km', '1.17km', '1.23km', '1.51km', '1.57km', '1.58km', '1.77km'], 'Food and Entertainment': ['0.48km', '0.89km', '1.17km', '1.17km', '1.18km', '1.19km', '1.24km', '1.52km', '1.53km', '1.53km', '1.53km', '1.56km', '1.57km'], 'Education': ['0.79km', '1.36km', '1.36km', '1.62km'], 'Shopping': ['1.21km', '1.22km', '1.53km', '1.53km'], 'Health': ['1.53km']}
# ==>Property link:  /for-sale/bendor/polokwane/limpopo/11332/108467623
# {'name': '4 Bedroom House for Sale in Bendor', 'price': 'R 2 200 000', 'province': 'limpopo', 'city': 'polokwane', 'address': 'Bendor, Polokwane', 'Listing Number': '108467623', 'Type of Property': 'House', 'Description': 'Single Storey', 'Listing Date': '20 February 2020', 'Erf Size': '634 m²', 'Bedrooms': '4', 'Bathrooms': '3', 'Kitchen': '1', 'Reception Rooms': '1', 'Lounge': '1', 'Dining Room': '1', 'Family/TV Room': '1', 'Entrance Hall': '1', 'Garage': '2', 'Education': ['1.54km', '1.81km', '2.20km', '2.43km', '2.79km', '2.90km', '2.92km', '2.94km', '3.09km', '3.10km', '3.45km', '3.53km', '3.74km', '3.74km', '3.75km', '3.75km', '3.83km', '4.01km', '4.08km', '4.34km', '4.34km', '4.34km', '4.99km', '5.78km', '5.97km', '6.00km'], 'Transport and Public Services': ['3.67km', '4.23km', '4.81km', '5.46km']}
# ==>Property link:  /for-sale/vanderbijlpark-cw-2/vanderbijlpark/gauteng/3640/109734661
# {'name': '2 Bedroom Apartment / Flat for Sale in Vanderbijlpark Cw 2', 'price': 'R 350 000', 'province': 'gauteng', 'city': 'vanderbijlpark', 'address': 'Vanderbijlpark CW 2, Vanderbijlpark', 'Listing Number': '109734661', 'Type of Property': 'Apartment / Flat', 'Listing Date': '10 March 2021', 'Levies': 'R 2 000', 'Rates and Taxes': 'R 100', 'Bedrooms': '2', 'Bedroom 1': 'Tiled Floors, Curtain Rails, Built-in Cupboards, Double Bed', 'Bedroom 2': 'Tiled Floors, Curtain Rails, Built-in Cupboards, Double Bed', 'Bathroom': 'Tiled Floors, Curtain Rails, Bath, Toilet and Basin', 'Kitchen': 'Stove, Tiled Floors, Curtain Rails', 'Lounge': 'Tiled Floors, Balcony, Curtain Rails', 'Garage': 'Roll up, Single', 'Parking': 'Secure Parking', 'Security': 'Electric Gate, Burglar Bars', 'Education': ['0.20km', '0.64km', '0.82km', '0.92km', '0.95km', '1.12km', '1.58km', '1.59km', '1.77km', '1.82km', '1.92km', '2.01km', '2.13km', '2.40km', '2.47km', '2.47km', '2.48km', '2.52km', '2.56km', '2.74km', '2.87km', '3.02km', '3.03km', '3.15km', '3.31km', '3.50km', '3.52km', '3.63km', '3.64km', '3.65km']}
# ==>Property link:  /for-sale/wellington-central/wellington/western-cape/8648/110121010
# {'name': '2 Bedroom Townhouse for Sale in Wellington Central', 'price': 'R 995 000', 'province': 'western-cape', 'city': 'wellington', 'address': '\n2 Bedroom Townhouse for Sale in Wellington Central\n', 'Listing Number': '110121010', 'Type of Property': 'Townhouse', 'Street Address': ' 11 Malan Estates, Malan Street, Wellington Central', 'Listing Date': '22 June 2021', 'Levies': 'R 2 023', 'Rates and Taxes': 'R 632', 'Bedrooms': '2', 'Bathrooms': '1', 'Kitchens': '1', 'Garage': '1', 'Parking': '2', 'Security': 'Security Gate, Burglar Bars, Electric fencing', 'Education': ['0.05km', '0.32km', '0.54km', '0.66km', '0.72km', '1.14km', '1.15km', '1.46km', '1.53km', '2.31km', '2.39km', '3.01km', '3.17km', '3.22km', '3.82km', '3.87km', '3.99km', '4.01km', '4.30km', '4.38km', '4.84km', '4.86km', '5.63km', '5.72km', '6.20km', '7.57km'], 'Transport and Public Services': ['1.36km', '3.30km', '6.78km', '7.42km']}
# ==>Property link:  /for-sale/durmonte/durbanville/western-cape/9523/110099232
# {'name': '3 Bedroom House for Sale in Durmonte', 'price': 'R 2 290 000', 'province': 'western-cape', 'city': 'durbanville', 'address': 'Durmonte, Durbanville', 'Listing Number': '110099232', 'Type of Property': 'House', 'Listing Date': '16 June 2021', 'Erf Size': '450 m²', 'Floor Size': '110 m²', 'Pets Allowed': 'Yes', 'Bedrooms': '3', 'Bathrooms': '2', 'Garage': '2', 'Parking': '2', 'Garden': 'Yes', 'Internet Access': 'Fibre', 'Education': ['0.50km', '1.92km', '2.09km', '3.07km', '3.16km', '3.19km', '3.21km', '3.72km', '4.43km', '4.64km', '4.65km'], 'Transport and Public Services': ['0.69km', '2.13km', '2.80km', '2.92km', '3.46km', '4.05km'], 'Sports and Leisure': ['2.22km', '2.31km', '2.33km', '2.38km', '2.58km', '4.37km'], 'Food and Entertainment': ['2.53km', '2.67km', '4.37km', '4.46km'], 'Shopping': ['2.65km', '2.66km', '2.68km']}
# ==>Property link:  /for-sale/parkmore/sandton/gauteng/5843/109285440
# {'name': '4 Bedroom House for Sale in Parkmore', 'price': 'R 2 990 000', 'province': 'gauteng', 'city': 'sandton', 'address': '\n4 Bedroom House for Sale in Parkmore\n', 'Listing Number': '109285440', 'Type of Property': 'House', 'Street Address': ' Ninth street, Parkmore, Parkmore', 'Listing Date': '30 May 2021', 'Erf Size': '991 m²', 'Rates and Taxes': 'R 1 200', 'Pets Allowed': 'Yes', 'Bedrooms': '4', 'Bathrooms': '3', 'Garage': '2', 'Parking': '3', 'Garden': 'Yes', 'Pool': 'Yes', 'Flatlet': 'Yes', 'Transport and Public Services': ['0.30km', '0.77km', '0.81km', '0.86km', '1.12km', '1.77km'], 'Education': ['0.38km', '1.05km', '1.11km'], 'Shopping': ['0.97km', '0.98km', '0.99km', '0.99km', '1.66km', '1.77km', '1.81km'], 'Food and Entertainment': ['1.66km', '1.67km', '1.67km', '1.68km', '1.68km', '1.68km', '1.72km', '1.77km', '1.78km', '1.78km', '1.79km', '1.79km', '1.79km'], 'Sports and Leisure': ['1.75km']}
# ==>Property link:  /for-sale/vanderbijlpark-se-2/vanderbijlpark/gauteng/3649/109394714
# {'name': '5 Bedroom House for Sale in Vanderbijlpark Se 2', 'price': 'R 1 800 000', 'province': 'gauteng', 'city': 'vanderbijlpark', 'address': 'Vanderbijlpark SE 2, Vanderbijlpark', 'Listing Number': '109394714', 'Type of Property': 'House', 'Listing Date': '26 November 2020', 'Erf Size': '1 452 m²', 'Pets Allowed': 'Yes', 'Bedrooms': '5', 'Bedroom 1': 'Built-in Cupboards', 'Bedroom 2': 'Built-in Cupboards', 'Bedroom 3': 'Built-in Cupboards', 'Bedroom 4': 'Built-in Cupboards', 'Bedroom 5': 'Built-in Cupboards', 'Bathrooms': '3', 'Bathroom 1': 'Main en Suite, Shower, En suite, Bath, Toilet and Basin', 'Bathroom 2': 'Full, En suite', 'Bathroom 3': 'Guest Toilet', 'Kitchen': 'Breakfast Nook, Pantry, Scullery, Laundry, Built-in Cupboards', 'Office/studies': '1', 'Domestic Rooms': '1', 'Domestic Bathrooms': '1', 'Lounges': '1', 'Dining Rooms': '1', 'Family/TV Rooms': '1', 'Braai Rooms': '1', 'Entrance Halls': '1', 'Garage': '2', 'Garage 1': 'Wooden doors', 'Garage 2': 'Wooden doors', 'Parking': '3', 'Parking 1': 'Carport', 'Parking 2': 'Carport', 'Parking 3': 'Carport', 'Gardens': '1', 'Outbuilding': 'Staff Quarters/Domestic Rooms, Domestic Bathroom', 'Security': 'Totally Fenced, Electric Gate, Intercom, Burglar Bars', 'Temperature Control': 'Jetmaster and 3 air cons', 'Special Featuress': '2', 'Special Features 1': 'Built in Braai, Satellite Dish, Borehole, Paveway', 'Special Features 2': 'Prepaid electricity', 'Roof': 'Tile', 'Sports and Leisure': ['0.26km', '0.42km'], 'Education': ['0.64km', '0.97km', '1.06km', '1.15km', '1.23km', '1.29km', '1.54km', '1.71km', '1.79km', '2.11km', '2.27km', '2.27km', '2.35km', '2.63km', '2.70km', '2.80km', '3.53km', '3.61km', '3.61km', '3.83km', '3.97km', '4.02km', '4.03km', '4.05km', '4.28km', '4.34km', '4.52km', '4.57km']}
# ==>Property link:  /for-sale/sea-point/cape-town/western-cape/11021/107506824
# {'name': '3 Bedroom Apartment / Flat for Sale in Sea Point', 'price': 'R 4 500 000', 'province': 'western-cape', 'city': 'cape-town', 'address': '\n3 Bedroom Apartment / Flat for Sale in Sea Point\n', 'Listing Number': '107506824', 'Type of Property': 'Apartment / Flat', 'Street Address': ' 341 Main Road, Sea Point', 'Listing Date': '17 May 2019', 'Levies': 'R 2 200', 'Rates and Taxes': 'R 1 800', 'Bedrooms': '3', 'Bathrooms': '2', 'Kitchens': '1', 'Dining Rooms': '1', 'Family/TV Rooms': '1', 'Parking': 'Single', 'Food and Entertainment': ['0.04km', '0.04km', '0.06km', '0.07km', '1.96km', '2.00km', '2.15km', '2.28km', '2.28km', '2.30km', '2.31km'], 'Education': ['0.40km', '0.57km', '0.87km', '0.97km', '1.60km', '1.86km', '1.95km', '1.99km', '2.02km', '2.16km', '2.24km'], 'Transport and Public Services': ['0.45km', '0.62km', '1.35km', '1.42km', '1.47km', '1.59km', '1.79km', '2.04km']}
# ==>Property link:  /for-sale/hazeldean/pretoria/gauteng/12193/109730986
# {'name': '4 Bedroom Townhouse for Sale in Hazeldean', 'price': 'R 1 549 000', 'province': 'gauteng', 'city': 'pretoria', 'address': '\n4 Bedroom Townhouse for Sale in Hazeldean\n', 'Listing Number': '109730986', 'Type of Property': 'Townhouse', 'Street Address': ' 1 Ridge Road, Hazeldean, Hazeldean', 'Lifestyle': 'Complex, Security Estate', 'Listing Date': '09 March 2021', 'Erf Size': '250 m²', 'Floor Size': '166 m²', 'Levies': 'R 1 090', 'Rates and Taxes': 'R 790', 'Age': '3', 'Pets Allowed': 'Yes', 'Coverage': '66 %', 'Bedrooms': '4', 'Bedroom 1': 'Tiled Floors, Curtain Rails, Queen Bed', 'Bedroom 2': 'Tiled Floors, Curtain Rails, Queen Bed', 'Bedroom 3': 'Tiled Floors, Curtain Rails, Built-in Cupboards, Queen Bed', 'Bedroom 4': 'Very spacious main bedroom with built in dressing table', 'Bathrooms': '2', 'Bathroom 1': 'Modern bathroom', 'Bathroom 2': 'Tiled Floors, Blinds, Shower, Toilet and Basin', 'Kitchen': 'Space for double door fridge/freezer', 'Office/study': 'Tiled Floors, Open Plan', 'Dining Room': 'Patio, Tiled Floors, Curtain Rails, Open Plan', 'Family/TV Room': 'Tiled Floors, Curtain Rails, Open Plan', 'Other': 'Store room under stairs', 'Garage': '2', 'Garage 1': 'Plenty of built in cupboards in garage ', 'Garage 2': 'Laundry space in garage can accommodate top loader washing machine', 'Parking': '2', 'Parking 1': 'Visitors Parking', 'Parking 2': 'Visitors Parking', 'Garden': 'Private garden where 2 small pets are welcome', 'Pool': 'Clubhouse and cricket nets are located at the swimming pool', 'Nearby Public Transport': 'Minibus Taxi', 'Internet Access': 'Fibre', 'Wheelchair Accessible': 'No', 'Style': 'Modern, Open Plan', 'Roof': 'Tile', 'Wall': 'Brick', 'Window': 'Steel ', 'Standalone Building': 'No', 'Education': ['0.23km', '1.09km', '2.75km', '2.88km', '2.98km'], 'Sports and Leisure': ['2.75km', '3.00km'], 'Shopping': ['3.18km', '3.23km', '3.26km', '3.27km', '3.31km'], 'Health': ['3.19km', '3.21km'], 'Food and Entertainment': ['3.20km', '3.20km', '3.20km', '3.21km', '3.21km', '3.22km', '3.23km', '3.24km', '3.25km', '3.27km', '3.28km', '3.29km', '3.29km', '3.30km', '3.31km', '3.32km']}
# ==>Property link:  /for-sale/esther-park/kempton-park/gauteng/1321/110112163
# {'name': '2 Bedroom Apartment / Flat for Sale in Esther Park', 'price': 'R 665 000', 'province': 'gauteng', 'city': 'kempton-park', 'address': 'Esther Park, Kempton Park', 'Listing Number': '110112163', 'Type of Property': 'Apartment / Flat', 'Listing Date': '21 June 2021', 'Erf Size': '33 529 m²', 'Floor Size': '67 m²', 'Price per m²': 'R 9 925', 'Levies': 'R 1 400', 'Rates and Taxes': 'R 350', 'Bedrooms': '2', 'Bedroom 1': 'Bedroom 2', 'Bedroom 2': 'Bedroom 1', 'Bathrooms': '2', 'Bathroom 1': 'Bathroom 2', 'Bathroom 2': 'Bathroom 1', 'Kitchen': 'Kitchen', 'Parking': '2', 'Parking 1': 'Parking 1', 'Parking 2': 'Parking 2', 'Secure Parking': '1', 'Pool': 'Pool', 'Outbuilding': 'Outbuilding', 'Outside Toilets': '1', 'Security': 'Electric Gate, Intercom, Guard House, Guard', 'Special Features': 'Special Features', 'Special Feature': 'Satellite Dish', 'Education': ['0.76km', '1.39km', '1.75km', '2.00km', '2.07km', '2.29km', '2.60km', '2.61km', '2.86km', '3.03km', '3.06km', '3.24km', '3.37km', '3.50km', '3.65km', '3.69km', '3.80km'], 'Transport and Public Services': ['2.89km', '3.07km', '3.25km', '3.27km', '3.34km', '3.38km', '3.76km', '3.78km'], 'Food and Entertainment': ['3.31km', '3.67km', '3.69km', '3.74km'], 'Health': ['3.70km']}
# ==>Property link:  /for-sale/new-market-park/alberton/gauteng/1881/109895646
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-205986050037> in <module>
#       3     dc.crawl_properties()
#       4 except:
# ----> 5     dc.crawl_properties()
#
# <ipython-input-12-bd177bca43db> in crawl_properties(self)
#     184
#     185             print('==>Property link: ', prop_link)
# --> 186             check_property_crawl = self.get_property_data(prop_link)
#     187             if check_property_crawl:
#     188                 self.__urls= self.__urls.drop(self.__urls.index[i])
#
# <ipython-input-12-bd177bca43db> in get_property_data(self, link)
#     135
#     136         #points_interest
# --> 137         interest_soup= crawl_page(self.__url_to_open+'/ListingReadOnly/PointsOfInterestForListing?ListingNumber=P24-'+estate_id)
#     138         # points_interest_panel=prop_soup.select_one('#accordian-points-of-interest')
#     139         # print(points_interest_panel)
#
# <ipython-input-1-dce068c5361d> in crawl_page(link)
#      28     #         raise
#      29     try:
# ---> 30         response = requests.get(
#      31             url='http://api.scraperapi.com', #scrapeapi
#      32             params={
#
# /usr/lib/python3/dist-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /usr/lib/python3/dist-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# /usr/lib/python3/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /usr/lib/python3/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /usr/lib/python3/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     663
#     664             # Make the request on the httplib connection object.
# --> 665             httplib_response = self._make_request(
#     666                 conn,
#     667                 method,
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                     # Python 3 (including for exceptions like SystemExit).
#     420                     # Otherwise it looks like a bug in the code.
# --> 421                     six.raise_from(e, None)
#     422         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     423             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/lib/python3/dist-packages/six.py in raise_from(value, from_value)
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     414                 # Python 3
#     415                 try:
# --> 416                     httplib_response = conn.getresponse()
#     417                 except BaseException as e:
#     418                     # Remove the TypeError from the exception chain in
#
# /usr/lib/python3.8/http/client.py in getresponse(self)
#    1342         try:
#    1343             try:
# -> 1344                 response.begin()
#    1345             except ConnectionError:
#    1346                 self.close()
#
# /usr/lib/python3.8/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# /usr/lib/python3.8/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# /usr/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# KeyboardInterrupt:
