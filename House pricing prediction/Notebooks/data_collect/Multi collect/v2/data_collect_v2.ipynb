# %%
from bs4 import BeautifulSoup
from urllib.error import HTTPError
import urllib.request
import requests
import pandas as pd
import re
import csv

def crawl_page(link=''):
    # req = urllib.request.Request(
    #         link, 
    #         data=None, 
    #         headers={
    #             'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
    #             'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.79 Safari/537.36 Edge/14.14393'
    #         }
    # )
    # try:
    #     page= urllib.request.urlopen(req)
    #     return_code= page.getcode()
    #     soup_page= BeautifulSoup(page,'html.parser')
    #     return {'page':soup_page, 'status': return_code}
    # except HTTPError as err:
    #     if err.code == 404:
    #         return_code=404
    #         return {'page':'no page', 'status': return_code}
    #     else:
    #         raise
    try:
        response = requests.get(
            url='http://api.scraperapi.com', #scrapeapi
            params={
                'api_key': '56fa8295856477d20660fa8c5dcd2638',
                'url': link,  
            },
            
        )
        return_code= 200
        soup_page= BeautifulSoup(response.content,'html.parser')
        return {'page':soup_page, 'status': return_code}
    except requests.exceptions.HTTPError as err:
        if err.response.status_code == 404:
            return_code=404
            return {'page':'no page', 'status': return_code}
    

def write_csv(line=[], file=''):
    with open(file, 'a', newline='') as csvfile:
        spamwriter = csv.writer(csvfile, delimiter=' ',
                                quotechar='|', quoting=csv.QUOTE_MINIMAL)
        spamwriter.writerow(line)

def remove_row_csv():
    with open('temp_27.csv') as inp:
        for link in csv.reader(inp):
            count=0
            temp=link
            with open('used_estate.txt') as out:
                for estate in csv.reader(out):
                    if re.match("(.*)/"+estate[0],temp[1]) is not None:
                        count+=1
            if count==0:
                new_row= [link[0]+','+link[1]]
                write_csv(new_row,"temp_28.csv")

def create_urls(file=''):
    with open(file) as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')
        line_count = 1
        for row in csv_reader:
            new_row= [str(line_count)+','+row[0]]
            write_csv(new_row,'property_url_v2.csv')
            line_count+=1

# %%
class DataCollect():
    def __init__(self):
        self.__url_to_open='https://www.property24.com'
        self.__soup=crawl_page(self.__url_to_open)['page']
        self.__area_url=[]
        self.__list_url=[]
        self.__urls=pd.read_csv("temp_60_v2.csv",usecols= ['id','url']) 
    
    def collect_all_first_page_url(self):
        other_links= self.__soup.find('div',class_='p24_popular').find(class_='col-8').find_all('a',class_='p24_bold')
        for link in other_links:
            self.__area_url.append(self.__url_to_open+link.get('href'))
        first_element_tag= self.__soup.find('div',class_='p24_popular').find(class_='col-8').find_all(class_='row')[1]
        first_link=first_element_tag.find('a').get('href')
        temp_soup= crawl_page(self.__url_to_open+first_link)['page']
        parent_link= temp_soup.find(id='breadCrumbContainer').find_all('a')[1]
        self.__area_url.append(self.__url_to_open+parent_link.get('href'))
    
    def collect_all_url(self):
        self.collect_all_first_page_url()
        for link in self.__area_url:
            soup= crawl_page(link)['page']
            link_house_tag= soup.find('ul',class_='p24_relatedSales').find(href=re.compile("houses-for-sale")).get('href')
            link_apart_tag= soup.find('ul',class_='p24_relatedSales').find(href=re.compile("apartments-for-sale")).get('href')
            link_townhouse_tag= soup.find('ul',class_='p24_relatedSales').find(href=re.compile("townhouses-for-sale")).get('href')
            self.__list_url.append(link_house_tag)
            self.__list_url.append(link_apart_tag)
            self.__list_url.append(link_townhouse_tag)

    def get_property_data(self, link=''):
        data={}

        estate_id= link.split('/')[-1].split('?')[0]

        prop_soup_element= crawl_page(self.__url_to_open+link)

        
        if prop_soup_element['status'] !=200:
            print('heres')
            return False
        
        prop_soup= prop_soup_element['page']

        if prop_soup is None:
            print('here')
            return False

        #check if page not found
        check_page_not_found_msg= prop_soup.select_one('.p24_not_found')
        if check_page_not_found_msg is not None:
            print("====> Page not found !!")
            return False
        
        #check page expired
        check_page_expired = prop_soup.select_one('.p24_results.p24_expired')
        if check_page_expired is not None:
            print("====> Page expired !!")
            return False
        

        name= prop_soup.find('div',class_='p24_listingFeaturesWrapper').find('h1').get_text()
        data['name']=name

        price= prop_soup.find('div',class_='p24_listingFeaturesWrapper').find('div',class_="p24_price").get_text()
        data['price']=price

        province= link.split('/')[4]
        data['province']=province

        city= link.split('/')[3]
        data['city']=city


        is_adress= len(prop_soup.find('div',class_='p24_listingFeaturesWrapper').find_all('div',class_="p24_mBM")) >= 3
        if is_adress:
            if len(prop_soup.find('div',class_='p24_listingFeaturesWrapper').find_all('div',class_="p24_mBM")) == 3:
                index=-1
            else:
                index=3
            address= prop_soup.find('div',class_='p24_listingFeaturesWrapper').find_all('div',class_="p24_mBM")[index].get_text()
            data['address']=address
        else:
            address=  prop_soup.select_one('.p24_addressPropOverview').get_text()
            data['address']=address

        #property overview
        if type(prop_soup.select_one('.p24_propertyOverview')) is not None:
            prop_overview_panel= prop_soup.find('div',class_='p24_propertyOverview').find('div',class_='panel-body')
            prop_overview_row= prop_overview_panel.find_all('div',class_='p24_propertyOverviewRow')
            for prop in prop_overview_row:
                key= prop.find('div',class_='p24_propertyOverviewKey').get_text()
                # value= prop.select_one('.noPadding > .p24_info').get_text()
                value= prop.find('div',class_='noPadding').contents[1].get_text()
                data[key]=value

        #rooms
        rooms_panel=prop_soup.select_one('#js_accordion_rooms')
        if rooms_panel is not None:
            prop_overview_row= rooms_panel.find_all('div',class_='p24_propertyOverviewRow')
            for prop in prop_overview_row:
                key= prop.find('div',class_='p24_propertyOverviewKey').get_text()
                # value= prop.select_one('.noPadding > .p24_info').get_text()
                value= prop.find('div',class_='noPadding').contents[1].get_text()
                data[key]=value

        #external_features
        external_features_panel=prop_soup.select_one('#js_accordion_externalfeatures')
        if external_features_panel is not None:
            prop_overview_row= external_features_panel.find_all('div',class_='p24_propertyOverviewRow')
            for prop in prop_overview_row:
                key= prop.find('div',class_='p24_propertyOverviewKey').get_text()
                # value= prop.select_one('.noPadding > .p24_info').get_text()
                value= prop.find('div',class_='noPadding').contents[1].get_text()
                data[key]=value
        
        #other_features
        other_features_panel=prop_soup.select_one('#js_accordion_otherfeatures')
        if other_features_panel is not None:
            prop_overview_row= other_features_panel.find_all('div',class_='p24_propertyOverviewRow')
            for prop in prop_overview_row:
                key= prop.find('div',class_='p24_propertyOverviewKey').get_text()
                # value= prop.select_one('.noPadding > .p24_info').get_text()
                value= prop.find('div',class_='noPadding').contents[1].get_text()
                data[key]=value

        #building_features
        building_features_panel=prop_soup.select_one('#js_accordion_building')
        if building_features_panel is not None:
            prop_overview_row= building_features_panel.find_all('div',class_='p24_propertyOverviewRow')
            for prop in prop_overview_row:
                key= prop.find('div',class_='p24_propertyOverviewKey').get_text()
                # value= prop.select_one('.noPadding > .p24_info').get_text()
                value= prop.find('div',class_='noPadding').contents[1].get_text()
                data[key]=value

        #points_interest
        interest_soup= crawl_page(self.__url_to_open+'/ListingReadOnly/PointsOfInterestForListing?ListingNumber=P24-'+estate_id)
        # points_interest_panel=prop_soup.select_one('#accordian-points-of-interest')
        # print(points_interest_panel)
        if interest_soup['status'] == 200:
            categories= interest_soup['page'].select('.js_P24_POICategory')
            for cat in categories:
                interest= cat.select_one('.row > .col-6 > .p24_semibold')
                distances= cat.select('.row > .col-6.noPadding.p24_semibold')
                dist_tab=[]
                for dist in distances:
                    dist_tab.append(dist.get_text())
                data[interest.get_text()]=dist_tab

        print(str(data))
        write_csv([str(data)],'data_property_v2.csv')

        
        return True

    def crawl_property_per_page(self,city,page,number_properties):
        link=self.__url_to_open+city+'/p'+str(page)
        print('==>Page link: ',link)
        cur_soup= crawl_page(link)['page']
        properties= cur_soup.find_all('div',class_='js_resultTile')
        for prop_index in range(len(properties)-1):
            prop_link= properties[prop_index].find('a').get('href')
            write_csv([prop_link],'data_property_url.csv')

        number_properties+= len(properties)
        return number_properties

    def crawl_property_per_city(self,city,cur_page):
        soup= crawl_page(self.__url_to_open+city)['page']
        pagination= soup.find('div',class_='p24_pager').find_all('li')[-1].find('a').get('data-pagenumber')
        page_number= int(pagination)
        number_properties=0
        print("City url: ",city)
        for page in range(cur_page, page_number+1):
            print("=>Page number: ",page)
            number_properties = self.crawl_property_per_page(city,page,number_properties)
        print(number_properties)
    
    def crawl_properties(self):
        #shuffle
        self.__urls = self.__urls.sample(frac = 1).reset_index(drop=True)
        for i in range(self.__urls.size):
            prop_link= self.__urls.iloc[i]['url']
            
            print('==>Property link: ', prop_link)
            check_property_crawl = self.get_property_data(prop_link)
            if check_property_crawl:
                self.__urls= self.__urls.drop(self.__urls.index[i])
                self.__urls.to_csv('temp_61_v2.csv',index=False)

    def crawl_property_url(self):
        self.__list_url=['/townhouses-for-sale/gauteng/1']
        for link in self.__list_url:
            self.crawl_property_per_city(link,1)

# %%
dc= DataCollect()
try:
    dc.crawl_properties()
except:
    dc.crawl_properties()
# Out:
# ==>Property link:  /for-sale/waterval-east/rustenburg/north-west/10619/106959002
# {'name': '2 Bedroom Apartment / Flat for Sale in Waterval East', 'price': 'R 660 000', 'province': 'north-west', 'city': 'rustenburg', 'address': '\n2 Bedroom Apartment / Flat for Sale in Waterval East\n', 'Listing Number': '106959002', 'Type of Property': 'Apartment / Flat', 'Street Address': '25A Potato Bass Street, Waterval East', 'Listing Date': '16 November 2018', 'Erf Size': '65 m²', 'Floor Size': '65 m²', 'Price per m²': 'R 10 154', 'Bedrooms': '2', 'Bedroom 1': 'Built-In Cupboards, Tiled Flooring', 'Bedroom 2': 'Built-In Cupboards, Tiled Flooring', 'Bathrooms': '1', 'Kitchen': 'Granite Tops, Open Plan, Stove, Tiled Flooring', 'Reception Rooms': '1', 'Lounge': 'Tiled Flooring', 'Other': 'Automatic Gates, Washing Line', 'Security': 'Burglar Bars, Electric Fence, Guard House, Security Complex, Security Gates', 'Food and Entertainment': ['0.47km', '0.47km', '0.52km', '1.08km', '3.59km', '3.63km', '3.82km', '4.21km', '4.63km', '4.96km'], 'Transport and Public Services': ['0.77km', '1.05km', '3.18km', '3.66km', '4.11km', '5.03km'], 'Education': ['0.97km', '2.50km', '2.75km', '2.80km', '3.27km', '3.34km', '3.47km', '3.69km', '3.99km', '4.12km', '4.14km', '4.19km', '4.39km'], 'Health': ['4.18km']}
# ==>Property link:  /for-sale/morningside/sandton/gauteng/4258/109009005
# {'name': '2 Bedroom Apartment / Flat for Sale in Morningside', 'price': 'R 2 000 000', 'province': 'gauteng', 'city': 'sandton', 'address': '\n2 Bedroom Apartment / Flat for Sale in Morningside\n', 'Listing Number': '109009005', 'Type of Property': 'Apartment / Flat', 'Street Address': ' 77 Grayston Drive, Morningside', 'Lifestyle': 'Estate, Metropolitan, Security Estate, Suburban', 'Listing Date': '20 August 2020', 'Erf Size': '114 m²', 'Floor Size': '114 m²', 'Price per m²': 'R 17 544', 'Levies': 'R 2 700', 'Rates and Taxes': 'R 1 350', 'Age': '18', 'Pets Allowed': 'No', 'Furnished': 'Yes', 'Bedrooms': '2', 'Bedroom 1': 'Main Bedroom', 'Bedroom 2': '2nd Bedroom', 'Bathrooms': '2', 'Bathroom 1': 'Ensuite', 'Bathroom 2': '2nd bath en suite', 'Kitchen': 'Kitchen', 'Lounge': 'Lounge', 'Dining Room': 'Dining', 'Entrance Hall': 'Entrance', 'Other': 'Patio', 'Garage': '2', 'Garage 1': 'Carport 1', 'Garage 2': 'Carport 2', 'Pool': 'Swimming Pool', 'Outbuildings': '2', 'Outbuilding 1': 'Clubhouse', 'Outbuilding 2': 'Gym', 'Security': 'Security', 'Nearby Public Transport': 'Bus, Train, Minibus Taxi', 'Internet Access': 'ADSL, Fibre', 'Wheelchair Accessible': 'Yes', 'Generator': 'No', 'Backup Water': 'No', 'Style': 'Modern, Open Plan, Architect-designed', 'Roof': 'Tile, Concrete, Aluminium, Waterproofing, Insulation', 'Wall': 'Brick, Plaster, Concrete', 'Window': 'Aluminium', 'Standalone Building': 'No', 'Shopping': ['0.15km', '0.15km', '0.15km', '0.17km', '0.91km', '0.96km', '1.01km'], 'Education': ['0.29km', '0.36km', '1.04km'], 'Transport and Public Services': ['0.36km', '0.92km', '0.97km', '1.02km'], 'Food and Entertainment': ['0.65km', '0.71km', '0.79km', '0.84km', '0.86km', '0.89km', '0.93km', '0.96km', '0.97km', '0.99km', '1.00km', '1.01km', '1.02km', '1.03km', '1.04km'], 'Sports and Leisure': ['0.99km']}
# ==>Property link:  /for-sale/summer-greens/milnerton/western-cape/8073/110234380
# {'name': '2 Bedroom Townhouse for Sale in Summer Greens', 'price': 'R 980 000', 'province': 'western-cape', 'city': 'milnerton', 'address': 'Summer Greens, Milnerton', 'Listing Number': '110234380', 'Type of Property': 'Townhouse', 'Description': 'Double Storey, Duplex', 'Listing Date': '26 July 2021', 'Erf Size': '90 m²', 'Floor Size': '70 m²', 'Rates and Taxes': 'R 242', 'Pets Allowed': 'Yes', 'Bedrooms': '2', 'Bathrooms': '1', 'Kitchen': '1', 'Lounge': '1', 'Parking': '2', 'Food and Entertainment': ['0.65km', '1.57km', '1.91km', '1.91km', '1.91km', '1.91km', '1.92km', '1.92km', '1.93km', '1.93km', '1.95km', '1.96km', '1.96km', '1.96km', '1.96km', '1.97km', '1.97km', '1.98km'], 'Education': ['0.74km', '0.96km', '1.64km', '1.88km'], 'Transport and Public Services': ['1.21km', '1.42km', '1.60km', '1.62km', '1.83km'], 'Shopping': ['1.69km'], 'Sports and Leisure': ['1.92km', '1.98km']}
# ==>Property link:  /for-sale/waterval-east/rustenburg/north-west/10619/106516220
# {'name': '3 Bedroom Townhouse for Sale in Waterval East', 'price': 'R 960 000', 'province': 'north-west', 'city': 'rustenburg', 'address': 'Waterval East, Rustenburg', 'Listing Number': '106516220', 'Type of Property': 'Townhouse', 'Listing Date': '09 July 2018', 'Bedrooms': '3', 'Bathrooms': '2', 'Kitchens': '1', 'Family/TV Rooms': '1', 'Other': 'Patio', 'Garage': '2', 'Gardens': '1', 'Food and Entertainment': ['0.66km', '0.69km', '0.74km', '0.75km', '4.06km', '4.10km', '4.31km', '4.69km', '4.91km', '5.44km'], 'Transport and Public Services': ['0.70km', '1.24km', '3.68km', '4.14km', '4.60km'], 'Education': ['1.18km', '2.94km', '3.11km', '3.23km', '3.70km', '3.81km', '3.94km', '3.96km', '4.31km', '4.48km', '4.56km', '4.60km', '4.88km', '5.30km'], 'Health': ['4.68km']}
# ==>Property link:  /for-sale/observatory/cape-town/western-cape/10157/110153636
# {'name': '2 Bedroom Apartment / Flat for Sale in Observatory', 'price': 'R 1 795 000', 'province': 'western-cape', 'city': 'cape-town', 'address': 'Observatory, Cape Town', 'Listing Number': '110153636', 'Type of Property': 'Apartment / Flat', 'Listing Date': '01 July 2021', 'Floor Size': '59 m²', 'Price per m²': 'R 30 424', 'Floor Number': '8', 'Bedrooms': '2', 'Bedroom 1': 'Curtain Rails, Built-in Cupboards, Double Bed, Queen Bed, Single Bed, Twin Bed, Vinyl Floors', 'Bedroom 2': 'Curtain Rails, Built-in Cupboards, Double Bed, King Bed, Queen Bed, Single Bed, Twin Bed, Vinyl Floors', 'Bathrooms': '2', 'Bathroom 1': 'Basin, Common Toilet, Shower, Shower, Toilet and Basin, Toilet, Vinyl Floors', 'Bathroom 2': 'Basin, Main en Suite, Common Toilet, Shower, En suite, Shower, Toilet and Basin, Toilet, Vinyl Floors', 'Kitchen': 'Stove (Oven & Hob), Extractor Fan, Dishwasher Connection, Granite Tops, Curtain Rails, Open Plan, Built-in Cupboards, Under Counter Oven, Hob, Vinyl Floors', 'Other': 'Balcony', 'Parking': '2', 'Parking 1': 'Secure Parking, Single, Underground', 'Parking 2': 'Secure Parking, Single, Underground', 'Outbuilding': 'Storeroom', 'Common Toilets': '2', 'Security': 'Partially Fenced, Security Gate, 24 Hour Response, Intercom, Closed Circuit TV, 24 Hour Access, Guard House, Guard', 'Nearby Public Transport': 'Bus, Train, Minibus Taxi', 'Internet Access': 'Fibre', 'Style': 'Contemporary, Modern, Open Plan', 'Wall': 'Brick, Face-brick', 'Window': 'Aluminium', 'Standalone Building': 'No', 'Number of floors': '9', 'Transport and Public Services': ['0.02km', '0.19km', '0.65km', '0.95km', '0.97km', '1.20km', '1.27km', '1.34km'], 'Food and Entertainment': ['0.19km', '0.22km', '0.22km', '0.24km', '0.24km', '0.25km', '0.27km', '0.29km', '0.57km', '0.94km'], 'Shopping': ['0.35km'], 'Education': ['0.36km', '0.69km', '0.84km', '0.85km', '0.92km', '1.02km', '1.13km', '1.15km', '1.19km'], 'Health': ['0.86km', '1.32km']}
# ==>Property link:  /for-sale/cashan/rustenburg/north-west/3132/107973162
# {'name': '15 Bedroom House for Sale in Cashan', 'price': 'R 13 130 000', 'province': 'north-west', 'city': 'rustenburg', 'address': 'Cashan, Rustenburg', 'Listing Number': '107973162', 'Type of Property': 'House', 'Listing Date': '24 September 2019', 'Erf Size': '1 476 m²', 'Rates and Taxes': 'R 3 000', 'Bedrooms': '15', 'Bathroom': 'Basin, Bath, Shower, Tiled Flooring, Toilet', 'Kitchen': 'Eye-Level Oven, Gas, Granite Tops, Hob, Open Plan, Tiled Flooring, Wood Kitchen', 'Office/study': 'Tiled Flooring', 'Reception Rooms': '4', 'Dining Room': 'Open Plan, Tiled Flooring', 'Family/TV Room': 'Open Plan, Tiled Flooring', 'Entrance Hall': 'Tiled Flooring', 'Other': '2', 'Other 1': 'Backup Generator, Patio, Washing Line, Water Feature, Water Tank, Wooden Deck', 'Other 2': 'Tiled Flooring', 'Parking': '3 Covered 10 Off Street ', 'Secure Parking': '13', 'Garden': 'Garden', 'Pool': 'Chlorine', 'Security': 'Burglar Bars, Security Gates', 'Food and Entertainment': ['1.18km', '1.72km', '1.72km', '1.74km', '4.14km', '4.54km', '4.58km', '5.04km', '5.16km'], 'Transport and Public Services': ['1.22km', '2.32km', '4.63km', '4.69km'], 'Education': ['1.58km', '2.74km', '3.16km', '3.19km', '3.30km', '3.85km', '3.86km', '4.25km', '4.27km', '4.30km', '4.62km', '5.13km', '5.45km', '5.58km', '5.60km'], 'Sports and Leisure': ['5.12km', '5.50km']}
# ==>Property link:  /for-sale/sandton-central/sandton/gauteng/16732/110171589
# {'name': '1 Bedroom Apartment / Flat for Sale in Sandton Central', 'price': 'R 3 200 000', 'province': 'gauteng', 'city': 'sandton', 'address': '\n1 Bedroom Apartment / Flat for Sale in Sandton Central\n', 'Listing Number': '110171589', 'Type of Property': 'Apartment / Flat', 'Street Address': ' The DaVinci on the Nelson Mandela Square , Sandton Central', 'Listing Date': '07 July 2021', 'Levies': 'R 4 500', 'Rates and Taxes': 'R 2 500', 'Bedrooms': '1', 'Bathrooms': '2', 'Kitchens': '1', 'Office/studies': '1', 'Family/TV Rooms': '1', 'Braai Rooms': '1', 'Entrance Halls': '1', 'Garage': '2', 'Parking': '2', 'Gardens': '1', 'Nearby Public Transport': 'Bus, Train, Minibus Taxi', 'Internet Access': 'Fibre', 'Wheelchair Accessible': 'Yes', 'Generator': 'Yes', 'Backup Water': 'Yes', 'Shopping': ['0.07km', '0.10km', '0.13km', '0.71km', '0.92km'], 'Food and Entertainment': ['0.08km', '0.10km', '0.11km', '0.11km', '0.12km', '0.16km', '0.17km', '0.18km', '0.21km', '0.23km', '0.24km', '0.26km', '0.27km', '0.66km', '0.66km', '0.68km', '0.69km', '0.70km', '0.78km'], 'Sports and Leisure': ['0.11km'], 'Transport and Public Services': ['0.19km', '0.27km', '0.34km', '0.35km', '0.84km']}
# ==>Property link:  /for-sale/morningside/sandton/gauteng/4258/109700288
# {'name': '5 Bedroom House for Sale in Morningside', 'price': 'R 19 775 000', 'province': 'gauteng', 'city': 'sandton', 'address': '\n5 Bedroom House for Sale in Morningside\n', 'Listing Number': '109700288', 'Type of Property': 'House', 'Street Address': ' 306 Redhill Road, Morningside', 'Description': 'Double Storey, Freestanding, New Development', 'Lifestyle': 'Security Estate', 'Listing Date': '02 March 2021', 'Erf Size': '1 700 m²', 'Floor Size': '950 m²', 'Pets Allowed': 'Yes', 'Coverage': '55 %', 'Bedrooms': '5', 'Bedroom 1': 'Bedroom 4: Spacious and opening onto spacious balcony ', 'Bedroom 2': 'Bedroom 5: Guest Bedroom downstairs with pivate deck area /garden', 'Bedroom 3': 'Bedroom 3: Spacious and opening onto spacious balcony ', 'Bedroom 4': 'Bedroom 2: Spacious and opening onto spacious balcony ', 'Bedroom 5': 'Main Bedroom: spacious balcony - large dresing room - spacious full bathroom - high quality finishes ', 'Bathrooms': '5.5', 'Bathroom 1': 'Full, Main en Suite, Bath, Shower, Double Basin, En suite, Toilet', 'Bathroom 2': 'Full, Basin, Bath, Shower, Toilet', 'Bathroom 3': 'Full, Basin, Bath, Shower, Toilet', 'Bathroom 4': 'Full, Basin, Bath, En suite, Toilet', 'Bathroom 5': 'Full, Basin, Bath, Shower, En suite, Toilet', 'Bathroom 6': 'Guest Toilet', 'Kitchen': 'Kitchen : Open plan Kitchen with separate wine cellar and centre island leading onto Family Tv lounge area and dinning room ', 'Office/study': 'Internet Port', 'Domestic Rooms': '1', 'Domestic Bathrooms': '1', 'Lounges': '2', 'Lounge 1': 'Internet Port, TV Port', 'Lounge 2': 'Pyjama Lounge: open plan with separate study area upstairs', 'Dining Room': 'Dining room: leading onto kitchen, family Tv lounge and entertainment area or covered patio', 'Family/TV Room': 'Internet Port, TV Port', 'Entrance Hall': 'Spacious', 'Other': '2', 'Other 1': 'Separate Scullery', 'Other 2': 'Bar area on covered patio overlooking the pool, garden and formal lounge', 'Garage': '4', 'Garage 1': 'Roll up, Covered', 'Garage 2': 'Roll up, Covered', 'Garage 3': 'Roll up, Covered', 'Garage 4': 'Roll up, Covered', 'Gardens': '2', 'Pool': 'Sparkling Rim Flow/ Infinity  Swimming Pool ', 'Outbuildings': '2', 'Outbuilding 1': 'Two Staff Rooms en suite - separate entrance - kitchenette - shared lounge area', 'Outbuilding 2': '2 En Suite Staff Bathrooms', 'Security': 'Secure Estate', 'Special Features': 'Smart Home Automation', 'Nearby Public Transport': 'Bus, Minibus Taxi', 'Internet Access': 'Fibre', 'Style': 'Contemporary, Architect-designed', 'Facing': 'North', 'Food and Entertainment': ['0.03km', '0.06km', '0.08km', '0.08km', '0.09km', '0.93km', '0.95km', '0.95km', '0.95km', '0.96km', '1.01km', '1.33km', '1.34km', '1.34km', '1.35km'], 'Shopping': ['0.04km', '0.07km', '0.90km', '0.94km'], 'Transport and Public Services': ['0.31km', '0.36km', '1.00km', '1.12km', '1.28km'], 'Education': ['0.59km', '0.72km', '1.18km', '1.28km'], 'Health': ['0.91km'], 'Sports and Leisure': ['0.92km']}
# ==>Property link:  /for-sale/bellevue/johannesburg/gauteng/5917/109329386
# {'name': '4 Bedroom Apartment / Flat for Sale in Bellevue', 'price': 'R 600 000', 'province': 'gauteng', 'city': 'johannesburg', 'address': 'Bellevue, Johannesburg', 'Listing Number': '109329386', 'Type of Property': 'Apartment / Flat', 'Listing Date': '09 November 2020', 'Pets Allowed': 'No', 'Bedrooms': '4', 'Bathrooms': '2', 'Kitchens': '1', 'Lounges': '1', 'Garage': '1', 'Education': ['0.39km', '0.45km', '0.53km', '0.55km', '0.65km', '0.74km', '0.81km', '0.93km', '0.96km', '0.97km', '1.03km', '1.04km', '1.06km', '1.07km', '1.09km', '1.27km', '1.36km', '1.45km', '1.59km', '1.70km', '1.70km', '1.74km', '1.74km', '1.86km', '1.87km'], 'Transport and Public Services': ['1.63km'], 'Food and Entertainment': ['1.79km', '1.82km', '1.83km'], 'Sports and Leisure': ['1.91km']}
# ==>Property link:  /for-sale/ezibeleni/queenstown/eastern-cape/6711/108811934
# {'name': '3 Bedroom House for Sale in Ezibeleni', 'price': 'R 420 000', 'province': 'eastern-cape', 'city': 'queenstown', 'address': '\n3 Bedroom House for Sale in Ezibeleni\n', 'Listing Number': '108811934', 'Type of Property': 'House', 'Street Address': ' 1499 Zone 1 Ezibeleni, 5326, Ezibeleni', 'Description': 'Freestanding', 'Lifestyle': 'Suburban', 'Listing Date': '29 June 2020', 'Erf Size': '450 m²', 'Pets Allowed': 'Yes', 'Bedrooms': '3', 'Bedroom 1': 'Tiled Floors, Curtain Rails', 'Bedroom 2': 'Tiled Floors, Curtain Rails', 'Bedroom 3': 'Tiled Floors, Curtain Rails', 'Bathroom': 'Tiled Floors, Curtain Rails, Bath, Toilet and Basin', 'Kitchen': 'Tiled Floors, Curtain Rails', 'Lounge': 'Tiled Floors, Curtain Rails', 'Garage': 'Roll up, Covered', 'Parking': 'Secure Parking', 'Gardens': '1', 'Security': 'Totally Fenced, Security Gate', 'Special Featuress': '1', 'Nearby Public Transport': 'Bus, Minibus Taxi', 'Wheelchair Accessible': 'No', 'Generator': 'No', 'Backup Water': 'No', 'Style': 'Traditional', 'Facing': 'East, Above Road', 'Roof': 'Zinc', 'Wall': 'Brick, Plaster', 'Window': 'Steel , Aluminium', 'Standalone Building': 'Yes', 'Education': ['0.32km', '0.45km', '0.46km', '0.65km', '0.74km', '0.74km', '0.82km', '0.83km', '0.89km', '1.18km', '1.19km', '1.24km', '1.31km', '4.02km', '4.34km', '4.77km', '6.62km', '7.15km', '7.15km', '7.29km'], 'Transport and Public Services': ['3.05km', '5.95km', '6.49km', '6.78km', '6.98km', '7.06km', '7.32km'], 'Sports and Leisure': ['6.76km', '7.31km'], 'Food and Entertainment': ['6.95km']}
# ==>Property link:  /for-sale/cullinan/cullinan/gauteng/16724/110187531
# {'name': '2 Bedroom Townhouse for Sale in Cullinan', 'price': 'R 990 000', 'province': 'gauteng', 'city': 'cullinan', 'address': 'Cullinan', 'Listing Number': '110187531', 'Type of Property': 'Townhouse', 'Listing Date': '12 July 2021', 'Floor Size': '104 m²', 'Levies': 'R 1 202', 'Rates and Taxes': 'R 700', 'Pets Allowed': 'No', 'Bedrooms': '2', 'Bathrooms': '2', 'Kitchen': 'Open Plan, Stove, Gas Hob, Vinyl Floors', 'Lounges': '1', 'Other': 'Patio', 'Parking': '2', 'Outbuilding': 'Golf Course', 'Special Features': 'Built in Braai', 'Education': ['0.30km', '2.97km', '3.49km', '3.91km', '7.84km', '7.89km', '10.53km', '11.00km'], 'Transport and Public Services': ['0.51km', '0.60km', '0.73km', '0.76km', '0.83km', '1.00km', '2.26km', '6.19km', '6.43km', '7.13km', '7.55km', '7.80km', '8.09km', '8.17km', '11.97km'], 'Sports and Leisure': ['5.57km']}
# ==>Property link:  /for-sale/menlyn/pretoria/gauteng/3957/110159285
# ====> Page not found !!
# ==>Property link:  /for-sale/danville/pretoria/gauteng/2906/110093184
# ====> Page expired !!
# ==>Property link:  /for-sale/westenburg/polokwane/limpopo/11389/110112226
# {'name': '3 Bedroom House for Sale in Westenburg', 'price': 'R 760 000', 'province': 'limpopo', 'city': 'polokwane', 'address': 'Westenburg, Polokwane', 'Listing Number': '110112226', 'Type of Property': 'House', 'Listing Date': '21 June 2021', 'Erf Size': '325 m²', 'Bedrooms': '3', 'Bedroom 1': 'Tiled Floors, Curtain Rails, Fan, Built-in Cupboards, King Bed', 'Bedroom 2': 'Tiled Floors, Curtain Rails, Fan, Built-in Cupboards, King Bed', 'Bedroom 3': 'Tiled Floors, Curtain Rails, Fan, Built-in Cupboards, Queen Bed', 'Bathroom': 'Tiled Floors, Full, Blinds, Bath, Toilet and Basin', 'Kitchen': 'Breakfast Nook, Stove, Tiled Floors, Blinds, Open Plan, Built-in Cupboards', 'Lounge': 'Tiled Floors, Curtain Rails, Fan, TV Port, Open Plan', 'Garage': 'Double, Covered', 'Parking': 'Carport, Secure Parking, Double', 'Garden': 'Garden Services', 'Security': 'Totally Fenced, Safe', 'Nearby Public Transport': 'Bus, Minibus Taxi', 'Wheelchair Accessible': 'Yes', 'Education': ['0.16km', '0.39km', '0.81km', '1.27km', '1.81km', '1.93km', '2.21km', '2.50km', '2.52km', '2.52km', '2.52km', '2.54km', '2.89km', '2.91km', '3.07km', '3.23km', '3.28km', '3.63km', '3.66km', '3.69km', '3.75km', '3.83km', '4.28km', '4.33km', '4.82km', '5.20km', '5.35km', '5.41km'], 'Transport and Public Services': ['2.74km', '2.77km']}
# ==>Property link:  /for-sale/cashan/rustenburg/north-west/3132/109722667
# {'name': '3 Bedroom Townhouse for Sale in Cashan', 'price': 'R 1 100 000', 'province': 'north-west', 'city': 'rustenburg', 'address': 'Cashan, Rustenburg', 'Listing Number': '109722667', 'Type of Property': 'Townhouse', 'Listing Date': '08 March 2021', 'Erf Size': '336 m²', 'Bedrooms': '3', 'Bedroom 1': 'Built-In Cupboards, Tiled Flooring', 'Bedroom 2': 'Built-In Cupboards, Tiled Flooring', 'Bedroom 3': 'Built-In Cupboards, Tiled Flooring', 'Bathrooms': '2', 'Bathroom 1': 'Basin, Bath, Shower, Tiled Flooring, Toilet', 'Bathroom 2': 'Basin, Bath, Tiled Flooring, Toilet', 'Kitchen': 'Extractor Fan, Hob, Melamine Kitchen, Tiled Flooring, Under Counter Oven', 'Reception Rooms': '2', 'Family/TV Room': 'Open Plan', 'Other': 'Automatic Gates, Braai, Washing Line', 'Garage': '2', 'Parking': '2 Garage(s) ', 'Garden': 'Garden', 'Security': 'Alarm, Security Gates', 'Food and Entertainment': ['1.18km', '1.72km', '1.72km', '1.74km', '4.14km', '4.54km', '4.58km', '5.04km', '5.16km'], 'Transport and Public Services': ['1.22km', '2.32km', '4.63km', '4.69km'], 'Education': ['1.58km', '2.74km', '3.16km', '3.19km', '3.30km', '3.85km', '3.86km', '4.25km', '4.27km', '4.30km', '4.62km', '5.13km', '5.45km', '5.58km', '5.60km'], 'Sports and Leisure': ['5.12km', '5.50km']}
# ==>Property link:  /for-sale/kidds-beach/east-london/eastern-cape/6674/109720003
# ====> Page expired !!
# ==>Property link:  /for-sale/retreat/cape-town/western-cape/9034/109786591
# ====> Page expired !!
# ==>Property link:  /for-sale/chartwell/randburg/gauteng/4424/109665290
# {'name': '5 Bedroom House for Sale in Chartwell', 'price': 'R 3 250 000', 'province': 'gauteng', 'city': 'randburg', 'address': 'Chartwell, Randburg', 'Listing Number': '109665290', 'Type of Property': 'House', 'Listing Date': '22 February 2021', 'Erf Size': '8 566 m²', 'Bedrooms': '5', 'Bedroom 1': ' ', 'Bedroom 2': ' ', 'Bedroom 3': ' ', 'Bedroom 4': ' ', 'Bedroom 5': ' ', 'Bathrooms': '2', 'Kitchen': ' ', 'Lounge': ' ', 'Dining Room': ' ', 'Garage': '2', 'Garage 1': ' ', 'Garage 2': ' ', 'Parking': '4', 'Transport and Public Services': ['1.20km', '1.47km', '3.55km'], 'Food and Entertainment': ['1.32km', '1.47km', '2.24km', '3.50km', '3.52km', '3.52km', '3.53km', '3.62km', '3.63km', '3.66km', '3.71km'], 'Health': ['1.36km', '3.06km', '3.12km', '3.65km'], 'Shopping': ['1.36km', '3.53km', '3.53km', '3.53km', '3.67km'], 'Education': ['1.40km', '2.11km', '2.14km', '3.56km', '3.57km'], 'Sports and Leisure': ['1.71km', '3.68km']}
# ==>Property link:  /for-sale/helderwyk/brakpan/gauteng/12637/108859165
# {'name': '3 Bedroom House for Sale in Helderwyk', 'price': 'R 4 300 000', 'province': 'gauteng', 'city': 'brakpan', 'address': 'Helderwyk, Brakpan', 'Listing Number': '108859165', 'Type of Property': 'House', 'Listing Date': '10 July 2020', 'Erf Size': '978 m²', 'Levies': 'R 1 820', 'Rates and Taxes': 'R 3 210', 'Bedrooms': '3', 'Bedroom 1': 'used for gym now', 'Bedroom 2': 'Curtain Rails, TV Port, Built-in Cupboards, King Bed, Laminated Floors', 'Bedroom 3': 'Air Conditioner, TV Port, Walk-in-closet, King Bed, Laminated Floors', 'Bathrooms': '3.5', 'Bathroom 1': 'Under Floor Heating, Tiled Floors, Full, En suite', 'Bathroom 2': 'Steam room', 'Bathroom 3': 'Tiled Floors, Basin, Guest Toilet', 'Bathroom 4': 'Under Floor Heating, Tiled Floors, Separate Toilet, Main en Suite, Bath, Shower, Double Basin', 'Kitchen': 'Open Plan, Eye Level Oven, Dishwasher Connection, Washing Machine Connection, Tiled Floors, Tumble Dryer, Centre Island, Gas Hob', 'Office/study': 'Under floor heating', 'Domestic Rooms': '1', 'Domestic Bathrooms': '1', 'Lounge': 'Tiled Floors, Curtain Rails, TV Port, Fireplace', 'Dining Room': 'Tiled Floors, Curtain Rails', 'Other': 'Message Room- indoor Pool', 'Garage': '4', 'Garage 1': 'Double, Electric Door, Tandem', 'Garage 2': 'Double, Electric Door, Tandem', 'Garage 3': 'Double, Electric Door, Tandem', 'Garage 4': 'Double, Electric Door, Tandem', 'Garden': 'Landscaped, Water Feature', 'Pool': 'Heated, Auto Cleaning Equipment', 'Outbuilding': 'Staff Quarters/Domestic Rooms, Domestic Bathroom', 'Security': 'Totally Fenced, Electric Garage, Electric Gate, 24 Hour Access, Guard House, Guard, Electric fencing, Safe', 'Temperature Control': 'Air Conditioning Unit, Solar Heating, Fireplace, Under Floor Heating', 'Special Features': 'Built in Braai, Satellite Dish, Driveway, Paveway, Open Plan, Sliding Doors, Special Doors, Totally Walled, Central Vacuum System', 'Generator': 'Yes', 'Education': ['0.56km', '2.39km', '2.51km', '3.39km', '3.53km', '3.56km', '4.19km', '4.46km', '4.48km', '4.77km', '4.84km', '4.95km', '4.96km', '4.98km', '5.15km', '5.51km', '5.55km', '5.70km', '5.70km', '5.72km', '5.76km', '5.85km', '5.86km'], 'Sports and Leisure': ['1.47km'], 'Transport and Public Services': ['3.28km', '3.65km', '5.66km', '5.75km'], 'Food and Entertainment': ['5.13km', '5.13km']}
# ==>Property link:  /for-sale/silver-lakes-golf-estate/pretoria/gauteng/2438/110053811
# {'name': '4 Bedroom House for Sale in Silver Lakes Golf Estate', 'price': 'R 12 325 000', 'province': 'gauteng', 'city': 'pretoria', 'address': 'Silver Lakes Golf Estate, Pretoria', 'Listing Number': '110053811', 'Type of Property': 'House', 'Listing Date': '04 June 2021', 'Erf Size': '1 955 m²', 'Floor Size': '750 m²', 'Levies': 'R 2 055', 'Rates and Taxes': 'R 4 085', 'Pets Allowed': 'Yes', 'Bedrooms': '4', 'Bathrooms': '5.5', 'Office': '1', 'Domestic Rooms': '1', 'Lounges': '3', 'Dining Rooms': '1', 'Garage': '4', 'Pool': 'Yes', 'Education': ['0.88km', '1.96km', '2.11km'], 'Food and Entertainment': ['1.25km', '1.27km', '1.29km', '1.31km', '1.34km', '1.34km', '1.35km', '1.36km', '2.29km', '2.29km', '2.29km', '2.29km', '2.31km', '2.41km', '2.44km', '2.65km'], 'Health': ['1.27km', '2.27km'], 'Shopping': ['1.31km', '1.33km', '2.25km', '2.30km', '2.31km'], 'Sports and Leisure': ['1.81km'], 'Transport and Public Services': ['2.42km', '2.50km', '2.63km']}
# ==>Property link:  /for-sale/orange-farm/evaton/gauteng/3738/110202652
# {'name': '2 Bedroom House for Sale in Orange Farm', 'price': 'R 185 000', 'province': 'gauteng', 'city': 'evaton', 'address': 'Orange Farm, Evaton', 'Listing Number': '110202652', 'Type of Property': 'House', 'Listing Date': '16 July 2021', 'Bedrooms': '2', 'Bathrooms': '1', 'Kitchens': '1', 'Education': ['0.61km', '0.69km', '0.75km', '0.76km', '0.80km', '0.82km', '1.08km', '1.21km', '1.30km', '1.44km', '1.71km', '1.72km', '1.83km', '2.01km', '2.16km', '2.29km', '2.39km', '2.43km', '2.54km', '2.58km', '2.71km', '2.87km', '2.88km', '2.96km', '3.02km', '3.16km', '3.22km', '3.44km'], 'Transport and Public Services': ['2.37km', '2.92km']}
# ==>Property link:  /for-sale/birch-acres/kempton-park/gauteng/1272/108414257
# {'name': '4 Bedroom House for Sale in Birch Acres', 'price': 'R 1 380 000', 'province': 'gauteng', 'city': 'kempton-park', 'address': '\n4 Bedroom House for Sale in Birch Acres\n', 'Listing Number': '108414257', 'Type of Property': 'House', 'Street Address': ' 134 Kwartel Road, Birch Acres', 'Listing Date': '06 February 2020', 'Erf Size': '1 147 m²', 'Rates and Taxes': 'R 800', 'Bedrooms': '4', 'Bathrooms': '2', 'Kitchen': 'Breakfast Nook, Tiled Floors', 'Office/study': 'Wooden Floors', 'Domestic Rooms': '1', 'Garage': '2', 'Parking': '2', 'Garden': 'Landscaped', 'Pools': '1', 'Outbuilding': 'Staff Quarters/Domestic Rooms', 'Education': ['0.28km', '0.55km', '0.60km', '0.86km', '1.44km', '1.62km', '1.78km', '2.14km', '2.52km', '2.54km', '2.64km', '2.71km', '2.88km', '3.04km', '3.10km', '3.20km', '3.21km', '3.33km', '3.33km', '3.46km', '3.51km', '3.55km', '3.57km', '3.63km', '3.78km', '3.92km'], 'Transport and Public Services': ['0.47km', '2.56km', '2.84km', '3.09km']}
# ==>Property link:  /for-sale/nelspruit-ext-1/nelspruit/mpumalanga/2693/109935797
# {'name': '3 Bedroom House for Sale in Nelspruit Ext 1', 'price': 'R 2 431 075', 'province': 'mpumalanga', 'city': 'nelspruit', 'address': 'Nelspruit Ext 1, Nelspruit', 'Listing Number': '109935797', 'Type of Property': 'House', 'Listing Date': '05 May 2021', 'Erf Size': '1 693 m²', 'Floor Size': '340 m²', 'Rates and Taxes': 'R 1 700', 'Pets Allowed': 'Yes', 'Coverage': '20 %', 'Bedrooms': '3', 'Bathrooms': '2', 'Kitchens': '1', 'Office/studies': '1', 'Garage': '2', 'Parking': '8', 'Gardens': '2', 'Pools': '1', 'Security': '1', 'Special Features': 'Wendy House', 'Nearby Public Transport': 'Bus', 'Wheelchair Accessible': 'Yes', 'Generator': 'Yes', 'Standalone Building': 'Yes', 'Transport and Public Services': ['0.04km', '0.12km', '0.34km', '0.53km', '0.57km', '0.77km', '0.82km', '0.84km', '0.84km', '0.88km', '1.19km', '1.37km'], 'Food and Entertainment': ['0.14km', '0.16km', '0.28km', '0.75km', '1.38km', '1.38km', '1.39km'], 'Education': ['0.64km', '0.77km', '0.78km', '0.80km', '0.93km', '1.29km', '1.38km', '1.40km'], 'Health': ['1.07km', '1.42km'], 'Sports and Leisure': ['1.20km']}
# ==>Property link:  /for-sale/soshanguve-uu/soshanguve/gauteng/17882/109966765
# {'name': '3 Bedroom House for Sale in Soshanguve Uu', 'price': 'R 609 000', 'province': 'gauteng', 'city': 'soshanguve', 'address': '\n3 Bedroom House for Sale in Soshanguve Uu\n', 'Listing Number': '109966765', 'Type of Property': 'House', 'Street Address': ' 742 Masianoke Street, Soshanguve UU', 'Listing Date': '12 May 2021', 'Erf Size': '200 m²', 'Floor Size': '50 m²', 'No Transfer Duty': 'Yes', 'Rates and Taxes': 'R 200', 'Pets Allowed': 'Yes', 'Coverage': '25 %', 'Bedrooms': '3', 'Bathrooms': '1.5', 'Kitchens': '1', 'Lounges': '1', 'Parking': '2', 'Nearby Public Transport': 'Bus, Train, Minibus Taxi', 'Wheelchair Accessible': 'Yes', 'Backup Water': 'No', 'Standalone Building': 'Yes', 'Education': ['0.44km', '0.47km', '0.61km', '0.66km', '1.08km', '1.27km', '1.57km', '1.59km', '2.13km', '2.36km', '2.60km', '2.84km', '2.92km', '3.06km', '3.12km', '3.36km', '3.36km', '3.38km', '3.40km', '3.43km', '3.46km', '3.52km', '3.68km', '3.69km', '3.72km', '3.76km', '3.78km', '3.83km'], 'Transport and Public Services': ['1.92km', '3.06km']}
# ==>Property link:  /for-sale/zimbali-coastal-resort-and-estate/ballito/kwazulu-natal/12884/107604332
# {'name': '4 Bedroom Townhouse for Sale in Zimbali Coastal Resort & Estate', 'price': 'R 9 949 000', 'province': 'kwazulu-natal', 'city': 'ballito', 'address': 'Zimbali Coastal Resort & Estate, Ballito', 'Listing Number': '107604332', 'Type of Property': 'Townhouse', 'Listing Date': '14 June 2019', 'Erf Size': '15 959 m²', 'Floor Size': '556 m²', 'Levies': 'R 3 670', 'Rates and Taxes': 'R 5 389', 'Pets Allowed': 'No', 'Bedrooms': '4', 'Bathrooms': '4', 'Kitchens': '1', 'Office': '1', 'Lounges': '1', 'Dining Rooms': '1', 'Garage': '2.5', 'Parking': '2', 'Pool': 'Yes', 'Sports and Leisure': ['0.47km', '2.53km', '4.01km', '4.74km', '6.52km'], 'Food and Entertainment': ['1.23km', '1.49km', '1.50km', '2.59km'], 'Health': ['1.58km', '1.98km', '6.08km'], 'Education': ['1.87km', '2.47km', '2.77km', '3.52km', '4.49km', '5.63km', '6.17km', '6.25km', '6.48km'], 'Transport and Public Services': ['2.41km', '2.42km', '3.71km', '4.05km', '5.54km', '5.60km', '6.05km', '6.12km', '6.23km']}
# ==>Property link:  /for-sale/umhlanga-ridge/umhlanga/kwazulu-natal/6383/109724220
# {'name': '2 Bedroom Apartment / Flat for Sale in Umhlanga Ridge', 'price': 'R 1 900 000', 'province': 'kwazulu-natal', 'city': 'umhlanga', 'address': 'Umhlanga Ridge, Umhlanga', 'Listing Number': '109724220', 'Type of Property': 'Apartment / Flat', 'Listing Date': '08 March 2021', 'Pets Allowed': 'No', 'Bedrooms': '2', 'Bathrooms': '2', 'Lounges': '1', 'Dining Rooms': '1', 'Garage': '1', 'Parking': '1', 'Pool': 'Yes', 'Food and Entertainment': ['0.16km', '0.17km', '0.17km', '0.19km', '0.19km', '0.19km', '0.19km', '0.19km', '0.19km', '0.20km', '0.22km', '0.26km', '0.27km', '0.37km', '0.37km', '0.37km', '0.38km', '0.38km', '0.39km', '0.39km', '0.39km', '0.40km', '0.41km'], 'Shopping': ['0.17km', '0.20km', '0.22km', '0.23km', '0.23km', '0.40km'], 'Sports and Leisure': ['0.20km']}
# ==>Property link:  /for-sale/new-town-centre/umhlanga/kwazulu-natal/12141/108997868
# {'name': '1 Bedroom Apartment / Flat for Sale in New Town Centre', 'price': 'R 1 250 000', 'province': 'kwazulu-natal', 'city': 'umhlanga', 'address': 'New Town Centre, Umhlanga', 'Listing Number': '108997868', 'Type of Property': 'Apartment / Flat', 'Lifestyle': 'Security Complex', 'Listing Date': '17 August 2020', 'Erf Size': '2 352 m²', 'Floor Size': '57 m²', 'Price per m²': 'R 21 930', 'Levies': 'R 1 500', 'Rates and Taxes': 'R 750', 'Bedroom': '1', 'Bathrooms': '1', 'Kitchens': '1', 'Rooms': 'Air Conditioner', 'Parking': '1', 'Security': 'Security Gate', 'Food and Entertainment': ['0.16km', '0.17km', '0.17km', '0.19km', '0.19km', '0.19km', '0.19km', '0.19km', '0.19km', '0.20km', '0.22km', '0.26km', '0.27km', '0.37km', '0.37km', '0.37km', '0.38km', '0.38km', '0.39km', '0.39km', '0.39km', '0.40km', '0.41km'], 'Shopping': ['0.17km', '0.20km', '0.22km', '0.23km', '0.23km', '0.40km'], 'Sports and Leisure': ['0.20km']}
# ==>Property link:  /for-sale/safari-gardens/rustenburg/north-west/3188/104074635
# {'name': '2 Bedroom Townhouse for Sale in Safari Gardens', 'price': 'R 625 000', 'province': 'north-west', 'city': 'rustenburg', 'address': 'Safari Gardens, Rustenburg', 'Listing Number': '104074635', 'Type of Property': 'Townhouse', 'Listing Date': '14 July 2016', 'Floor Size': '88 m²', 'Levies': 'R 1 030', 'Bedrooms': '2', 'Bathrooms': '1', 'Kitchen': 'Open Plan, Laundry', 'Parking': 'Parking features', 'Security': 'Perimeter Wall', 'Special Feature': 'Built in Braai', 'Roof': 'Tile', 'Wall': 'Plaster', 'Floor': 'Tiled Floors', 'Education': ['1.53km', '1.68km', '1.72km', '1.75km', '2.48km', '2.76km', '2.81km', '2.91km', '3.12km', '3.42km', '3.82km', '4.12km', '4.19km', '4.51km'], 'Food and Entertainment': ['2.17km', '2.22km', '2.22km', '2.27km', '2.65km', '3.62km', '3.65km', '4.18km', '4.24km'], 'Transport and Public Services': ['2.29km', '2.42km', '3.80km', '4.05km', '4.76km'], 'Sports and Leisure': ['4.42km', '4.56km']}
# ==>Property link:  /for-sale/west-bank/oudtshoorn/western-cape/7570/109912491
# {'name': '4 Bedroom House for Sale in West Bank', 'price': 'R 3 670 000', 'province': 'western-cape', 'city': 'oudtshoorn', 'address': 'West Bank, Oudtshoorn', 'Listing Number': '109912491', 'Type of Property': 'House', 'Listing Date': '28 April 2021', 'Erf Size': '1 141 m²', 'Floor Size': '363 m²', 'Rates and Taxes': 'R 2 800', 'Pets Allowed': 'Yes', 'Bedrooms': '4', 'Bathrooms': '5', 'Kitchens': '1', 'Lounges': '2', 'Dining Rooms': '1', 'Garage': '4', 'Garden': 'Yes', 'Security': 'Alarm System', 'Flatlet': 'Yes', 'Shopping': ['0.72km'], 'Food and Entertainment': ['0.74km'], 'Education': ['0.81km', '1.14km', '1.25km', '1.27km', '1.31km', '1.35km', '1.46km', '1.67km', '2.22km', '2.32km', '2.48km', '2.56km', '2.73km', '3.10km', '3.14km', '3.37km', '4.23km', '4.48km', '4.49km', '5.60km', '6.37km', '9.04km', '9.24km', '12.64km'], 'Transport and Public Services': ['1.89km', '3.50km', '5.60km'], 'Sports and Leisure': ['3.10km']}
# ==>Property link:  /for-sale/fourways/sandton/gauteng/5811/110042701
# {'name': '3 Bedroom Apartment / Flat for Sale in Fourways', 'price': 'R 1 590 000', 'province': 'gauteng', 'city': 'sandton', 'address': '\n3 Bedroom Apartment / Flat for Sale in Fourways\n', 'Listing Number': '110042701', 'Type of Property': 'Apartment / Flat', 'Street Address': ' 1 Cedar Acres Estate 959 Inchanga Road, Fourways', 'Description': 'New Development', 'Listing Date': '01 June 2021', 'Floor Size': '125 m²', 'Price per m²': 'R 12 720', 'Levies': 'R 2 683', 'No Transfer Duty': 'Yes', 'Rates and Taxes': 'R 801', 'Bedrooms': '3', 'Bathrooms': '2', 'Lounge': '1', 'Dining Room': '1', 'Parking': 'Carport', 'Pool': 'Yes', 'Special Feature': 'Built in Braai, Tennis Court, Balcony', 'Food and Entertainment': ['1.57km', '1.90km', '1.96km', '2.25km', '2.93km', '2.97km', '2.98km', '2.99km', '3.02km', '3.06km'], 'Transport and Public Services': ['1.86km', '2.10km', '2.15km', '2.24km', '2.28km', '2.28km', '2.33km', '2.75km', '3.03km', '3.07km'], 'Health': ['2.07km', '2.10km', '2.29km'], 'Education': ['2.08km', '2.10km'], 'Shopping': ['2.30km', '3.00km', '3.01km', '3.01km', '3.09km']}
# ==>Property link:  /for-sale/grootvlei/grootvlei/mpumalanga/4901/110194731
# ====> Page not found !!
# ==>Property link:  /for-sale/uvongo/margate/kwazulu-natal/6359/109616421
# {'name': '5 Bedroom House for Sale in Uvongo', 'price': 'R 2 850 000', 'province': 'kwazulu-natal', 'city': 'margate', 'address': 'Uvongo, Margate', 'Listing Number': '109616421', 'Type of Property': 'House', 'Listing Date': '09 February 2021', 'Erf Size': '809 m²', 'Rates and Taxes': 'R 1 800', 'Pets Allowed': 'Yes', 'Bedrooms': '5', 'Bathrooms': '3', 'Kitchens': '1', 'Lounges': '1', 'Dining Rooms': '1', 'Garage': '2', 'Garden': 'Yes', 'Pool': 'Yes', 'Education': ['0.69km', '3.16km', '3.19km', '3.19km', '3.21km', '4.45km', '5.03km', '5.06km', '5.33km', '5.35km', '5.45km', '5.66km', '6.20km', '6.24km', '6.29km', '6.30km', '6.31km', '6.72km', '7.17km', '7.58km', '7.65km', '7.95km', '8.24km', '8.45km', '8.86km', '8.90km', '8.96km'], 'Transport and Public Services': ['2.24km', '4.68km'], 'Sports and Leisure': ['2.88km']}
# ==>Property link:  /for-sale/evaton-central/evaton/gauteng/16725/110116499
# {'name': 'House for Sale in Evaton Central', 'price': 'R 550 000', 'province': 'gauteng', 'city': 'evaton', 'address': 'Evaton Central, Evaton', 'Listing Number': '110116499', 'Type of Property': 'House', 'Listing Date': '21 June 2021', 'Erf Size': '4 045 m²', 'Education': ['0.46km', '0.65km', '0.82km', '1.01km', '1.27km', '1.33km', '1.42km', '1.49km', '1.56km', '1.75km', '1.86km', '1.98km', '2.01km', '2.02km', '2.22km', '2.30km', '2.32km', '2.36km', '2.40km', '2.41km', '2.41km', '2.46km', '2.47km', '2.61km', '2.82km', '2.86km', '2.87km', '2.97km', '3.08km', '3.10km']}
# ==>Property link:  /for-sale/hyde-park/sandton/gauteng/5832/110034166
# {'name': '2 Bedroom Apartment / Flat for Sale in Hyde Park', 'price': 'R 1 400 000', 'province': 'gauteng', 'city': 'sandton', 'address': 'Hyde Park, Sandton', 'Listing Number': '110034166', 'Type of Property': 'Apartment / Flat', 'Description': 'Top Floor', 'Listing Date': '31 May 2021', 'Erf Size': '89 m²', 'Floor Size': '89 m²', 'Price per m²': 'R 15 730', 'Levies': 'R 2 150', 'Rates and Taxes': 'R 1 269', 'Pets Allowed': 'No', 'Bedrooms': '2', 'Bedroom 1': ' ', 'Bedroom 2': ' ', 'Bathrooms': '2', 'Kitchen': ' ', 'Lounge': ' ', 'Dining Room': ' ', 'Braai Room': ' ', 'Garage': '2', 'Garage 1': ' ', 'Garage 2': ' ', 'Education': ['0.22km', '0.88km', '1.44km', '1.73km', '1.83km', '2.06km'], 'Health': ['0.58km', '0.64km', '2.00km'], 'Shopping': ['0.58km', '0.75km', '2.17km'], 'Food and Entertainment': ['0.59km', '0.60km', '0.61km', '0.96km', '0.97km', '1.50km', '2.04km', '2.07km', '2.09km', '2.14km', '2.16km', '2.17km', '2.21km'], 'Sports and Leisure': ['0.62km', '1.93km', '2.21km'], 'Transport and Public Services': ['1.15km', '1.97km']}
# ==>Property link:  /for-sale/raslouw/centurion/gauteng/383/109990079
# ====> Page not found !!
# ==>Property link:  /for-sale/broadlands-estate/polokwane/limpopo/11513/109265879
# {'name': '6 Bedroom House for Sale in Broadlands Estate', 'price': 'R 6 200 000', 'province': 'limpopo', 'city': 'polokwane', 'address': 'Broadlands Estate, Polokwane', 'Listing Number': '109265879', 'Type of Property': 'House', 'Description': 'Freestanding', 'Lifestyle': 'Wildlife Estate', 'Listing Date': '22 October 2020', 'Erf Size': '8 572 m²', 'Floor Size': '602 m²', 'Levies': 'R 3 555', 'Rates and Taxes': 'R 5 000', 'Pets Allowed': 'Yes', 'Coverage': '7 %', 'Bedrooms': '6', 'Bathrooms': '4', 'Kitchens': '1', 'Office/studies': '1', 'Lofts': '1', 'Lounges': '1', 'Dining Rooms': '1', 'Family/TV Rooms': '1', 'Bars': '1', 'Entrance Halls': '1', 'Garage': '4', 'Garage 1': 'Electric Door', 'Garage 2': 'Electric Door', 'Garage 3': 'Electric Door', 'Garage 4': 'Electric Door', 'Parking': '2', 'Gardens': '1', 'Security': '1', 'Temperature Controls': '1', 'Special Featuress': '1', 'Internet Access': 'Fibre', 'Generator': 'Yes', 'Backup Water': 'Yes', 'Standalone Building': 'Yes', 'Education': ['0.80km', '3.28km', '3.32km', '3.81km', '4.20km', '4.45km', '4.60km', '4.65km', '4.90km', '5.09km', '5.10km', '5.22km', '5.23km', '5.23km', '5.29km', '5.33km', '5.47km', '5.71km', '5.76km', '5.81km', '6.04km', '6.33km', '6.57km', '6.57km', '6.57km'], 'Transport and Public Services': ['1.73km', '5.43km', '6.04km', '6.43km', '7.01km']}
# ==>Property link:  /for-sale/umhlanga-rocks/umhlanga/kwazulu-natal/6381/109248999
# {'name': '3 Bedroom Apartment / Flat for Sale in Umhlanga Rocks', 'price': 'R 2 500 000', 'province': 'kwazulu-natal', 'city': 'umhlanga', 'address': 'Umhlanga Rocks, Umhlanga', 'Listing Number': '109248999', 'Type of Property': 'Apartment / Flat', 'Lifestyle': 'Complex', 'Listing Date': '19 October 2020', 'Floor Size': '86 m²', 'Price per m²': 'R 29 070', 'Levies': 'R 2 307', 'Rates and Taxes': 'R 1 272', 'Bedrooms': '3', 'Bedroom 1': ' ', 'Bedroom 2': ' ', 'Bedroom 3': ' ', 'Bathrooms': '2', 'Kitchen': ' ', 'Parking': 'Shade net parking', 'Pool': 'Yes', 'Wheelchair Accessible': 'Yes', 'Food and Entertainment': ['0.53km', '1.39km', '1.39km', '1.46km', '1.47km', '1.47km', '1.49km', '1.50km', '1.52km', '1.53km', '1.54km', '1.54km', '1.54km', '1.54km', '1.54km', '1.54km', '1.54km', '1.54km'], 'Education': ['0.54km', '1.23km'], 'Health': ['1.15km', '1.24km', '1.30km', '1.37km', '1.50km', '1.53km'], 'Shopping': ['1.47km', '1.50km', '1.52km'], 'Sports and Leisure': ['1.53km']}
# ==>Property link:  /for-sale/umhlanga-ridge/umhlanga/kwazulu-natal/6383/107638909
# {'name': '3 Bedroom Apartment / Flat for Sale in Umhlanga Ridge', 'price': 'R 3 238 000', 'province': 'kwazulu-natal', 'city': 'umhlanga', 'address': 'Umhlanga Ridge, Umhlanga', 'Listing Number': '107638909', 'Type of Property': 'Apartment / Flat', 'Listing Date': '03 March 2021', 'Floor Size': '155 m²', 'Price per m²': 'R 20 890', 'Pets Allowed': 'No', 'Bedrooms': '3', 'Bathrooms': '2', 'Kitchens': '1', 'Lounges': '1', 'Parking': '2', 'Pool': 'Yes', 'Food and Entertainment': ['0.16km', '0.17km', '0.17km', '0.19km', '0.19km', '0.19km', '0.19km', '0.19km', '0.19km', '0.20km', '0.22km', '0.26km', '0.27km', '0.37km', '0.37km', '0.37km', '0.38km', '0.38km', '0.39km', '0.39km', '0.39km', '0.40km', '0.41km'], 'Shopping': ['0.17km', '0.20km', '0.22km', '0.23km', '0.23km', '0.40km'], 'Sports and Leisure': ['0.20km']}
# ==>Property link:  /for-sale/amandasig/akasia/gauteng/3990/104258354
# {'name': '4 Bedroom House for Sale in Amandasig', 'price': 'R 2 558 000', 'province': 'gauteng', 'city': 'akasia', 'address': 'Amandasig, Akasia', 'Listing Number': '104258354', 'Type of Property': 'House', 'Description': 'Freestanding', 'Listing Date': '06 September 2016', 'Erf Size': '1.48 m²', 'Floor Size': '440 m²', 'Levies': 'R 1 300', 'Rates and Taxes': 'R 2 000', 'Pets Allowed': 'Yes', 'Coverage': '100 %', 'Bedrooms': '4', 'Bedroom 1': 'Tiled Floors, Built-in Cupboards, Double Bed', 'Bedroom 2': 'Tiled Floors, Built-in Cupboards, Double Bed', 'Bedroom 3': 'Tiled Floors, Built-in Cupboards, Double Bed', 'Bedroom 4': 'Tiled Floors, Built-in Cupboards, Double Bed', 'Bathrooms': '3', 'Bathroom 1': 'Tiled Floors, Shower, Bath, Toilet and Basin', 'Bathroom 2': 'Tiled Floors, Shower, Bath, Toilet and Basin', 'Bathroom 3': 'Tiled Floors, Shower, Bath, Toilet and Basin', 'Kitchen': 'Laundry, Stove (Oven & Hob), Tiled Floors', 'Office/study': 'Tiled Floors', 'Lounges': '2', 'Lounge 1': 'Tiled Floors', 'Lounge 2': 'Tiled Floors', 'Dining Room': 'Tiled Floors', 'Family/TV Room': 'Tiled Floors', 'Garage': '2', 'Parking': '4', 'Parking 1': 'Carport', 'Parking 2': 'Carport', 'Parking 3': 'Carport', 'Parking 4': 'Carport', 'Gardens': '1', 'Outbuilding': 'The Flat has is an 1 Beroom with an bath, basin and toilet\r\n\r\nThe House is 2 Bedroom 2 bathroom with an study has an open plan kitchen + lounge and double garage. Dubble carport and has gas stove and gas geyser. House also have an gym Suitable for Guest house or Business.House size 160 sqm', 'Security': 'Electric Gate, Alarm System, 24 Hour Response, Burglar Bars, Electric fencing', 'Special Features': 'Special Lights, Sprinkler System', 'Second House': 'Yes', 'Flatlet': 'Yes', 'Flat Description': 'The Flat has is an 1 Beroom with an bath, basin...', 'Style': 'Modern', 'Roof': 'Tile', 'Wall': 'Plaster', 'Window': 'Steel ', 'Education': ['0.50km', '3.13km', '3.25km', '3.95km', '4.84km', '5.21km', '5.30km', '5.90km', '5.99km', '6.02km', '6.82km', '7.17km', '7.27km', '7.32km', '7.48km', '7.66km', '7.69km'], 'Transport and Public Services': ['2.95km', '4.33km', '5.23km', '5.51km', '5.67km', '6.09km', '6.32km', '6.33km', '6.77km'], 'Food and Entertainment': ['3.49km'], 'Sports and Leisure': ['4.53km', '5.50km', '7.09km']}
# ==>Property link:  /for-sale/parkhill-gardens/germiston/gauteng/1733/110009986
# {'name': '6 Bedroom House for Sale in Parkhill Gardens', 'price': 'R 2 200 000', 'province': 'gauteng', 'city': 'germiston', 'address': '\n6 Bedroom House for Sale in Parkhill Gardens\n', 'Listing Number': '110009986', 'Type of Property': 'House', 'Street Address': ' 41 haley, Parkhill Gardens', 'Listing Date': '24 May 2021', 'Erf Size': '1 900 m²', 'Pets Allowed': 'Yes', 'Bedrooms': '6', 'Bedroom 1': ' ', 'Bedroom 2': ' ', 'Bedroom 3': ' ', 'Bedroom 4': ' ', 'Bedroom 5': ' ', 'Bedroom 6': ' ', 'Bathrooms': '4', 'Kitchen': ' ', 'Domestic Rooms': '1', 'Lounge': ' ', 'Dining Room': ' ', 'Braai Room': ' ', 'Entrance Hall': 'Entrance Hall', 'Garage': '6', 'Garage 1': ' ', 'Garage 2': ' ', 'Garage 3': ' ', 'Garage 4': ' ', 'Garage 5': ' ', 'Garage 6': ' ', 'Parking': '10', 'Garden': 'Yes', 'Pool': 'Yes', 'Special Feature': 'Borehole', 'Flatlet': 'Yes', 'Transport and Public Services': ['0.38km', '0.50km', '1.11km', '1.40km', '1.78km', '2.26km', '2.37km', '2.51km', '2.76km', '3.33km'], 'Education': ['0.66km', '0.76km', '0.99km', '1.16km', '1.52km', '1.54km', '1.79km', '1.81km', '1.84km', '2.30km', '2.35km', '2.90km', '2.91km', '3.10km', '3.21km', '3.31km', '3.40km', '3.40km', '3.43km', '3.47km']}
# ==>Property link:  /for-sale/umzinto/umzinto/kwazulu-natal/6317/105343904
# {'name': '3 Bedroom House for Sale in Umzinto', 'price': 'R 995 000', 'province': 'kwazulu-natal', 'city': 'umzinto', 'address': 'Umzinto', 'Listing Number': '105343904', 'Type of Property': 'House', 'Listing Date': '07 July 2017', 'Erf Size': '938 m²', 'Bedrooms': '3', 'Bedroom 1': 'Built-In Cupboards, Tiled Flooring', 'Bedroom 2': 'Built-In Cupboards, Tiled Flooring', 'Bedroom 3': 'Built-In Cupboards, Tiled Flooring', 'Bathrooms': '2', 'Kitchen': 'Extractor Fan, Granite Tops, Oven/Hob, Wood Kitchen', 'Reception Rooms': '2', 'Lounge': 'Balcony, Satellite Dish', 'Dining Room': 'Tiled Flooring', 'Other': 'Automatic Gates', 'Garden': 'Landscaped', 'Security': '24 Hour Manned Security, Burglar Bars, Electronic Beams', 'Education': ['0.17km', '0.17km', '0.69km', '0.69km', '0.74km', '0.88km', '0.95km', '2.46km', '5.20km', '5.36km', '6.08km', '6.28km', '6.30km', '6.59km', '6.86km', '7.00km', '7.59km', '7.79km', '7.90km', '7.94km', '8.17km', '8.46km', '8.46km', '8.62km', '8.82km'], 'Transport and Public Services': ['3.27km', '7.11km', '7.59km'], 'Sports and Leisure': ['8.18km', '8.29km']}
# ==>Property link:  /for-sale/karenpark/akasia/gauteng/335/109779351
# {'name': '3 Bedroom House for Sale in Karenpark', 'price': 'R 914 000', 'province': 'gauteng', 'city': 'akasia', 'address': '\n3 Bedroom House for Sale in Karenpark\n', 'Listing Number': '109779351', 'Type of Property': 'House', 'Street Address': '43 Libiscus Avenue , Karenpark', 'Listing Date': '23 March 2021', 'Erf Size': '218 m²', 'Rates and Taxes': 'R 1 000', 'Pets Allowed': 'Yes', 'Bedrooms': '3', 'Bathrooms': '2', 'Reception Rooms': '2', 'Lounge': '2 Lounge', 'Parking': '3', 'Garden': 'Yes', 'Education': ['0.80km', '1.77km', '1.84km', '2.34km', '2.43km', '2.79km', '2.93km', '2.99km', '3.34km', '4.17km', '4.23km', '4.56km', '4.97km', '5.77km', '5.93km', '6.00km', '6.08km', '6.09km'], 'Transport and Public Services': ['2.69km', '2.78km', '3.28km', '3.28km', '4.58km', '4.72km', '5.41km', '5.54km'], 'Sports and Leisure': ['3.06km', '5.38km', '5.83km'], 'Food and Entertainment': ['4.91km']}
# ==>Property link:  /for-sale/three-rivers/vereeniging/gauteng/3754/109879649
# {'name': '4 Bedroom House for Sale in Three Rivers', 'price': 'R 1 200 000', 'province': 'gauteng', 'city': 'vereeniging', 'address': 'Three Rivers, Vereeniging', 'Listing Number': '109879649', 'Type of Property': 'House', 'Listing Date': '19 April 2021', 'Erf Size': '1 152 m²', 'Pets Allowed': 'Yes', 'Bedrooms': '4', 'Bathrooms': '2', 'Kitchen': 'Laundry, Eye Level Oven', 'Rooms': 'Patio', 'Garage': '2', 'Parking': '3', 'Garden': 'Yes', 'Pool': 'Yes', 'Security': 'Perimeter Wall', 'Flatlet': 'Yes', 'Roof': 'Tile, Concrete', 'Wall': 'Plaster', 'Floor': 'Tiled Floors', 'Education': ['0.77km', '1.32km', '1.50km', '1.52km', '1.55km', '2.36km', '2.89km', '3.60km', '4.75km', '4.75km', '4.89km', '5.04km', '5.47km', '5.70km', '5.70km', '5.75km', '5.80km', '6.05km', '6.10km', '6.19km', '6.43km', '6.50km', '6.53km', '7.71km'], 'Transport and Public Services': ['3.66km', '3.70km', '5.03km', '5.22km', '6.37km', '7.48km']}
# ==>Property link:  /for-sale/azalea-park/rustenburg/north-west/3225/110169578
# ====> Page not found !!
# ==>Property link:  /for-sale/lethlabile/brits/north-west/3090/110191662
# {'name': '3 Bedroom House for Sale in Lethlabile', 'price': 'R 650 000', 'province': 'north-west', 'city': 'brits', 'address': 'Lethlabile, Brits', 'Listing Number': '110191662', 'Type of Property': 'House', 'Listing Date': '13 July 2021', 'Rates and Taxes': 'R 600', 'Pets Allowed': 'Yes', 'Bedrooms': '3', 'Bathrooms': '1', 'Kitchens': '1', 'Lounges': '1', 'Education': ['0.14km', '0.29km', '0.36km', '0.61km', '0.73km', '1.27km', '1.30km', '1.66km', '1.92km', '2.21km', '3.93km', '4.04km', '4.70km', '4.73km', '4.97km', '5.16km', '5.16km', '5.23km', '5.25km', '5.86km', '6.21km', '6.66km', '7.18km', '7.22km', '7.88km', '8.91km', '9.29km', '9.60km', '9.93km'], 'Transport and Public Services': ['6.51km']}
# ==>Property link:  /for-sale/northmead/benoni/gauteng/2168/110213799
# {'name': '3 Bedroom House for Sale in Northmead', 'price': 'R 1 350 000', 'province': 'gauteng', 'city': 'benoni', 'address': '\n3 Bedroom House for Sale in Northmead\n', 'Listing Number': '110213799', 'Type of Property': 'House', 'Street Address': ' 36 Stokroos Street, Northmead', 'Description': 'Single Storey, Freestanding', 'Listing Date': '20 July 2021', 'Erf Size': '991 m²', 'Floor Size': '200 m²', 'Special Levy': 'R 0', 'Rates and Taxes': 'R 850', 'Age': '21', 'Pets Allowed': 'Yes', 'Coverage': '20 %', 'Bedrooms': '3', 'Bedroom 1': 'Main Bedroom', 'Bedroom 2': '2nd Bedroom ', 'Bedroom 3': '3rd Bedroom', 'Bathroom': 'Bathroom', 'Kitchen': 'Kitchen ', 'Lounge': 'Lounge', 'Dining Room': 'Dining room', 'Garage': '2', 'Garage 1': 'Garage 1', 'Garage 2': 'Garage 2', 'Parking': '2', 'Parking 1': 'Carport ', 'Parking 2': 'Carport ', 'Garden': 'Garden ', 'Size of Outbuildings': '50 m²', 'Security': 'Security ', 'Nearby Public Transport': 'Minibus Taxi', 'Internet Access': 'Fibre', 'Wheelchair Accessible': 'No', 'Generator': 'No', 'Backup Water': 'No', 'Style': 'Traditional', 'Roof': 'Zinc', 'Wall': 'Brick, Plaster', 'Window': 'Steel ', 'Standalone Building': 'Yes', 'Food and Entertainment': ['0.45km', '1.16km', '1.45km', '1.57km', '1.67km', '1.90km', '2.42km'], 'Education': ['0.58km', '0.82km', '0.95km', '1.25km', '1.32km', '1.32km', '1.44km', '1.72km', '1.90km', '2.05km', '2.14km', '2.20km', '2.29km', '2.32km'], 'Transport and Public Services': ['0.77km', '1.32km', '1.62km', '1.74km'], 'Health': ['1.08km', '1.12km', '1.56km', '2.15km'], 'Sports and Leisure': ['1.52km']}
# ==>Property link:  /for-sale/jeppestown/johannesburg/gauteng/4213/107990064
# {'name': '29 Bedroom House for Sale in Jeppestown', 'price': 'R 2 500 000', 'province': 'gauteng', 'city': 'johannesburg', 'address': 'Jeppestown, Johannesburg', 'Listing Number': '107990064', 'Type of Property': 'House', 'Listing Date': '30 September 2019', 'Bedrooms': '29', 'Bedroom 1': ' ', 'Bedroom 2': ' ', 'Bedroom 3': ' ', 'Bedroom 4': ' ', 'Bedroom 5': ' ', 'Bedroom 6': ' ', 'Bedroom 7': ' ', 'Bedroom 8': ' ', 'Bedroom 9': ' ', 'Bedroom 10': ' ', 'Bedroom 11': ' ', 'Bedroom 12': ' ', 'Bedroom 13': ' ', 'Bedroom 14': ' ', 'Bedroom 15': ' ', 'Bedroom 16': ' ', 'Bedroom 17': ' ', 'Bedroom 18': ' ', 'Bedroom 19': ' ', 'Bedroom 20': ' ', 'Bedroom 21': ' ', 'Bedroom 22': ' ', 'Bedroom 23': ' ', 'Bedroom 24': ' ', 'Bedroom 25': ' ', 'Bedroom 26': ' ', 'Bedroom 27': ' ', 'Bedroom 28': ' ', 'Bedroom 29': ' ', 'Bathrooms': '6', 'Kitchen': 'Laundry', 'Transport and Public Services': ['0.34km', '1.51km', '1.66km', '1.69km', '2.02km', '2.20km', '2.52km'], 'Education': ['0.47km', '0.57km', '0.59km', '0.67km', '0.87km', '1.03km', '1.07km', '1.20km', '1.22km', '1.23km', '1.23km', '1.27km', '1.47km', '1.60km', '1.68km', '1.82km', '1.83km', '1.91km', '2.04km', '2.07km', '2.34km'], 'Sports and Leisure': ['2.14km'], 'Food and Entertainment': ['2.42km']}
# ==>Property link:  /for-sale/deales-gift/bloemfontein/free-state/9650/109581969
# ==>Property link:  /for-sale/daspoort/pretoria/gauteng/281/109581628
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-205986050037> in <module>
#       2 try:
# ----> 3     dc.crawl_properties()
#       4 except:
#
# <ipython-input-18-fcd08170ee41> in crawl_properties(self)
#     185             print('==>Property link: ', prop_link)
# --> 186             check_property_crawl = self.get_property_data(prop_link)
#     187             if check_property_crawl:
#
# <ipython-input-18-fcd08170ee41> in get_property_data(self, link)
#     136         #points_interest
# --> 137         interest_soup= crawl_page(self.__url_to_open+'/ListingReadOnly/PointsOfInterestForListing?ListingNumber=P24-'+estate_id)
#     138         # points_interest_panel=prop_soup.select_one('#accordian-points-of-interest')
#
# <ipython-input-3-ab13bed783be> in crawl_page(link)
#      29     try:
# ---> 30         response = requests.get(
#      31             url='http://api.scraperapi.com', #scrapeapi
#
# ~/.local/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#
# ~/.local/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#
# ~/.local/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#
# ~/.local/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#
# ~/.local/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     664             # Make the request on the httplib connection object.
# --> 665             httplib_response = self._make_request(
#     666                 conn,
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                     # Otherwise it looks like a bug in the code.
# --> 421                     six.raise_from(e, None)
#     422         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# /usr/lib/python3/dist-packages/six.py in raise_from(value, from_value)
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     415                 try:
# --> 416                     httplib_response = conn.getresponse()
#     417                 except BaseException as e:
#
# /usr/lib/python3.8/http/client.py in getresponse(self)
#    1343             try:
# -> 1344                 response.begin()
#    1345             except ConnectionError:
#
# /usr/lib/python3.8/http/client.py in begin(self)
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#
# /usr/lib/python3.8/http/client.py in _read_status(self)
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#
# /usr/lib/python3.8/socket.py in readinto(self, b)
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-205986050037> in <module>
#       3     dc.crawl_properties()
#       4 except:
# ----> 5     dc.crawl_properties()
#
# <ipython-input-18-fcd08170ee41> in crawl_properties(self)
#     184
#     185             print('==>Property link: ', prop_link)
# --> 186             check_property_crawl = self.get_property_data(prop_link)
#     187             if check_property_crawl:
#     188                 self.__urls= self.__urls.drop(self.__urls.index[i])
#
# <ipython-input-18-fcd08170ee41> in get_property_data(self, link)
#      59
#      60
# ---> 61         name= prop_soup.find('div',class_='p24_listingFeaturesWrapper').find('h1').get_text()
#      62         data['name']=name
#      63
#
# AttributeError: 'NoneType' object has no attribute 'find'
