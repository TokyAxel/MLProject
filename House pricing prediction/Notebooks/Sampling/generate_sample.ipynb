# %%
import pandas as pd
import re

# %%
def to_snake_case(string):
    string = re.sub('\s+', r'_', string)   
    return string.lower()

# %%
data= pd.read_csv("../../Data/Dataset_v1.csv",sep=";")

data= data.rename(to_snake_case, axis='columns')

data['sampling']=0

# %%
(data['type_of_property'].value_counts() / len(data), data['province'].value_counts() / len(data))
# Out:
# (House                 0.502214
#  Apartment / Flat      0.350076
#  Townhouse             0.147629
#  Vacant Land / Plot    0.000080
#  Name: type_of_property, dtype: float64,
#  gauteng          0.453594
#  western-cape     0.157772
#  kwazulu-natal    0.133140
#  north-west       0.079127
#  mpumalanga       0.058923
#  free-state       0.040248
#  eastern-cape     0.039765
#  limpopo          0.029220
#  northern-cape    0.008211
#  Name: province, dtype: float64)

# %%
def get_type_property_per_province_proportion(data=pd.DataFrame):
    total_house=  data[(data['type_of_property']=="House")].shape[0]
    total_apartement=  data[(data['type_of_property']=="Apartment / Flat")].shape[0]
    total_townhouse=  data[(data['type_of_property']=="Townhouse")].shape[0]
    provinces= data['province'].sort_values(ascending=True).unique().tolist()
    houses=[]
    houses_percentage=[]
    houses_all_percentage=[]
    apartments_percentage=[]
    apartments_all_percentage=[]
    apartments=[]
    townhouses=[]
    townhouses_percentage=[]
    townhouses_all_percentage=[]
    for province in provinces:
        temp_house= data[(data['type_of_property']=="House") & (data['province']==province)].shape[0]
        temp_apartement= data[(data['type_of_property']=="Apartment / Flat") & (data['province']==province)].shape[0]
        temp_townhouse= data[(data['type_of_property']=="Townhouse") & (data['province']==province)].shape[0]

        houses.append(temp_house)
        houses_percentage.append(temp_house*100/total_house)
        houses_all_percentage.append(temp_house*100/len(data))
        apartments.append(temp_apartement)
        apartments_percentage.append(temp_apartement*100/total_apartement)
        apartments_all_percentage.append(temp_apartement*100/len(data))
        townhouses.append(temp_townhouse)
        townhouses_percentage.append(temp_townhouse*100/total_townhouse)
        townhouses_all_percentage.append(temp_townhouse*100/len(data))

    provinces_data=pd.DataFrame([houses,houses_percentage,houses_all_percentage,apartments,apartments_percentage,apartments_all_percentage,townhouses,townhouses_percentage,townhouses_all_percentage],\
        index=["House","House %","House % over all properties","Apartment / Flat","Apartment / Flat %","Apartment / Flat % over all properties","Townhouse","Townhouse %","Townhouse % over all properties"],columns=provinces)

    return provinces_data

# %% [markdown]
# Utilisation de la fonction stratified_sample venant du site https://www.kaggle.com/flaviobossolan/stratified-sampling-python avec modification selon le besoin

# %%
def stratified_sample(df, strata, size=None, seed=None, keep_index= True, sampling_code=0):
    '''
    It samples data from a pandas dataframe using strata. These functions use
    proportionate stratification:
    n1 = (N1/N) * n
    where:
        - n1 is the sample size of stratum 1
        - N1 is the population size of stratum 1
        - N is the total population size
        - n is the sampling size
    Parameters
    ----------
    :df: pandas dataframe from which data will be sampled.
    :strata: list containing columns that will be used in the stratified sampling.
    :size: sampling size. If not informed, a sampling size will be calculated
        using Cochran adjusted sampling formula:
        cochran_n = (Z**2 * p * q) /e**2
        where:
            - Z is the z-value. In this case we use 1.96 representing 95%
            - p is the estimated proportion of the population which has an
                attribute. In this case we use 0.5
            - q is 1-p
            - e is the margin of error
        This formula is adjusted as follows:
        adjusted_cochran = cochran_n / 1+((cochran_n -1)/N)
        where:
            - cochran_n = result of the previous formula
            - N is the population size
    :seed: sampling seed
    :keep_index: if True, it keeps a column with the original population index indicator
    
    Returns
    -------
    A sampled pandas dataframe based in a set of strata.
    Examples
    --------
    >> df.head()
    	id  sex age city 
    0	123 M   20  XYZ
    1	456 M   25  XYZ
    2	789 M   21  YZX
    3	987 F   40  ZXY
    4	654 M   45  ZXY
    ...
    # This returns a sample stratified by sex and city containing 30% of the size of
    # the original data
    >> stratified = stratified_sample(df=df, strata=['sex', 'city'], size=0.3)
    Requirements
    ------------
    - pandas
    - numpy
    '''
    population = len(df[df['sampling']==0])
    tmp = df[strata].where(data['sampling']==0)

    tmp['size'] = 1
    tmp_grpd = tmp.groupby(strata).count().reset_index()

    tmp_grpd['samp_size'] = round(size/population * tmp_grpd['size']).astype(int)


    # controlling variable to create the dataframe or append to it
    first = True 
    for i in range(len(tmp_grpd)):
        # query generator for each iteration
        qry=''
        for s in range(len(strata)):
            stratum = strata[s]
            value = tmp_grpd.iloc[i][stratum]
            n = tmp_grpd.iloc[i]['samp_size']


            if type(value) == str:
                value = "'" + str(value) + "'"
            
            if s != len(strata)-1:
                qry = qry + stratum + ' == ' + str(value) +' & '
            else:
                qry = qry + stratum + ' == ' + str(value)
        
        qry = qry + ' & sampling==0' #using only the data that were not yet sampled
        
        # final dataframe
        if first:
            stratified_df = df.query(qry).sample(n=n, random_state=seed).reset_index(drop=(not keep_index))
            selected_index= stratified_df['index'].tolist()
            first = False
        else:
            tmp_df = df.query(qry).sample(n=n, random_state=seed).reset_index(drop=(not keep_index))
            selected_index= tmp_df['index'].tolist()

            # stratified_df = stratified_df.append(tmp_df, ignore_index=True)
        
        df.loc[selected_index,'sampling']=sampling_code
        
    
    return df

# %%
data= pd.read_csv("../../Data/Dataset_v1.csv",sep=";")

data= data.rename(to_snake_case, axis='columns')

data['sampling']=0

sampling={"Train": {"code": 1, "size": round(len(data)*70 /100)}, 
            "Test": {"code": 2, "size": round(len(data)*15 /100) }, 
            "Validation": {"code": 3, "size": round(len(data)*15 /100) }
        }


#generate sampling
for elt in sampling:
    sample= sampling[elt]
    print("size:",sample['size'], "population: ", len(data[data['sampling'] == 0]) )
    sample_df = stratified_sample(data, ['province','type_of_property'], size=sample['size'], seed=123, keep_index= True,sampling_code=sample['code'])  
    print("sample size:", len(sample_df[sample_df['sampling']==sample['code']]))
# Out:
# size: 8696 population:  12423
# sample size: 8694
# size: 1863 population:  3729
# sample size: 1857
# size: 1863 population:  1872
# sample size: 1865

# %%
len(data[data['sampling'] == 0])
# Out:
# 7

# %%
get_type_property_per_province_proportion(data)
# Out:
#                                         eastern-cape  free-state      gauteng  \
# House                                     321.000000  315.000000  2744.000000
# House %                                     5.145055    5.048886    43.981407
# House % over all properties                 2.583917    2.535619    22.088062
# Apartment / Flat                          125.000000   82.000000  1913.000000
# Apartment / Flat %                          2.874224    1.885491    43.987123
# Apartment / Flat % over all properties      1.006198    0.660066    15.398857
# Townhouse                                  48.000000  103.000000   978.000000
# Townhouse %                                 2.617230    5.616140    53.326063
# Townhouse % over all properties             0.386380    0.829107     7.872495
#
#                                         kwazulu-natal     limpopo  mpumalanga  \
# House                                      566.000000  255.000000  502.000000
# House %                                      9.071967    4.087193    8.046161
# House % over all properties                  4.556065    2.052644    4.040892
# Apartment / Flat                           835.000000   59.000000  100.000000
# Apartment / Flat %                          19.199816    1.356634    2.299379
# Apartment / Flat % over all properties       6.721404    0.474926    0.804959
# Townhouse                                  253.000000   49.000000  130.000000
# Townhouse %                                 13.794984    2.671756    7.088332
# Townhouse % over all properties              2.036545    0.394430    1.046446
#
#                                         north-west  northern-cape  \
# House                                   490.000000      89.000000
# House %                                   7.853823       1.426511
# House % over all properties               3.944297       0.716413
# Apartment / Flat                        351.000000       7.000000
# Apartment / Flat %                        8.070821       0.160957
# Apartment / Flat % over all properties    2.825404       0.056347
# Townhouse                               141.000000       6.000000
# Townhouse %                               7.688113       0.327154
# Townhouse % over all properties           1.134992       0.048298
#
#                                         western-cape
# House                                     957.000000
# House %                                    15.338997
# House % over all properties                 7.703453
# Apartment / Flat                          877.000000
# Apartment / Flat %                         20.165555
# Apartment / Flat % over all properties      7.059486
# Townhouse                                 126.000000
# Townhouse %                                 6.870229
# Townhouse % over all properties             1.014248

# %%
get_type_property_per_province_proportion(data[data['sampling']==1])
# Out:
#                                         eastern-cape  free-state      gauteng  \
# House                                     225.000000  220.000000  1921.000000
# House %                                     5.153459    5.038937    43.999084
# House % over all properties                 2.587992    2.530481    22.095698
# Apartment / Flat                           87.000000   57.000000  1339.000000
# Apartment / Flat %                          2.859021    1.873151    44.002629
# Apartment / Flat % over all properties      1.000690    0.655625    15.401426
# Townhouse                                  34.000000   72.000000   685.000000
# Townhouse %                                 2.647975    5.607477    53.348910
# Townhouse % over all properties             0.391074    0.828157     7.878997
#
#                                         kwazulu-natal     limpopo  mpumalanga  \
# House                                      396.000000  178.000000  351.000000
# House %                                      9.070087    4.076958    8.039395
# House % over all properties                  4.554865    2.047389    4.037267
# Apartment / Flat                           584.000000   41.000000   70.000000
# Apartment / Flat %                          19.191587    1.347355    2.300361
# Apartment / Flat % over all properties       6.717276    0.471590    0.805153
# Townhouse                                  177.000000   34.000000   91.000000
# Townhouse %                                 13.785047    2.647975    7.087227
# Townhouse % over all properties              2.035887    0.391074    1.046699
#
#                                         north-west  northern-cape  \
# House                                   343.000000      62.000000
# House %                                   7.856161       1.420064
# House % over all properties               3.945250       0.713135
# Apartment / Flat                        246.000000       5.000000
# Apartment / Flat %                        8.084128       0.164312
# Apartment / Flat % over all properties    2.829538       0.057511
# Townhouse                                99.000000       4.000000
# Townhouse %                               7.710280       0.311526
# Townhouse % over all properties           1.138716       0.046009
#
#                                         western-cape
# House                                     670.000000
# House %                                    15.345854
# House % over all properties                 7.706464
# Apartment / Flat                          614.000000
# Apartment / Flat %                         20.177456
# Apartment / Flat % over all properties      7.062342
# Townhouse                                  88.000000
# Townhouse %                                 6.853583
# Townhouse % over all properties             1.012192

# %%
get_type_property_per_province_proportion(data[data['sampling']==2])
# Out:
#                                         eastern-cape  free-state     gauteng  \
# House                                      48.000000   47.000000  411.000000
# House %                                     5.144695    5.037513   44.051447
# House % over all properties                 2.584814    2.530964   22.132472
# Apartment / Flat                           19.000000   12.000000  287.000000
# Apartment / Flat %                          2.918587    1.843318   44.086022
# Apartment / Flat % over all properties      1.023156    0.646204   15.455035
# Townhouse                                   7.000000   15.000000  146.000000
# Townhouse %                                 2.564103    5.494505   53.479853
# Townhouse % over all properties             0.376952    0.807754    7.862143
#
#                                         kwazulu-natal    limpopo  mpumalanga  \
# House                                       85.000000  38.000000   75.000000
# House %                                      9.110397   4.072883    8.038585
# House % over all properties                  4.577275   2.046311    4.038772
# Apartment / Flat                           125.000000   9.000000   15.000000
# Apartment / Flat %                          19.201229   1.382488    2.304147
# Apartment / Flat % over all properties       6.731287   0.484653    0.807754
# Townhouse                                   38.000000   7.000000   19.000000
# Townhouse %                                 13.919414   2.564103    6.959707
# Townhouse % over all properties              2.046311   0.376952    1.023156
#
#                                         north-west  northern-cape  \
# House                                    73.000000      13.000000
# House %                                   7.824223       1.393355
# House % over all properties               3.931072       0.700054
# Apartment / Flat                         52.000000       1.000000
# Apartment / Flat %                        7.987711       0.153610
# Apartment / Flat % over all properties    2.800215       0.053850
# Townhouse                                21.000000       1.000000
# Townhouse %                               7.692308       0.366300
# Townhouse % over all properties           1.130856       0.053850
#
#                                         western-cape
# House                                     143.000000
# House %                                    15.326902
# House % over all properties                 7.700592
# Apartment / Flat                          131.000000
# Apartment / Flat %                         20.122888
# Apartment / Flat % over all properties      7.054389
# Townhouse                                  19.000000
# Townhouse %                                 6.959707
# Townhouse % over all properties             1.023156

# %%
get_type_property_per_province_proportion(data[data['sampling']==3])
# Out:
#                                         eastern-cape  free-state     gauteng  \
# House                                      48.000000   48.000000  410.000000
# House %                                     5.122732    5.122732   43.756670
# House % over all properties                 2.573727    2.573727   21.983914
# Apartment / Flat                           19.000000   13.000000  286.000000
# Apartment / Flat %                          2.914110    1.993865   43.865031
# Apartment / Flat % over all properties      1.018767    0.697051   15.335121
# Townhouse                                   7.000000   16.000000  146.000000
# Townhouse %                                 2.536232    5.797101   52.898551
# Townhouse % over all properties             0.375335    0.857909    7.828418
#
#                                         kwazulu-natal    limpopo  mpumalanga  \
# House                                       85.000000  39.000000   76.000000
# House %                                      9.071505   4.162220    8.110993
# House % over all properties                  4.557641   2.091153    4.075067
# Apartment / Flat                           125.000000   9.000000   15.000000
# Apartment / Flat %                          19.171779   1.380368    2.300613
# Apartment / Flat % over all properties       6.702413   0.482574    0.804290
# Townhouse                                   38.000000   8.000000   20.000000
# Townhouse %                                 13.768116   2.898551    7.246377
# Townhouse % over all properties              2.037534   0.428954    1.072386
#
#                                         north-west  northern-cape  \
# House                                    74.000000      14.000000
# House %                                   7.897545       1.494130
# House % over all properties               3.967828       0.750670
# Apartment / Flat                         53.000000       1.000000
# Apartment / Flat %                        8.128834       0.153374
# Apartment / Flat % over all properties    2.841823       0.053619
# Townhouse                                21.000000       1.000000
# Townhouse %                               7.608696       0.362319
# Townhouse % over all properties           1.126005       0.053619
#
#                                         western-cape
# House                                     143.000000
# House %                                    15.261473
# House % over all properties                 7.667560
# Apartment / Flat                          131.000000
# Apartment / Flat %                         20.092025
# Apartment / Flat % over all properties      7.024129
# Townhouse                                  19.000000
# Townhouse %                                 6.884058
# Townhouse % over all properties             1.018767
