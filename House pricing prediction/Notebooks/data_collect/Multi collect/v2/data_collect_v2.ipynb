# %%
from bs4 import BeautifulSoup
from urllib.error import HTTPError
import urllib.request
import requests
import pandas as pd
import re
import csv

def crawl_page(link=''):
    # req = urllib.request.Request(
    #         link, 
    #         data=None, 
    #         headers={
    #             'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
    #             'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.79 Safari/537.36 Edge/14.14393'
    #         }
    # )
    # try:
    #     page= urllib.request.urlopen(req)
    #     return_code= page.getcode()
    #     soup_page= BeautifulSoup(page,'html.parser')
    #     return {'page':soup_page, 'status': return_code}
    # except HTTPError as err:
    #     if err.code == 404:
    #         return_code=404
    #         return {'page':'no page', 'status': return_code}
    #     else:
    #         raise
    try:
        response = requests.get(
            url='http://api.scraperapi.com', #scrapeapi
            params={
                'api_key': 'b4b2907633a4c7758d3e81f40c85a442',
                'url': link,  
            },
            
        )
        return_code= 200
        soup_page= BeautifulSoup(response.content,'html.parser')
        return {'page':soup_page, 'status': return_code}
    except requests.exceptions.HTTPError as err:
        if err.response.status_code == 404:
            return_code=404
            return {'page':'no page', 'status': return_code}
    

def write_csv(line=[], file=''):
    with open(file, 'a', newline='') as csvfile:
        spamwriter = csv.writer(csvfile, delimiter=' ',
                                quotechar='|', quoting=csv.QUOTE_MINIMAL)
        spamwriter.writerow(line)

def remove_row_csv():
    with open('temp_27.csv') as inp:
        for link in csv.reader(inp):
            count=0
            temp=link
            with open('used_estate.txt') as out:
                for estate in csv.reader(out):
                    if re.match("(.*)/"+estate[0],temp[1]) is not None:
                        count+=1
            if count==0:
                new_row= [link[0]+','+link[1]]
                write_csv(new_row,"temp_28.csv")

def create_urls(file=''):
    with open(file) as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')
        line_count = 1
        for row in csv_reader:
            new_row= [str(line_count)+','+row[0]]
            write_csv(new_row,'property_url_v2.csv')
            line_count+=1

# %%
class DataCollect():
    def __init__(self):
        self.__url_to_open='https://www.property24.com'
        self.__soup=crawl_page(self.__url_to_open)['page']
        self.__area_url=[]
        self.__list_url=[]
        self.__urls=pd.read_csv("temp_67_v2.csv",usecols= ['id','url']) 
    
    def collect_all_first_page_url(self):
        other_links= self.__soup.find('div',class_='p24_popular').find(class_='col-8').find_all('a',class_='p24_bold')
        for link in other_links:
            self.__area_url.append(self.__url_to_open+link.get('href'))
        first_element_tag= self.__soup.find('div',class_='p24_popular').find(class_='col-8').find_all(class_='row')[1]
        first_link=first_element_tag.find('a').get('href')
        temp_soup= crawl_page(self.__url_to_open+first_link)['page']
        parent_link= temp_soup.find(id='breadCrumbContainer').find_all('a')[1]
        self.__area_url.append(self.__url_to_open+parent_link.get('href'))
    
    def collect_all_url(self):
        self.collect_all_first_page_url()
        for link in self.__area_url:
            soup= crawl_page(link)['page']
            link_house_tag= soup.find('ul',class_='p24_relatedSales').find(href=re.compile("houses-for-sale")).get('href')
            link_apart_tag= soup.find('ul',class_='p24_relatedSales').find(href=re.compile("apartments-for-sale")).get('href')
            link_townhouse_tag= soup.find('ul',class_='p24_relatedSales').find(href=re.compile("townhouses-for-sale")).get('href')
            self.__list_url.append(link_house_tag)
            self.__list_url.append(link_apart_tag)
            self.__list_url.append(link_townhouse_tag)

    def get_property_data(self, link=''):
        data={}

        estate_id= link.split('/')[-1].split('?')[0]

        prop_soup_element= crawl_page(self.__url_to_open+link)

        
        if prop_soup_element['status'] !=200:
            print('heres')
            return False
        
        prop_soup= prop_soup_element['page']

        if prop_soup is None:
            print('here')
            return False

        #check if page not found
        check_page_not_found_msg= prop_soup.select_one('.p24_not_found')
        if check_page_not_found_msg is not None:
            print("====> Page not found !!")
            return False
        
        #check page expired
        check_page_expired = prop_soup.select_one('.p24_results.p24_expired')
        if check_page_expired is not None:
            print("====> Page expired !!")
            return False
        

        name= prop_soup.find('div',class_='p24_listingFeaturesWrapper').find('h1').get_text()
        data['name']=name

        price= prop_soup.find('div',class_='p24_listingFeaturesWrapper').find('div',class_="p24_price").get_text()
        data['price']=price

        province= link.split('/')[4]
        data['province']=province

        city= link.split('/')[3]
        data['city']=city


        is_adress= len(prop_soup.find('div',class_='p24_listingFeaturesWrapper').find_all('div',class_="p24_mBM")) >= 3
        if is_adress:
            if len(prop_soup.find('div',class_='p24_listingFeaturesWrapper').find_all('div',class_="p24_mBM")) == 3:
                index=-1
            else:
                index=3
            address= prop_soup.find('div',class_='p24_listingFeaturesWrapper').find_all('div',class_="p24_mBM")[index].get_text()
            data['address']=address
        else:
            address=  prop_soup.select_one('.p24_addressPropOverview').get_text()
            data['address']=address

        #property overview
        if type(prop_soup.select_one('.p24_propertyOverview')) is not None:
            prop_overview_panel= prop_soup.find('div',class_='p24_propertyOverview').find('div',class_='panel-body')
            prop_overview_row= prop_overview_panel.find_all('div',class_='p24_propertyOverviewRow')
            for prop in prop_overview_row:
                key= prop.find('div',class_='p24_propertyOverviewKey').get_text()
                # value= prop.select_one('.noPadding > .p24_info').get_text()
                value= prop.find('div',class_='noPadding').contents[1].get_text()
                data[key]=value

        #rooms
        rooms_panel=prop_soup.select_one('#js_accordion_rooms')
        if rooms_panel is not None:
            prop_overview_row= rooms_panel.find_all('div',class_='p24_propertyOverviewRow')
            for prop in prop_overview_row:
                key= prop.find('div',class_='p24_propertyOverviewKey').get_text()
                # value= prop.select_one('.noPadding > .p24_info').get_text()
                value= prop.find('div',class_='noPadding').contents[1].get_text()
                data[key]=value

        #external_features
        external_features_panel=prop_soup.select_one('#js_accordion_externalfeatures')
        if external_features_panel is not None:
            prop_overview_row= external_features_panel.find_all('div',class_='p24_propertyOverviewRow')
            for prop in prop_overview_row:
                key= prop.find('div',class_='p24_propertyOverviewKey').get_text()
                # value= prop.select_one('.noPadding > .p24_info').get_text()
                value= prop.find('div',class_='noPadding').contents[1].get_text()
                data[key]=value
        
        #other_features
        other_features_panel=prop_soup.select_one('#js_accordion_otherfeatures')
        if other_features_panel is not None:
            prop_overview_row= other_features_panel.find_all('div',class_='p24_propertyOverviewRow')
            for prop in prop_overview_row:
                key= prop.find('div',class_='p24_propertyOverviewKey').get_text()
                # value= prop.select_one('.noPadding > .p24_info').get_text()
                value= prop.find('div',class_='noPadding').contents[1].get_text()
                data[key]=value

        #building_features
        building_features_panel=prop_soup.select_one('#js_accordion_building')
        if building_features_panel is not None:
            prop_overview_row= building_features_panel.find_all('div',class_='p24_propertyOverviewRow')
            for prop in prop_overview_row:
                key= prop.find('div',class_='p24_propertyOverviewKey').get_text()
                # value= prop.select_one('.noPadding > .p24_info').get_text()
                value= prop.find('div',class_='noPadding').contents[1].get_text()
                data[key]=value

        #points_interest
        interest_soup= crawl_page(self.__url_to_open+'/ListingReadOnly/PointsOfInterestForListing?ListingNumber=P24-'+estate_id)
        # points_interest_panel=prop_soup.select_one('#accordian-points-of-interest')
        # print(points_interest_panel)
        if interest_soup['status'] == 200:
            categories= interest_soup['page'].select('.js_P24_POICategory')
            for cat in categories:
                interest= cat.select_one('.row > .col-6 > .p24_semibold')
                distances= cat.select('.row > .col-6.noPadding.p24_semibold')
                dist_tab=[]
                for dist in distances:
                    dist_tab.append(dist.get_text())
                data[interest.get_text()]=dist_tab

        print(str(data))
        write_csv([str(data)],'data_property_v2.csv')

        
        return True

    def crawl_property_per_page(self,city,page,number_properties):
        link=self.__url_to_open+city+'/p'+str(page)
        print('==>Page link: ',link)
        cur_soup= crawl_page(link)['page']
        properties= cur_soup.find_all('div',class_='js_resultTile')
        for prop_index in range(len(properties)-1):
            prop_link= properties[prop_index].find('a').get('href')
            write_csv([prop_link],'data_property_url.csv')

        number_properties+= len(properties)
        return number_properties

    def crawl_property_per_city(self,city,cur_page):
        soup= crawl_page(self.__url_to_open+city)['page']
        pagination= soup.find('div',class_='p24_pager').find_all('li')[-1].find('a').get('data-pagenumber')
        page_number= int(pagination)
        number_properties=0
        print("City url: ",city)
        for page in range(cur_page, page_number+1):
            print("=>Page number: ",page)
            number_properties = self.crawl_property_per_page(city,page,number_properties)
        print(number_properties)
    
    def crawl_properties(self):
        #shuffle
        self.__urls = self.__urls.sample(frac = 1).reset_index(drop=True)
        for i in range(self.__urls.size):
            prop_link= self.__urls.iloc[i]['url']
            
            print('==>Property link: ', prop_link)
            check_property_crawl = self.get_property_data(prop_link)
            if check_property_crawl:
                self.__urls= self.__urls.drop(self.__urls.index[i])
                self.__urls.to_csv('temp_68_v2.csv',index=False)

    def crawl_property_url(self):
        self.__list_url=['/townhouses-for-sale/gauteng/1']
        for link in self.__list_url:
            self.crawl_property_per_city(link,1)

# %%
dc= DataCollect()
try:
    dc.crawl_properties()
except:
    dc.crawl_properties()
# Out:
# ==>Property link:  /for-sale/heritage-hill/centurion/gauteng/10855/106701946
# {'name': '3 Bedroom House for Sale in Heritage Hill', 'price': 'R 2 790 000', 'province': 'gauteng', 'city': 'centurion', 'address': '\n3 Bedroom House for Sale in Heritage Hill\n', 'Listing Number': '106701946', 'Type of Property': 'House', 'Street Address': '926 Lucia Lilleen Avenue, Heritage Hill', 'Description': 'Double Storey, Cluster Home', 'Listing Date': '03 May 2021', 'Erf Size': '380 m²', 'Floor Size': '307 m²', 'Levies': 'R 3 680', 'Rates and Taxes': 'R 1 200', 'Pets Allowed': 'Yes', 'Bedrooms': '3', 'Bathrooms': '2.5', 'Kitchen': '1', 'Office': '1', 'Reception Rooms': '1', 'Lounge': '1', 'Dining Room': '1', 'Braai Room': '1', 'Entrance Hall': '1', 'Rooms': 'Patio', 'Garage': '2', 'Parking': '4', 'Garden': '1', 'Security': '24 Hour Access', 'Special Feature': 'Built in Braai, Satellite Dish, Balcony', 'Roof': 'Iron', 'Standalone Building': 'Yes', 'Food and Entertainment': ['1.18km', '1.21km', '1.22km', '1.23km', '1.23km', '1.24km', '1.26km', '1.27km', '2.02km', '2.03km', '2.03km', '2.78km', '2.78km', '2.93km', '2.97km'], 'Shopping': ['1.21km', '2.74km', '2.97km'], 'Sports and Leisure': ['1.84km'], 'Transport and Public Services': ['1.90km', '2.05km', '2.11km', '2.70km', '2.76km', '2.99km', '3.01km'], 'Health': ['2.05km', '2.80km'], 'Education': ['2.21km', '2.67km']}
# ==>Property link:  /for-sale/elandspoort/pretoria/gauteng/2913/109985304
# ==>Property link:  /for-sale/jeffreys-bay-central/jeffreys-bay/eastern-cape/10503/110120594
# {'name': '2 Bedroom House for Sale in Jeffreys Bay Central', 'price': 'R 1 100 000', 'province': 'eastern-cape', 'city': 'jeffreys-bay', 'address': 'Jeffreys Bay Central, Jeffreys Bay', 'Listing Number': '110120594', 'Type of Property': 'House', 'Lifestyle': 'Retirement Living', 'Listing Date': '22 June 2021', 'Floor Size': '95 m²', 'Levies': 'R 1 095', 'Pets Allowed': 'Yes', 'Bedrooms': '2', 'Bathrooms': '1', 'Kitchens': '1', 'Garage': '1', 'Wheelchair Accessible': 'Yes', 'Education': ['0.67km', '1.56km', '1.63km', '1.97km'], 'Transport and Public Services': ['3.11km', '5.64km', '7.42km', '8.07km'], 'Food and Entertainment': ['3.45km', '3.57km']}
# ==>Property link:  /for-sale/soshanguve-uu/soshanguve/gauteng/17882/109633686
# {'name': '3 Bedroom House for Sale in Soshanguve Uu', 'price': 'R 609 000', 'province': 'gauteng', 'city': 'soshanguve', 'address': '\n3 Bedroom House for Sale in Soshanguve Uu\n', 'Listing Number': '109633686', 'Type of Property': 'House', 'Street Address': ' 742 Masianoke Street, Soshanguve UU', 'Listing Date': '13 February 2021', 'Erf Size': '200 m²', 'Floor Size': '50 m²', 'No Transfer Duty': 'Yes', 'Rates and Taxes': 'R 200', 'Coverage': '25 %', 'Bedrooms': '3', 'Bathrooms': '1', 'Kitchens': '1', 'Lounges': '1', 'Education': ['0.44km', '0.47km', '0.61km', '0.66km', '1.08km', '1.27km', '1.57km', '1.59km', '2.13km', '2.36km', '2.60km', '2.84km', '2.92km', '3.06km', '3.12km', '3.36km', '3.36km', '3.38km', '3.40km', '3.43km', '3.46km', '3.52km', '3.68km', '3.69km', '3.72km', '3.76km', '3.78km', '3.83km'], 'Transport and Public Services': ['1.92km', '3.06km']}
# ==>Property link:  /for-sale/morningside/sandton/gauteng/4258/108089272
# {'name': '4 Bedroom Apartment / Flat for Sale in Morningside', 'price': 'R 3 200 000', 'province': 'gauteng', 'city': 'sandton', 'address': 'Morningside, Sandton', 'Listing Number': '108089272', 'Type of Property': 'Apartment / Flat', 'Listing Date': '13 April 2021', 'Erf Size': '1 413 m²', 'Levies': 'R 4 390', 'Rates and Taxes': 'R 1 911', 'Bedrooms': '4', 'Bedroom 1': 'Bedroom 1', 'Bedroom 2': 'Bedroom 2', 'Bedroom 3': 'Bedroom 3', 'Bedroom 4': 'Bedroom 4', 'Bathrooms': '3', 'Bathroom 1': 'Bathroom 1', 'Bathroom 2': 'Bathroom 2', 'Bathroom 3': 'Bathroom 3', 'Kitchen': 'Kitchen', 'Lounge': 'Lounge', 'Dining Room': 'Dining Room', 'Garage': '2', 'Garage 1': 'Garage 1', 'Garage 2': 'Garage 2', 'Parking': '2', 'Parking 1': 'Parking 1', 'Parking 2': 'Parking 2', 'Pool': 'Pool', 'Food and Entertainment': ['0.03km', '0.06km', '0.08km', '0.08km', '0.09km', '0.93km', '0.95km', '0.95km', '0.95km', '0.96km', '1.01km', '1.33km', '1.34km', '1.34km', '1.35km'], 'Shopping': ['0.04km', '0.07km', '0.90km', '0.94km'], 'Transport and Public Services': ['0.31km', '0.36km', '1.00km', '1.12km', '1.28km'], 'Education': ['0.59km', '0.72km', '1.18km', '1.28km'], 'Health': ['0.91km'], 'Sports and Leisure': ['0.92km']}
# ==>Property link:  /for-sale/oubaai/george/western-cape/10763/108234484
# {'name': '1 Bedroom Apartment / Flat for Sale in Oubaai', 'price': 'R 1 495 000', 'province': 'western-cape', 'city': 'george', 'address': 'Oubaai, George', 'Listing Number': '108234484', 'Type of Property': 'Apartment / Flat', 'Description': 'Simplex, First Floor', 'Lifestyle': 'Golf Estate', 'Listing Date': '11 May 2021', 'Erf Size': '173 m²', 'Floor Size': '173 m²', 'Price per m²': 'R 8 642', 'Levies': 'R 4 935', 'Rates and Taxes': 'R 1 379', 'Age': '16', 'Pets Allowed': 'No', 'Floor Number': '1', 'Bedroom': 'Carpets, Curtain Rails, TV Port, Built-in Cupboards, King Bed, Veranda', 'Bathroom': 'Tiled Floors, Full, Basin, Bath, Shower', 'Kitchen': 'Breakfast Nook, Open Plan, Stove (Oven & Hob), Fridge, Dishwasher Connection, Granite Tops, Tiled Floors, Under Counter Oven', 'Garage': 'Electric Door, Roll up, Single', 'Security': 'Safe', 'Internet Access': 'Fibre', 'Wheelchair Accessible': 'No', 'Facing': 'Sea', 'Standalone Building': 'No', 'Number of floors': '2', 'Education': ['5.07km', '5.21km', '5.27km', '6.10km', '7.21km', '7.57km', '7.81km', '7.89km', '7.92km', '7.95km', '8.64km', '8.67km', '8.86km', '8.91km', '8.93km', '9.27km', '9.73km', '9.75km', '9.93km', '10.14km', '10.46km', '10.47km', '10.57km'], 'Transport and Public Services': ['5.08km', '6.75km', '9.63km', '10.45km'], 'Sports and Leisure': ['7.34km'], 'Shopping': ['10.09km', '10.13km']}
# ==>Property link:  /for-sale/bryanston/sandton/gauteng/5176/110056169
# {'name': '2 Bedroom Apartment / Flat for Sale in Bryanston', 'price': 'R 1 575 000', 'province': 'gauteng', 'city': 'sandton', 'address': 'Bryanston, Sandton', 'Listing Number': '110056169', 'Type of Property': 'Apartment / Flat', 'Listing Date': '04 June 2021', 'Floor Size': '115 m²', 'Price per m²': 'R 13 696', 'Levies': 'R 3 050', 'Rates and Taxes': 'R 1 050', 'Bedrooms': '2', 'Bedroom 1': 'Bedroom 2', 'Bedroom 2': 'Bedroom 1', 'Bathrooms': '2', 'Bathroom 1': 'Bathroom 2', 'Bathroom 2': 'Bathroom 1', 'Kitchen': 'Kitchen', 'Loft': 'Loft', 'Lounge': 'Lounge', 'Family/TV Room': 'Family T V Room', 'Parking': '2', 'Parking 1': 'Parking 1', 'Parking 2': 'Parking 2', 'Pool': 'Pool', 'Security': 'Electric Gate, Security Gate, Intercom, Guard House, Guard, Perimeter Wall', 'Food and Entertainment': ['0.58km', '0.61km', '0.73km', '0.74km', '0.74km', '0.75km', '0.75km', '0.81km', '0.87km', '0.88km', '0.91km', '1.84km', '1.84km', '1.90km'], 'Education': ['0.62km', '1.15km', '1.17km', '1.18km', '1.23km', '1.66km', '1.71km', '1.76km', '1.86km'], 'Shopping': ['0.75km', '0.82km', '0.83km', '1.11km', '1.84km', '1.85km', '1.90km']}
# ==>Property link:  /for-sale/phuthaditjhaba/phuthaditjhaba/free-state/9999/109664867
# ====> Page expired !!
# ==>Property link:  /for-sale/payneville/springs/gauteng/1190/110162818
# {'name': '3 Bedroom House for Sale in Payneville', 'price': 'R 535 000', 'province': 'gauteng', 'city': 'springs', 'address': 'Payneville, Springs', 'Listing Number': '110162818', 'Type of Property': 'House', 'Listing Date': '05 July 2021', 'Erf Size': '270 m²', 'Pets Allowed': 'Yes', 'Bedrooms': '3', 'Bathrooms': '1.5', 'Kitchens': '1', 'Lounges': '1', 'Dining Rooms': '1', 'Garage': '1', 'Garden': 'Yes', 'Food and Entertainment': ['1.06km'], 'Education': ['1.15km', '1.23km', '1.24km', '1.24km', '1.42km', '1.43km', '1.48km', '1.87km', '1.97km', '2.10km', '2.31km', '2.49km', '2.71km', '2.99km', '3.28km', '3.38km', '3.65km', '4.14km', '4.45km', '4.95km', '5.44km'], 'Transport and Public Services': ['1.25km', '2.39km', '2.92km', '4.47km', '4.53km', '4.57km', '4.67km'], 'Sports and Leisure': ['3.88km']}
# ==>Property link:  /for-sale/delarey/roodepoort/gauteng/668/109961249
# {'name': '5 Bedroom House for Sale in Delarey', 'price': 'R 1 200 000', 'province': 'gauteng', 'city': 'roodepoort', 'address': 'Delarey, Roodepoort', 'Listing Number': '109961249', 'Type of Property': 'House', 'Listing Date': '11 May 2021', 'Erf Size': '991 m²', 'Rates and Taxes': 'R 3 500', 'Pets Allowed': 'Yes', 'Bedrooms': '5', 'Bedroom 1': 'Main Bedroom with loose cupboards', 'Bedroom 2': 'Build in cupboards', 'Bedroom 3': 'Build in cupboards', 'Bedroom 4': 'Flat-let', 'Bedroom 5': 'Flat-let', 'Bathrooms': '2', 'Bathroom 1': 'Tiled Floors, Shower, Bath, Toilet and Basin', 'Bathroom 2': 'Flat-let', 'Kitchen': 'Stove (Oven & Hob), Fridge, Tumble Dryer, Built-in Cupboards, Laminated Floors', 'Garage': 'Plus in front of garage x4 under cover parking', 'Parking': 'Extra open parking for 2 cars in front of house', 'Garden': 'Courtyard', 'Nearby Public Transport': 'Bus, Train, Minibus Taxi', 'Internet Access': 'Satellite', 'Education': ['0.41km', '0.62km', '0.97km', '1.06km', '1.15km', '1.45km', '1.64km', '1.93km', '1.97km', '2.03km', '2.07km', '2.07km', '2.16km', '2.21km', '2.22km', '2.28km', '2.39km', '2.43km', '2.46km'], 'Transport and Public Services': ['0.84km', '0.99km', '1.07km', '1.13km', '1.22km', '2.02km', '2.09km', '2.13km', '2.41km'], 'Food and Entertainment': ['1.81km'], 'Sports and Leisure': ['2.07km']}
# ==>Property link:  /for-sale/die-bult/potchefstroom/north-west/5049/108613958
# {'name': '1 Bedroom Apartment / Flat for Sale in Die Bult', 'price': 'R 620 000', 'province': 'north-west', 'city': 'potchefstroom', 'address': 'Die Bult, Potchefstroom', 'Listing Number': '108613958', 'Type of Property': 'Apartment / Flat', 'Description': 'First Floor', 'Listing Date': '04 April 2020', 'Floor Size': '38 m²', 'Price per m²': 'R 16 316', 'Levies': 'R 883', 'Rates and Taxes': 'R 166', 'Pets Allowed': 'No', 'Bedroom': 'Tiled Floors, Built-in Cupboards', 'Bathroom': 'Main en Suite, Shower, Toilet', 'Kitchen': 'Granite Tops, Tiled Floors, Open Plan', 'Office/study': 'Built in cupboards', 'Lounge': 'Tiled Floors, Open Plan', 'Parking': 'Carport, Single', 'Garden': 'Communal', 'Pool': 'Communal Pool', 'Outbuildings': '2', 'Outbuilding 1': 'Laundry in complex', 'Outbuilding 2': 'braai area', 'Security': 'Security Gate, 24 Hour Response, Electric fencing', 'Special Features': 'Paveway, Open Plan, Communal braai area, Special Doors', 'Roof': 'Iron', 'Wall': 'Brick, Plaster', 'Window': 'Cottage', 'Education': ['0.57km', '0.58km', '0.69km', '1.69km', '1.96km', '2.16km', '2.32km', '2.83km', '2.99km', '3.06km', '3.08km', '3.26km', '3.49km', '3.60km', '3.75km', '3.84km', '4.02km', '5.27km', '5.30km', '5.35km', '5.50km', '5.63km', '5.75km', '5.82km', '5.90km'], 'Transport and Public Services': ['0.62km', '1.58km', '2.57km', '2.64km'], 'Food and Entertainment': ['1.97km']}
# ==>Property link:  /for-sale/potchefstroom-central/potchefstroom/north-west/5025/105798277
# {'name': '2 Bedroom Townhouse for Sale in Potchefstroom Central', 'price': 'R 780 000', 'province': 'north-west', 'city': 'potchefstroom', 'address': 'Potchefstroom Central, Potchefstroom', 'Listing Number': '105798277', 'Type of Property': 'Townhouse', 'Listing Date': '13 November 2017', 'Erf Size': '80 m²', 'Floor Size': '80 m²', 'Levies': 'R 631', 'Rates and Taxes': 'R 320', 'Pets Allowed': 'Yes', 'Bedrooms': '2', 'Bedroom 1': 'Bedroom 2', 'Bedroom 2': 'Bedroom 1', 'Bathroom': 'Bathroom 1', 'Kitchen': 'Kitchen ', 'Lounge': 'Lounge ', 'Parking': '2', 'Parking 1': 'Carport', 'Parking 2': 'Parking', 'Security': 'Security Fence', 'Food and Entertainment': ['0.37km'], 'Education': ['0.52km', '0.59km', '0.64km', '0.79km', '1.03km', '1.06km', '1.28km', '1.34km', '1.57km', '1.57km', '1.61km', '1.64km', '1.71km', '1.90km', '2.23km', '2.68km', '2.79km', '3.89km', '4.08km', '4.22km', '4.29km', '4.35km', '4.38km', '4.59km', '4.67km'], 'Transport and Public Services': ['1.00km', '2.42km', '2.61km', '4.76km']}
# ==>Property link:  /for-sale/kempton-park-ext-4/kempton-park/gauteng/32938/110095713
# {'name': '2 Bedroom Apartment / Flat for Sale in Kempton Park Ext 4', 'price': 'R 860 000', 'province': 'gauteng', 'city': 'kempton-park', 'address': 'Kempton Park Ext 4, Kempton Park', 'Listing Number': '110095713', 'Type of Property': 'Apartment / Flat', 'Listing Date': '15 June 2021', 'Floor Size': '121 m²', 'Price per m²': 'R 7 107', 'Levies': 'R 1 150', 'Rates and Taxes': 'R 330', 'Bedrooms': '2', 'Bathrooms': '1.5', 'Garage': '1', 'Transport and Public Services': ['0.37km', '1.22km', '1.70km', '2.06km', '2.09km', '2.36km', '2.37km', '2.38km', '2.68km'], 'Education': ['0.60km', '0.87km', '0.95km', '1.13km', '1.22km', '1.22km', '1.49km', '1.79km', '1.81km', '1.84km', '1.93km', '1.95km', '2.04km', '2.11km', '2.29km', '2.36km', '2.47km', '2.72km'], 'Food and Entertainment': ['2.29km'], 'Shopping': ['2.30km'], 'Health': ['2.38km']}
# ==>Property link:  /for-sale/claremont/pretoria/gauteng/275/110229777
# {'name': '3 Bedroom House for Sale in Claremont', 'price': 'R 1 995 000', 'province': 'gauteng', 'city': 'pretoria', 'address': 'Claremont, Pretoria', 'Listing Number': '110229777', 'Type of Property': 'House', 'Listing Date': '24 July 2021', 'Erf Size': '1 276 m²', 'Floor Size': '315 m²', 'Rates and Taxes': 'R 418', 'Pets Allowed': 'Yes', 'Zoning': 'Single Residential', 'Bedrooms': '3', 'Bathrooms': '2', 'Kitchens': '1', 'Office': '1', 'Lounges': '1', 'Dining Rooms': '1', 'Garage': '1', 'Parking': '4', 'Garden': 'Yes', 'Pool': 'Yes', 'Flatlet': 'Yes', 'Education': ['0.19km', '0.46km', '0.59km', '0.72km', '1.17km', '1.23km', '1.25km', '1.63km', '2.02km', '2.69km', '2.93km', '3.22km', '3.23km', '3.59km', '3.61km', '3.62km'], 'Sports and Leisure': ['0.21km', '2.14km', '2.59km', '3.52km'], 'Transport and Public Services': ['1.67km', '3.07km', '3.09km', '3.36km', '3.64km', '3.72km', '3.74km', '3.76km'], 'Health': ['1.94km'], 'Shopping': ['3.76km']}
# ==>Property link:  /for-sale/bloemspruit/bloemfontein/free-state/9740/109830074
# {'name': '3 Bedroom House for Sale in Bloemspruit', 'price': 'R 1 400 000', 'province': 'free-state', 'city': 'bloemfontein', 'address': '\n3 Bedroom House for Sale in Bloemspruit\n', 'Listing Number': '109830074', 'Type of Property': 'House', 'Street Address': '23039 Pinehaven, Bloemspruit', 'Listing Date': '07 April 2021', 'Erf Size': '544 m²', 'Bedrooms': '3', 'Bathrooms': '2', 'Reception Rooms': '2', 'Transport and Public Services': ['0.83km', '1.22km', '3.98km'], 'Education': ['1.51km', '2.10km', '2.15km', '2.51km', '2.87km', '3.06km', '3.07km', '3.07km', '3.16km', '3.49km', '3.57km', '3.60km', '3.90km', '3.93km', '3.97km', '3.99km', '4.10km', '4.10km', '4.21km', '4.22km', '4.26km', '4.62km', '4.63km', '4.63km', '4.78km', '4.81km'], 'Sports and Leisure': ['3.76km']}
# ==>Property link:  /for-sale/waves-edge/blouberg/western-cape/11591/105939693
# {'name': '3 Bedroom Apartment / Flat for Sale in Waves Edge', 'price': 'R 13 700 000', 'province': 'western-cape', 'city': 'blouberg', 'address': 'Waves Edge, Blouberg', 'Listing Number': '105939693', 'Type of Property': 'Apartment / Flat', 'Listing Date': '17 January 2018', 'Floor Size': '454 m²', 'Price per m²': 'R 30 176', 'Levies': 'R 10 178', 'Rates and Taxes': 'R 8 130', 'Pets Allowed': 'No', 'Bedrooms': '3', 'Bathrooms': '3.5', 'Kitchens': '1', 'Lounges': '2', 'Dining Rooms': '1', 'Parking': '1', 'Pool': 'Yes', 'Transport and Public Services': ['0.52km', '0.81km', '0.81km', '0.87km', '0.89km', '0.94km', '0.98km', '1.03km', '1.40km', '1.54km', '1.60km', '2.17km', '2.18km', '2.19km'], 'Food and Entertainment': ['0.56km', '0.85km'], 'Shopping': ['0.71km', '0.74km', '0.89km'], 'Education': ['0.91km', '1.06km', '1.28km', '1.82km', '1.97km', '2.00km'], 'Health': ['0.98km', '1.78km', '2.31km', '2.32km'], 'Sports and Leisure': ['2.11km']}
# ==>Property link:  /for-sale/cape-town-city-centre/cape-town/western-cape/9138/109893950
# {'name': '1 Bedroom Apartment / Flat for Sale in Cape Town City Centre', 'price': 'R 2 350 000', 'province': 'western-cape', 'city': 'cape-town', 'address': 'Cape Town City Centre, Cape Town', 'Listing Number': '109893950', 'Type of Property': 'Apartment / Flat', 'Listing Date': '22 April 2021', 'Floor Size': '45 m²', 'Price per m²': 'R 52 222', 'Pets Allowed': 'No', 'Bedroom': '1', 'Bathrooms': '1', 'Lounges': '1', 'Dining Rooms': '1', 'Parking': '1', 'Pool': 'Yes', 'Transport and Public Services': ['0.10km', '0.18km', '0.32km', '0.32km', '0.34km', '0.45km', '0.46km'], 'Food and Entertainment': ['0.15km', '0.30km', '0.37km', '0.41km', '0.42km', '0.42km', '0.42km', '0.43km', '0.43km', '0.43km', '0.44km', '0.44km', '0.44km', '0.45km', '0.46km', '0.46km', '0.46km'], 'Health': ['0.37km', '0.40km'], 'Education': ['0.37km'], 'Shopping': ['0.41km', '0.45km', '0.47km']}
# ==>Property link:  /for-sale/langenhovenpark/bloemfontein/free-state/9735/110122855
# ====> Page not found !!
# ==>Property link:  /for-sale/witbank-central/witbank/mpumalanga/2460/106402117
# {'name': '1 Bedroom Apartment / Flat for Sale in Witbank Central', 'price': 'R 450 000', 'province': 'mpumalanga', 'city': 'witbank', 'address': 'Witbank Central, Witbank', 'Listing Number': '106402117', 'Type of Property': 'Apartment / Flat', 'Listing Date': '04 June 2018', 'Bedroom': '1', 'Bathrooms': '1', 'Education': ['0.17km', '0.35km', '0.38km', '0.84km', '1.06km', '1.34km', '1.53km', '1.73km', '1.82km', '1.89km', '1.94km', '1.97km', '2.07km', '2.25km', '2.33km', '2.41km', '2.51km', '2.73km', '2.79km', '2.98km', '3.05km', '3.72km', '3.97km', '4.06km', '4.19km', '4.23km', '4.28km', '4.48km', '4.56km'], 'Sports and Leisure': ['2.62km']}
# ==>Property link:  /for-sale/la-mercy/la-mercy/kwazulu-natal/7683/110063532
# {'name': '8 Bedroom House for Sale in La Mercy', 'price': 'R 4 700 000', 'province': 'kwazulu-natal', 'city': 'la-mercy', 'address': 'La Mercy', 'Listing Number': '110063532', 'Type of Property': 'House', 'Listing Date': '07 June 2021', 'Erf Size': '105 m²', 'Floor Size': '360 m²', 'Rates and Taxes': 'R 1 820', 'Pets Allowed': 'Yes', 'Bedrooms': '8', 'Bathrooms': '3', 'Kitchens': '1', 'Office': '1', 'Domestic Rooms': '1', 'Lounges': '2', 'Dining Rooms': '1', 'Garage': '6', 'Garden': 'Yes', 'Education': ['0.39km', '4.20km', '5.00km', '5.75km', '5.78km', '6.39km', '6.68km', '6.84km', '6.90km', '6.94km', '6.98km', '7.09km', '7.19km', '7.22km', '7.34km', '7.37km', '7.47km', '7.47km', '7.49km', '7.53km', '7.66km', '7.76km'], 'Food and Entertainment': ['2.87km'], 'Transport and Public Services': ['3.05km', '3.08km', '3.11km', '3.20km', '3.27km', '3.35km', '3.35km']}
# ==>Property link:  /for-sale/oakdene/johannesburg/gauteng/4323/107051840
# {'name': '3 Bedroom Townhouse for Sale in Oakdene', 'price': 'R 1 250 000', 'province': 'gauteng', 'city': 'johannesburg', 'address': '\n3 Bedroom Townhouse for Sale in Oakdene\n', 'Listing Number': '107051840', 'Type of Property': 'Townhouse', 'Street Address': '55 Oakdene Park Drive, Oakdene', 'Listing Date': '13 May 2021', 'Floor Size': '93 m²', 'Levies': 'R 1 300', 'Rates and Taxes': 'R 550', 'Bedrooms': '3', 'Bathrooms': '2', 'Reception Rooms': '1', 'Pool': 'Yes', 'Education': ['0.59km', '0.84km', '1.15km', '1.21km', '1.33km', '1.72km', '1.73km', '2.74km', '3.18km', '3.23km', '3.25km', '3.44km', '3.88km', '4.16km', '4.23km', '4.32km', '4.34km', '4.40km', '4.56km', '4.65km', '4.72km', '4.78km', '4.81km', '4.97km', '5.04km'], 'Transport and Public Services': ['2.56km', '2.97km', '3.00km'], 'Food and Entertainment': ['3.19km'], 'Sports and Leisure': ['4.52km']}
# ==>Property link:  /for-sale/oakdene/johannesburg/gauteng/4323/110144721
# {'name': '2 Bedroom Townhouse for Sale in Oakdene', 'price': 'R 1 195 000', 'province': 'gauteng', 'city': 'johannesburg', 'address': '\n2 Bedroom Townhouse for Sale in Oakdene\n', 'Listing Number': '110144721', 'Type of Property': 'Townhouse', 'Street Address': ' 9 Oakdene Gardens, 2 South Street, Oakdene', 'Description': 'Duplex', 'Lifestyle': 'Complex, Security Complex, Cul-de-sac', 'Listing Date': '29 June 2021', 'Erf Size': '22 590 m²', 'Floor Size': '137 m²', 'Levies': 'R 2 450', 'Rates and Taxes': 'R 600', 'Pets Allowed': 'Yes', 'Bedrooms': '2', 'Bedroom 1': 'Laminated Flooring, main en suite', 'Bedroom 2': 'Laminated Flooring,', 'Bathrooms': '2', 'Bathroom 1': 'Main en Suite, Bath, Double Basin, Toilet', 'Bathroom 2': 'Basin, Shower, Shower, Toilet and Basin, Toilet', 'Kitchen': ' ', 'Lounge': 'Leads to private garden', 'Dining Room': ' ', 'Entrance Hall': ' ', 'Garage': ' ', 'Parking': '1', 'Garden': 'Yes', 'Security': 'Security Gate, Burglar Bars, Electric fencing', 'Education': ['0.39km', '0.74km', '1.38km', '1.39km', '1.39km', '1.65km', '1.95km', '2.24km', '2.36km', '2.46km', '2.47km', '2.52km', '2.53km', '2.58km', '2.62km', '2.77km', '2.80km', '2.82km', '2.87km', '2.87km', '2.88km', '3.14km', '3.17km', '3.21km', '3.34km', '3.37km', '3.38km', '3.42km', '3.44km', '3.49km']}
# ==>Property link:  /for-sale/zululami-luxury-coastal-estate/ballito/kwazulu-natal/32686/110166533
# {'name': 'House for Sale in Zululami Luxury Coastal Estate', 'price': 'R 5 730 000', 'province': 'kwazulu-natal', 'city': 'ballito', 'address': 'Zululami Luxury Coastal Estate, Ballito', 'Listing Number': '110166533', 'Type of Property': 'House', 'Description': 'New Development', 'Lifestyle': 'Estate', 'Listing Date': '06 July 2021', 'Erf Size': '1 274 m²', 'Floor Size': '248 m²', 'Levies': 'R 1 700', 'No Transfer Duty': 'Yes', 'Pets Allowed': 'Yes', 'Coverage': '19 %', 'Internet Access': 'Fibre', 'Style': 'Modern', 'Standalone Building': 'Yes', 'Transport and Public Services': ['0.67km', '1.07km', '3.27km', '3.43km', '3.54km', '3.60km', '3.69km', '4.06km', '4.11km', '5.64km', '5.97km', '7.66km'], 'Education': ['2.62km', '3.07km', '3.90km', '4.07km', '4.39km', '5.16km', '5.38km', '5.78km', '6.69km', '7.21km', '7.49km', '7.81km'], 'Health': ['3.58km'], 'Sports and Leisure': ['5.11km', '7.22km', '7.30km', '7.58km'], 'Food and Entertainment': ['7.08km']}
# ==>Property link:  /for-sale/witbank-ext-8/witbank/mpumalanga/2585/109611350
# {'name': '5 Bedroom House for Sale in Witbank Ext 8', 'price': 'R 975 000', 'province': 'mpumalanga', 'city': 'witbank', 'address': 'Witbank Ext 8, Witbank', 'Listing Number': '109611350', 'Type of Property': 'House', 'Listing Date': '08 February 2021', 'Erf Size': '1 300 m²', 'Rates and Taxes': 'R 500', 'Bedrooms': '5', 'Bathrooms': '2', 'Dining Rooms': '1', 'Garage': '1', 'Parking': '1', 'Gardens': '1', 'Education': ['1.48km', '1.63km', '1.81km', '1.86km', '1.91km', '1.92km', '1.97km', '2.20km', '2.69km', '2.74km', '2.82km', '2.89km', '2.90km', '3.01km', '3.04km', '3.05km', '3.43km', '3.46km', '3.68km', '3.78km', '3.98km', '4.07km', '4.17km', '4.24km', '4.26km', '4.37km'], 'Sports and Leisure': ['2.53km'], 'Shopping': ['4.27km', '4.44km'], 'Food and Entertainment': ['4.34km']}
# ==>Property link:  /for-sale/vaalwater/vaalwater/limpopo/11472/108680907
# {'name': '2 Bedroom House for Sale in Vaalwater', 'price': 'R 1 572 000', 'province': 'limpopo', 'city': 'vaalwater', 'address': '\n2 Bedroom House for Sale in Vaalwater\n', 'Listing Number': '108680907', 'Type of Property': 'House', 'Street Address': '106 Melkrivier Road, Vaalwater', 'Listing Date': '23 May 2020', 'Erf Size': '20 000 m²', 'Floor Size': '100 m²', 'Levies': 'R 1 980', 'Rates and Taxes': 'R 250', 'Bedrooms': '2', 'Bathrooms': '2', 'Reception Rooms': '1', 'Garage': '1', 'Education': ['9.31km']}
# ==>Property link:  /for-sale/kidds-beach/east-london/eastern-cape/6674/110065321
# {'name': '3 Bedroom House for Sale in Kidds Beach', 'price': 'R 2 955 000', 'province': 'eastern-cape', 'city': 'east-london', 'address': '\n3 Bedroom House for Sale in Kidds Beach\n', 'Listing Number': '110065321', 'Type of Property': 'House', 'Street Address': ' 888 Village Avenue, The Village Estate, Kidds Beach', 'Listing Date': '07 June 2021', 'Erf Size': '275 m²', 'Bedrooms': '3', 'Bathrooms': '2', 'Kitchens': '1', 'Garage': '2', 'Parking': '1', 'Gardens': '1', 'Education': ['0.17km', '8.12km', '8.50km', '10.12km', '10.15km', '10.75km', '11.12km'], 'Transport and Public Services': ['1.26km']}
# ==>Property link:  /for-sale/phalaborwa/phalaborwa/limpopo/11266/107934271
# {'name': '2 Bedroom Apartment / Flat for Sale in Phalaborwa', 'price': 'R 480 000', 'province': 'limpopo', 'city': 'phalaborwa', 'address': 'Phalaborwa', 'Listing Number': '107934271', 'Type of Property': 'Apartment / Flat', 'Listing Date': '27 August 2020', 'Levies': 'R 1 150', 'Rates and Taxes': 'R 400', 'Pets Allowed': 'Yes', 'Bedrooms': '2', 'Bathrooms': '1', 'Parking': '1', 'Gardens': '1', 'Sports and Leisure': ['0.66km', '0.66km', '2.13km', '3.38km'], 'Food and Entertainment': ['0.68km', '0.82km'], 'Education': ['0.71km', '1.11km', '1.17km', '1.20km', '1.24km', '1.42km', '4.87km', '9.65km', '10.41km', '10.82km', '10.86km', '10.86km', '10.95km', '10.99km', '11.54km', '12.30km', '12.89km'], 'Transport and Public Services': ['1.06km', '1.20km', '1.34km', '1.37km', '4.94km', '6.70km'], 'Health': ['1.26km']}
# ==>Property link:  /for-sale/soshanguve-uu/soshanguve/gauteng/17882/109418830
# {'name': '3 Bedroom House for Sale in Soshanguve Uu', 'price': 'R 729 000', 'province': 'gauteng', 'city': 'soshanguve', 'address': '\n3 Bedroom House for Sale in Soshanguve Uu\n', 'Listing Number': '109418830', 'Type of Property': 'House', 'Street Address': ' 742 Masianoke Street, Soshanguve UU', 'Listing Date': '03 December 2020', 'Erf Size': '195 m²', 'Floor Size': '65 m²', 'No Transfer Duty': 'Yes', 'Rates and Taxes': 'R 200', 'Coverage': '33 %', 'Bedrooms': '3', 'Bathrooms': '1', 'Kitchens': '1', 'Lounges': '1', 'Education': ['0.44km', '0.47km', '0.61km', '0.66km', '1.08km', '1.27km', '1.57km', '1.59km', '2.13km', '2.36km', '2.60km', '2.84km', '2.92km', '3.06km', '3.12km', '3.36km', '3.36km', '3.38km', '3.40km', '3.43km', '3.46km', '3.52km', '3.68km', '3.69km', '3.72km', '3.76km', '3.78km', '3.83km'], 'Transport and Public Services': ['1.92km', '3.06km']}
# ==>Property link:  /for-sale/square-hill-park/kimberley/northern-cape/11084/108881784
# {'name': '3 Bedroom House for Sale in Square Hill Park', 'price': 'R 2 300 000', 'province': 'northern-cape', 'city': 'kimberley', 'address': 'Square Hill Park, Kimberley', 'Listing Number': '108881784', 'Type of Property': 'House', 'Listing Date': '17 July 2020', 'Erf Size': '1 049 m²', 'Rates and Taxes': 'R 900', 'Pets Allowed': 'Yes', 'Bedrooms': '3', 'Bedroom 1': 'Bedroom 3 with curtain rails, built-in cupboards and wooden floors', 'Bedroom 2': 'Bedroom 2 with curtain rails, built-in cupboards and wooden floors', 'Bedroom 3': 'Main bedroom with en-suite bathroom, curtain rails, built-in cupboards and wooden floors', 'Bathrooms': '2', 'Bathroom 1': 'Bathroom 1 with basin, bath, toilet and tiled floors', 'Bathroom 2': 'Bathroom 2 with basin, bath, shower, toilet and tiled floors', 'Kitchen': 'Kitchen with tiled floors, melamine finishes and oven and hob', 'Office/study': 'Study with curtain rails and wooden floors', 'Lounge': 'Formal lounge with curtain rails, wood fireplace and wooden floors', 'Dining Room': 'Dining room with curtain rails and wooden floors', 'Parking': '6', 'Garden': 'Garden with low maintenance', 'Special Featuress': '5', 'Special Features 1': 'Roof with zinc roof', 'Special Features 2': 'Plastered walls', 'Special Features 3': 'Steel windows', 'Special Features 4': 'Palisade fence boundary', 'Special Features 5': 'Exterior features including water tank', 'Flatlet': 'Yes', 'Transport and Public Services': ['0.23km', '0.88km', '1.06km', '1.28km', '1.38km', '1.44km', '1.56km', '1.85km', '2.18km'], 'Education': ['0.38km', '0.65km', '0.66km', '0.73km', '0.93km', '0.94km', '0.95km', '1.20km', '1.33km', '1.42km', '1.42km', '1.81km', '1.81km', '2.05km', '2.05km', '2.16km'], 'Food and Entertainment': ['1.26km', '1.48km', '1.50km', '1.76km', '1.77km']}
# ==>Property link:  /for-sale/craigavon/sandton/gauteng/3913/110026074
# {'name': '3 Bedroom Townhouse for Sale in Craigavon', 'price': 'R 2 650 000', 'province': 'gauteng', 'city': 'sandton', 'address': '\n3 Bedroom Townhouse for Sale in Craigavon\n', 'Listing Number': '110026074', 'Type of Property': 'Townhouse', 'Street Address': '1 Campbell Road, Craigavon', 'Description': 'Cluster Home', 'Listing Date': '27 May 2021', 'Erf Size': '200 m²', 'Floor Size': '218 m²', 'Levies': 'R 2 800', 'No Transfer Duty': 'Yes', 'Rates and Taxes': 'R 1 200', 'Pets Allowed': 'Yes', 'Bedrooms': '3', 'Bathrooms': '2', 'Reception Rooms': '1', 'Lounge': '1 Lounge', 'Garage': '2', 'Garden': 'Yes', 'Food and Entertainment': ['0.45km', '0.50km', '0.66km', '0.78km', '0.82km', '1.13km', '1.17km', '1.18km', '1.19km', '1.19km', '1.22km', '1.24km'], 'Transport and Public Services': ['0.48km', '0.86km', '0.89km', '1.11km', '1.22km', '1.26km'], 'Education': ['0.50km', '1.21km'], 'Shopping': ['0.53km', '1.20km', '1.21km', '1.21km', '1.24km'], 'Health': ['0.76km', '0.90km', '0.96km', '1.18km'], 'Sports and Leisure': ['0.81km']}
# ==>Property link:  /for-sale/dalview/brakpan/gauteng/2271/109462436
# {'name': '4 Bedroom House for Sale in Dalview', 'price': 'R 1 399 000', 'province': 'gauteng', 'city': 'brakpan', 'address': 'Dalview, Brakpan', 'Listing Number': '109462436', 'Type of Property': 'House', 'Listing Date': '21 December 2020', 'Erf Size': '967 m²', 'Rates and Taxes': 'R 700', 'Pets Allowed': 'Yes', 'Bedrooms': '4', 'Bathrooms': '3.5', 'Kitchens': '1', 'Domestic Rooms': '1', 'Lounges': '1', 'Dining Rooms': '1', 'Parking': '1', 'Garden': 'Yes', 'Flatlet': 'Yes', 'Education': ['0.38km', '1.14km', '1.25km', '1.70km', '1.70km', '1.73km', '2.12km', '2.37km', '2.42km', '2.75km', '2.81km', '2.85km', '3.11km', '3.16km', '3.34km', '3.51km', '3.97km', '4.17km', '4.24km', '4.51km', '5.13km'], 'Transport and Public Services': ['1.83km', '2.36km', '3.25km', '3.81km', '4.39km', '4.53km', '5.34km'], 'Sports and Leisure': ['3.09km', '4.16km']}
# ==>Property link:  /for-sale/cashan/rustenburg/north-west/3132/103486048
# {'name': '3 Bedroom Townhouse for Sale in Cashan', 'price': 'R 1 200 000', 'province': 'north-west', 'city': 'rustenburg', 'address': 'Cashan, Rustenburg', 'Listing Number': '103486048', 'Type of Property': 'Townhouse', 'Listing Date': '01 August 2018', 'Floor Size': '112 m²', 'Levies': 'R 650', 'Rates and Taxes': 'R 753', 'Pets Allowed': 'Yes', 'Bedrooms': '3', 'Bedroom 1': 'En-suite', 'Bedroom 2': 'Carpets, Built-in Cupboards, Double Bed', 'Bedroom 3': 'Carpets, Built-in Cupboards, Single Bed', 'Bathrooms': '2', 'Kitchens': '1', 'Lounges': '1', 'Other': 'Patio', 'Garage': '1', 'Parking': '1', 'Garden': 'Small and neat', 'Security': 'Electric Gate, Alarm System, Burglar Bars, Electric fencing', 'Special Features': 'Built in Braai', 'Food and Entertainment': ['1.18km', '1.72km', '1.72km', '1.74km', '4.14km', '4.54km', '4.58km', '5.04km', '5.16km'], 'Transport and Public Services': ['1.22km', '2.32km', '4.63km', '4.69km'], 'Education': ['1.58km', '2.74km', '3.16km', '3.19km', '3.30km', '3.85km', '3.86km', '4.25km', '4.27km', '4.30km', '4.62km', '5.13km', '5.45km', '5.58km', '5.60km'], 'Sports and Leisure': ['5.12km', '5.50km']}
# ==>Property link:  /for-sale/raslouw/centurion/gauteng/383/108566529
# {'name': '2 Bedroom Apartment / Flat for Sale in Raslouw', 'price': 'R 1 065 019', 'province': 'gauteng', 'city': 'centurion', 'address': '\n2 Bedroom Apartment / Flat for Sale in Raslouw\n', 'Listing Number': '108566529', 'Type of Property': 'Apartment / Flat', 'Street Address': '25 Philirene Road, Raslouw', 'Listing Date': '13 March 2020', 'Floor Size': '86 m²', 'Price per m²': 'R 12 384', 'Levies': 'R 800', 'Special Levy': 'R 1 700', 'No Transfer Duty': 'Yes', 'Rates and Taxes': 'R 600', 'Pets Allowed': 'No', 'Bedrooms': '2', 'Bathrooms': '2', 'Kitchen': 'Open Plan, Extractor Fan, Under Counter Oven', 'Parking': '2', 'Security': 'Perimeter Wall', 'Style': 'Contemporary, Modern', 'Roof': 'Tile, Concrete, Insulation', 'Wall': 'Plaster', 'Window': 'Aluminium', 'Floor': 'Tiled Floors, Laminated Floors', 'Education': ['1.33km', '1.37km', '1.82km', '2.62km', '2.65km', '3.09km', '3.25km'], 'Food and Entertainment': ['1.55km', '1.56km', '1.62km', '1.64km', '1.65km', '2.45km', '2.47km', '2.64km'], 'Shopping': ['1.59km'], 'Health': ['1.63km', '2.45km'], 'Transport and Public Services': ['1.76km', '2.13km', '2.60km', '2.61km', '2.65km', '2.71km', '2.75km', '2.79km', '2.97km', '2.99km', '3.18km', '3.24km']}
# ==>Property link:  /for-sale/kwaggasrand/pretoria/gauteng/2921/109922198
# {'name': '3 Bedroom House for Sale in Kwaggasrand', 'price': 'R 1 340 000', 'province': 'gauteng', 'city': 'pretoria', 'address': 'Kwaggasrand, Pretoria', 'Listing Number': '109922198', 'Type of Property': 'House', 'Listing Date': '01 May 2021', 'Pets Allowed': 'No', 'Bedrooms': '3', 'Bedroom 1': ' ', 'Bedroom 2': ' ', 'Bedroom 3': ' ', 'Bathrooms': '1', 'Kitchen': ' ', 'Lounge': ' ', 'Dining Room': ' ', 'Garage': '2', 'Garage 1': ' ', 'Garage 2': ' ', 'Education': ['0.24km', '0.76km', '1.95km', '2.04km', '2.49km', '2.68km', '2.73km', '2.76km', '2.91km', '2.92km', '2.93km', '2.93km', '2.96km', '3.10km', '3.14km', '3.23km', '3.23km', '3.28km', '3.42km', '3.43km'], 'Transport and Public Services': ['1.90km', '1.95km', '2.71km', '2.93km'], 'Sports and Leisure': ['2.65km', '2.88km', '3.02km', '3.38km'], 'Food and Entertainment': ['3.31km', '3.40km']}
# ==>Property link:  /for-sale/windsor-east/randburg/gauteng/4522/110067324
# {'name': '2 Bedroom Townhouse for Sale in Windsor East', 'price': 'R 490 000', 'province': 'gauteng', 'city': 'randburg', 'address': 'Windsor East, Randburg', 'Listing Number': '110067324', 'Type of Property': 'Townhouse', 'Listing Date': '08 June 2021', 'Erf Size': '1 985 m²', 'Floor Size': '114 m²', 'Age': '35', 'Bedrooms': '2', 'Bedroom 1': 'Bedroom 2 with built-in cupboards and tiled floors', 'Bedroom 2': 'Main bedroom with built-in cupboards and tiled floors', 'Bathrooms': '1.5', 'Bathroom 1': 'Bathroom 2 with basin, toilet and tiled floors', 'Bathroom 2': 'Bathroom 1 with basin, bath, toilet and tiled floors', 'Kitchen': 'Kitchen with tiled floors, wood finishes and stove', 'Reception Rooms': '2', 'Dining Room': 'Dining room with tiled floors', 'Parking': '1', 'Garden': 'Garden', 'Security': 'Security including security gates', 'Special Featuress': '2', 'Special Features 1': 'Tiled roof', 'Special Features 2': 'Palisade fence boundary', 'Food and Entertainment': ['0.12km', '0.71km', '0.99km', '1.01km', '1.01km', '1.01km', '1.03km', '1.04km', '1.05km', '1.05km', '1.06km', '1.06km', '1.06km', '1.07km', '1.07km', '1.07km', '1.07km', '1.09km', '1.10km', '1.10km'], 'Shopping': ['0.15km', '0.16km', '1.10km', '1.10km'], 'Transport and Public Services': ['0.16km', '1.09km'], 'Education': ['0.77km', '0.89km'], 'Sports and Leisure': ['1.05km'], 'Health': ['1.07km']}
# ==>Property link:  /for-sale/theunissen/theunissen/free-state/9750/109801227
# {'name': '4 Bedroom House for Sale in Theunissen', 'price': 'R 820 000', 'province': 'free-state', 'city': 'theunissen', 'address': 'Theunissen', 'Listing Number': '109801227', 'Type of Property': 'House', 'Listing Date': '29 March 2021', 'Erf Size': '1 402 m²', 'Pets Allowed': 'Yes', 'Bedrooms': '4', 'Bedroom 1': 'Carpets, Curtain Rails', 'Bedroom 2': 'Carpets, Curtain Rails, Fan', 'Bedroom 3': 'Carpets, Curtain Rails, Fan, Built-in Cupboards', 'Bedroom 4': 'Tiled Floors, Curtain Rails, Fan, Built-in Cupboards', 'Bathrooms': '2.5', 'Bathroom 1': 'Tiled Floors, Main en Suite, Shower, Bath, Toilet and Basin', 'Bathroom 2': 'Tiled Floors, Bath, Toilet and Basin', 'Bathroom 3': 'Tiled Floors, Guest Toilet', 'Kitchen': 'Eye Level Oven, Tiled Floors, Built-in Cupboards', 'Office/study': 'Tiled Floors, Curtain Rails', 'Domestic Rooms': '1', 'Lounges': '2', 'Lounge 1': 'Tiled Floors, Curtain Rails', 'Lounge 2': 'Tiled Floors, Curtain Rails', 'Dining Room': 'Tiled Floors, Air Conditioner, Curtain Rails, Open Plan', 'Family/TV Room': 'Tiled Floors, Curtain Rails', 'Garage': '2', 'Parking': 'Carport, Secure Parking, Single, Triple', 'Garden': 'Borehole, Irrigation system, Immaculate Condition', 'Outbuildings': '2', 'Outbuilding 1': 'Staff Quarters/Domestic Rooms, Outside Toilets', 'Outbuilding 2': 'with built-in-braai', 'Outside Toilets': '1', 'Security': 'Alarm System', 'Special Features': 'Special light is spotlight outside', 'Standalone Building': 'Yes', 'Education': ['0.40km', '0.89km', '0.89km', '1.17km', '1.39km', '2.55km', '2.81km', '9.32km', '11.35km'], 'Transport and Public Services': ['1.90km', '9.17km']}
# ==>Property link:  /for-sale/huttenheights/newcastle/kwazulu-natal/5426/108549716
# {'name': '3 Bedroom Townhouse for Sale in Huttenheights', 'price': 'R 1 260 000', 'province': 'kwazulu-natal', 'city': 'newcastle', 'address': 'Huttenheights, Newcastle', 'Listing Number': '108549716', 'Type of Property': 'Townhouse', 'Listing Date': '10 March 2020', 'Floor Size': '70 m²', 'Pets Allowed': 'No', 'Furnished': 'Optional', 'Bedrooms': '3', 'Bathrooms': '2', 'Office': '1', 'Garage': '1', 'Garden': 'Yes', 'Security': 'Electric Garage, Electric Gate, Perimeter Wall', 'Style': 'Conventional, Contemporary', 'Roof': 'Tile', 'Wall': 'Face-brick', 'Floor': 'Tiled Floors', 'Education': ['0.33km', '0.99km', '1.84km', '2.12km', '2.15km', '2.30km', '2.49km', '2.63km', '2.80km', '2.91km', '2.92km', '3.08km', '3.37km', '3.40km', '3.58km', '3.79km', '4.21km', '4.34km', '4.39km', '4.87km', '7.04km', '7.85km', '7.97km', '8.55km', '8.88km'], 'Food and Entertainment': ['1.18km', '1.27km', '6.74km'], 'Transport and Public Services': ['6.03km', '6.20km']}
# ==>Property link:  /for-sale/warner-beach/kingsburgh/kwazulu-natal/6291/109790757
# {'name': '2 Bedroom Apartment / Flat for Sale in Warner Beach', 'price': 'R 740 000', 'province': 'kwazulu-natal', 'city': 'kingsburgh', 'address': 'Warner Beach, Kingsburgh', 'Listing Number': '109790757', 'Type of Property': 'Apartment / Flat', 'Listing Date': '25 March 2021', 'Floor Size': '69 m²', 'Price per m²': 'R 10 725', 'Levies': 'R 1 200', 'Rates and Taxes': 'R 800', 'Bedrooms': '2', 'Bathrooms': '1', 'Garage': '1', 'Education': ['0.07km', '1.15km', '2.16km', '2.63km', '3.78km', '3.80km', '3.84km', '4.01km', '4.33km', '4.35km', '4.41km', '4.46km', '4.57km', '4.63km', '4.84km', '5.14km', '5.30km', '5.44km', '5.45km', '5.59km', '5.81km', '5.89km'], 'Transport and Public Services': ['0.65km', '1.52km', '1.96km', '3.75km', '3.77km', '4.92km', '5.63km'], 'Food and Entertainment': ['1.39km']}
# ==>Property link:  /for-sale/chroompark/mokopane/limpopo/11473/108584339
# {'name': '3 Bedroom Townhouse for Sale in Chroompark', 'price': 'R 1 320 000', 'province': 'limpopo', 'city': 'mokopane', 'address': 'Chroompark, Mokopane', 'Listing Number': '108584339', 'Type of Property': 'Townhouse', 'Listing Date': '18 March 2020', 'Erf Size': '128 m²', 'Bedrooms': '3', 'Bedroom 1': 'Bedroom 3', 'Bedroom 2': 'Bedroom 2', 'Bedroom 3': 'Bedroom 1', 'Bathrooms': '2', 'Bathroom 1': 'Bathroom 1', 'Bathroom 2': 'Bathroom 2', 'Kitchen': 'Kitchen', 'Lounge': 'Lounge', 'Dining Room': 'Dining Room', 'Garage': 'Garage', 'Parking': 'Parking', 'Secure Parking': '1', 'Garden': 'Garden', 'Pool': 'Pool', 'Security': 'Electric Gate, Alarm System', 'Special Features': 'Special Features', 'Special Feature': 'Driveway', 'Education': ['0.95km', '1.41km', '1.63km', '1.66km', '1.88km', '2.15km', '2.59km', '2.71km', '2.79km', '2.88km', '3.12km', '3.33km', '3.74km', '3.87km', '4.97km', '5.10km', '5.76km', '6.16km', '6.19km', '6.22km', '6.28km', '6.45km', '6.47km', '6.55km', '6.92km', '7.19km', '7.21km', '7.26km'], 'Transport and Public Services': ['2.31km', '5.23km']}
# ==>Property link:  /for-sale/visagie-park/nigel/gauteng/2077/105946944
# {'name': '4 Bedroom House for Sale in Visagie Park', 'price': 'R 1 600 000', 'province': 'gauteng', 'city': 'nigel', 'address': 'Visagie Park, Nigel', 'Listing Number': '105946944', 'Type of Property': 'House', 'Listing Date': '19 January 2018', 'Erf Size': '574 m²', 'Rates and Taxes': 'R 600', 'Bedrooms': '4', 'Bathrooms': '3', 'Bathroom 1': 'En suite', 'Bathroom 2': 'En suite', 'Kitchens': '1', 'Office/studies': '1', 'Lounges': '1', 'Dining Rooms': '1', 'Family/TV Rooms': '1', 'Other': 'Patio', 'Garage': '2', 'Gardens': '1', 'Security': 'Totally Fenced, Electric Gate, Alarm System', 'Special Features': 'Paveway', 'Roof': 'Tile', 'Wall': 'Plaster', 'Window': 'Steel ', 'Education': ['1.06km', '1.06km', '1.22km', '1.49km', '1.73km', '1.82km', '2.08km', '2.09km', '2.80km', '9.10km', '9.51km', '9.79km', '10.25km', '10.26km', '10.38km', '10.39km', '10.62km', '10.80km', '10.91km', '11.07km', '11.15km', '11.24km', '11.34km', '11.35km'], 'Transport and Public Services': ['4.41km', '6.95km', '7.16km', '9.43km', '9.92km', '10.65km']}
# ==>Property link:  /for-sale/cotswold-downs-golf-and-country-estate/hillcrest/kwazulu-natal/15672/110223296
# {'name': '3 Bedroom House for Sale in Cotswold Downs Golf & Country Estate', 'price': 'R 5 200 000', 'province': 'kwazulu-natal', 'city': 'hillcrest', 'address': '\n3 Bedroom House for Sale in Cotswold Downs Golf & Country Estate\n', 'Listing Number': '110223296', 'Type of Property': 'House', 'Street Address': '93 Inanda Road, Cotswold Downs Estate, Cotswold Downs Golf & Country Estate', 'Listing Date': '22 July 2021', 'Erf Size': '1 050 m²', 'Floor Size': '305 m²', 'Levies': 'R 2 038', 'Rates and Taxes': 'R 3 500', 'Pets Allowed': 'Yes', 'Zoning': 'Single Residential', 'Bedrooms': '3', 'Bathrooms': '3', 'Kitchens': '1', 'Lounges': '2', 'Dining Rooms': '1', 'Garage': '2', 'Garden': 'Yes', 'Pool': 'Yes', 'Education': ['1.52km', '2.17km', '2.18km', '2.21km', '2.78km', '2.84km', '2.93km', '3.15km', '3.44km', '3.70km', '3.71km', '4.15km', '4.18km', '4.30km', '4.55km', '4.57km', '4.82km', '5.12km', '5.26km', '5.31km', '5.32km'], 'Transport and Public Services': ['2.61km', '4.06km', '4.24km', '4.25km', '5.06km', '5.17km'], 'Shopping': ['4.23km', '5.35km'], 'Food and Entertainment': ['5.37km']}
# ==>Property link:  /for-sale/clearwater-estate/boksburg/gauteng/15114/110228235
# {'name': '3 Bedroom Townhouse for Sale in Clearwater Estate', 'price': 'R 1 550 000', 'province': 'gauteng', 'city': 'boksburg', 'address': 'Clearwater Estate, Boksburg', 'Listing Number': '110228235', 'Type of Property': 'Townhouse', 'Listing Date': '23 July 2021', 'Erf Size': '402 m²', 'Floor Size': '155 m²', 'Levies': 'R 890', 'Rates and Taxes': 'R 1 447', 'Pets Allowed': 'Yes', 'Bedrooms': '3', 'Bathrooms': '3', 'Kitchens': '1', 'Lounges': '1', 'Dining Rooms': '1', 'Garage': '2', 'Garden': 'Yes', 'Security': 'Electric Garage', 'Education': ['0.71km', '1.59km', '1.80km', '1.93km', '2.66km', '2.75km', '2.82km', '3.04km', '3.21km', '3.26km', '3.83km'], 'Health': ['1.20km', '2.34km', '3.25km', '3.31km', '3.42km'], 'Food and Entertainment': ['1.25km', '2.41km', '2.41km', '2.96km', '3.29km', '3.48km', '3.59km', '3.98km'], 'Transport and Public Services': ['1.26km', '2.10km', '2.69km', '3.28km', '3.50km', '4.06km']}
# ==>Property link:  /for-sale/claremont/cape-town/western-cape/11741/110152658
# {'name': '1 Bedroom Apartment / Flat for Sale in Claremont', 'price': 'R 2 000 000', 'province': 'western-cape', 'city': 'cape-town', 'address': 'Claremont, Cape Town', 'Listing Number': '110152658', 'Type of Property': 'Apartment / Flat', 'Listing Date': '01 July 2021', 'Floor Size': '68 m²', 'Price per m²': 'R 29 412', 'Bedrooms': '1', 'Bathrooms': '1', 'Kitchens': '1', 'Lounges': '1', 'Parking': '1', 'Education': ['0.27km', '0.40km', '0.49km', '0.56km', '0.65km', '0.90km', '0.94km', '0.97km', '1.09km', '1.17km'], 'Transport and Public Services': ['0.28km', '0.36km', '0.79km', '0.82km', '0.86km', '0.89km', '0.94km', '0.97km', '1.00km', '1.02km', '1.14km'], 'Food and Entertainment': ['0.53km', '0.98km', '1.21km'], 'Health': ['0.80km', '0.97km', '1.14km'], 'Sports and Leisure': ['1.18km', '1.22km', '1.23km']}
# ==>Property link:  /for-sale/randpark-ridge/randburg/gauteng/4471/110085848
# ====> Page not found !!
# ==>Property link:  /for-sale/bulwer/durban/kwazulu-natal/5969/109949528
# {'name': '8 Bedroom House for Sale in Bulwer', 'price': 'R 3 000 000', 'province': 'kwazulu-natal', 'city': 'durban', 'address': 'Bulwer, Durban', 'Listing Number': '109949528', 'Type of Property': 'House', 'Description': 'Single Storey', 'Listing Date': '08 May 2021', 'Erf Size': '690 m²', 'Bedrooms': '8', 'Kitchens': '1', 'Domestic Rooms': '1', 'Rooms': 'Air Conditioner', 'Garage': '3', 'Security': 'Alarm System, Burglar Bars', 'Floor': 'Wooden Floors', 'Education': ['0.33km', '0.64km', '0.66km', '0.71km', '0.89km', '0.94km', '1.01km', '1.25km', '1.38km', '1.61km', '1.68km', '1.70km', '1.75km', '1.80km', '1.81km', '1.93km', '2.00km', '2.09km', '2.17km'], 'Shopping': ['0.57km', '0.59km'], 'Food and Entertainment': ['0.58km', '2.22km', '2.23km', '2.27km'], 'Health': ['0.79km', '1.20km'], 'Transport and Public Services': ['1.26km', '1.40km', '2.07km']}
# ==>Property link:  /for-sale/lambton/germiston/gauteng/1711/110126424
# ====> Page not found !!
# ==>Property link:  /for-sale/somerset-lakes/somerset-west/western-cape/15987/109848941
# {'name': '1 Bedroom Apartment / Flat for Sale in Somerset Lakes', 'price': 'R 699 999', 'province': 'western-cape', 'city': 'somerset-west', 'address': '\n1 Bedroom Apartment / Flat for Sale in Somerset Lakes\n', 'Listing Number': '109848941', 'Type of Property': 'Apartment / Flat', 'Street Address': ' Unit  A1, Somerlife Square, Somerset Lakes', 'Description': 'New Development', 'Lifestyle': 'Estate, Security Estate', 'Listing Date': '12 April 2021', 'Erf Size': '37 m²', 'Floor Size': '37 m²', 'Price per m²': 'R 18 919', 'Levies': 'R 725', 'No Transfer Duty': 'Yes', 'Rates and Taxes': 'R 400', 'Bedroom': 'Tiled Floors, Built-in Cupboards', 'Bathroom': 'Solar PV Geysers', 'Kitchen': 'Engineered stone kitchen tops', 'Lounge': 'Tiled Floors', 'Parking': 'allocated', 'Garden': 'Enclosed gardens on ground units, Communal kids play area', 'Security': '24 Hour Access, Guard, Electric fencing, Perimeter Wall, Boomed Area', 'Special Features': 'Accompanying Retail centre,', 'Nearby Public Transport': 'Bus, Minibus Taxi', 'Internet Access': 'Fibre', 'Style': 'Modern', 'Education': ['0.86km', '0.97km', '1.05km', '1.10km', '1.13km', '1.25km', '1.39km', '1.41km', '1.84km', '2.01km', '2.28km', '2.44km', '2.77km', '2.86km', '2.94km', '3.09km', '3.19km', '3.29km', '3.38km', '3.44km', '3.49km', '3.49km', '3.51km'], 'Transport and Public Services': ['2.38km', '2.57km', '3.50km', '3.55km'], 'Health': ['2.60km', '3.50km'], 'Sports and Leisure': ['3.48km']}
# ==>Property link:  /for-sale/burgundy-estate/milnerton/western-cape/12107/109931017
# {'name': '2 Bedroom Apartment / Flat for Sale in Burgundy Estate', 'price': 'R 1 365 000', 'province': 'western-cape', 'city': 'milnerton', 'address': 'Burgundy Estate, Milnerton', 'Listing Number': '109931017', 'Type of Property': 'Apartment / Flat', 'Listing Date': '04 May 2021', 'Floor Size': '75 m²', 'Price per m²': 'R 18 200', 'Levies': 'R 1 938', 'Rates and Taxes': 'R 495', 'Pets Allowed': 'Yes', 'Zoning': 'General Residential', 'Bedrooms': '2', 'Bathrooms': '2', 'Kitchens': '1', 'Lounges': '1', 'Dining Rooms': '1', 'Rooms': 'Balcony', 'Parking': '2', 'Garden': 'Yes', 'Pool': 'Yes', 'Education': ['0.60km', '1.76km', '1.76km', '2.41km', '2.46km', '2.71km', '2.80km', '3.26km', '3.32km', '3.34km'], 'Transport and Public Services': ['0.66km', '1.56km', '1.59km', '2.07km', '2.08km', '2.22km', '2.88km', '3.15km', '3.21km', '3.32km'], 'Food and Entertainment': ['0.67km', '1.54km', '2.10km', '2.56km', '3.32km', '3.32km', '3.32km', '3.33km'], 'Shopping': ['3.32km', '3.32km']}
# ==>Property link:  /for-sale/arcon-park/vereeniging/gauteng/3688/110038097
# ...
# ==>Property link:  /for-sale/sagewood/midrand/gauteng/11595/109886557
# {'name': '2 Bedroom Apartment / Flat for Sale in Sagewood', 'price': 'R 829 000', 'province': 'gauteng', 'city': 'midrand', 'address': '\n2 Bedroom Apartment / Flat for Sale in Sagewood\n', 'Listing Number': '109886557', 'Type of Property': 'Apartment / Flat', 'Street Address': '9 Beethoven Lane, Sagewood', 'Listing Date': '20 April 2021', 'Floor Size': '80 m²', 'Price per m²': 'R 10 363', 'Levies': 'R 1 620', 'Rates and Taxes': 'R 478', 'Bedrooms': '2', 'Bathrooms': '1', 'Kitchen': '1', 'Lounge': '1', 'Garage': '1', 'Parking': '1', 'Garden': '1', 'Pool': '1', 'Security': 'Security Gate, 24 Hour Access, Electric fencing', 'Special Feature': 'Balcony', 'Sports and Leisure': ['0.37km', '3.62km'], 'Education': ['0.92km', '1.16km', '1.72km', '1.93km', '2.10km', '2.80km', '2.84km', '2.89km', '3.24km', '3.56km', '3.67km', '3.68km', '3.77km', '3.96km', '4.24km', '4.25km', '4.33km'], 'Transport and Public Services': ['1.23km', '2.15km', '2.30km', '2.78km', '4.19km', '4.25km', '4.35km'], 'Health': ['2.34km'], 'Food and Entertainment': ['2.81km', '3.68km'], 'Shopping': ['3.43km']}
# ==>Property link:  /for-sale/meyersdal/alberton/gauteng/12770/107663456
# {'name': '2 Bedroom Townhouse for Sale in Meyersdal', 'price': 'R 920 000', 'province': 'gauteng', 'city': 'alberton', 'address': 'Meyersdal, Alberton', 'Listing Number': '107663456', 'Type of Property': 'Townhouse', 'Listing Date': '03 July 2019', 'Levies': 'R 1 160', 'Rates and Taxes': 'R 510', 'Bedrooms': '2', 'Bathrooms': '1', 'Kitchens': '1', 'Garage': '1', 'Garden': 'Yes', 'Education': ['1.17km', '1.92km', '2.19km', '2.24km', '2.45km', '2.50km', '2.51km', '2.73km', '2.80km', '2.84km', '3.08km', '3.14km', '3.34km', '3.48km', '3.56km', '3.58km', '3.66km', '3.88km', '3.95km', '3.95km', '4.00km', '4.09km', '4.16km', '4.19km', '4.30km', '4.33km'], 'Transport and Public Services': ['1.62km', '1.62km', '4.35km'], 'Shopping': ['2.69km']}
# ==>Property link:  /for-sale/comet/boksburg/gauteng/1925/109941185
# {'name': '2 Bedroom Apartment / Flat for Sale in Comet', 'price': 'R 470 000', 'province': 'gauteng', 'city': 'boksburg', 'address': 'Comet, Boksburg', 'Listing Number': '109941185', 'Type of Property': 'Apartment / Flat', 'Listing Date': '06 May 2021', 'Erf Size': '50 m²', 'Floor Size': '50 m²', 'Price per m²': 'R 9 400', 'Rates and Taxes': 'R 240', 'Pets Allowed': 'No', 'Bedrooms': '2', 'Bathrooms': '1', 'Kitchens': '1', 'Lounges': '1', 'Parking': '1', 'Garden': 'Yes', 'Education': ['0.86km', '0.95km', '1.00km', '1.09km', '1.87km', '2.05km', '2.11km', '2.11km', '2.14km', '2.28km', '2.43km', '2.48km', '2.60km', '2.85km', '2.92km', '3.13km', '3.14km', '3.16km', '3.17km', '3.22km', '3.25km', '3.51km', '4.12km', '4.17km', '4.26km'], 'Transport and Public Services': ['1.35km', '1.62km', '2.22km', '2.92km', '4.25km']}
# ==>Property link:  /for-sale/caneside/phoenix/kwazulu-natal/11787/110176999
# {'name': '3 Bedroom House for Sale in Caneside', 'price': 'R 1 090 000', 'province': 'kwazulu-natal', 'city': 'phoenix', 'address': 'Caneside, Phoenix', 'Listing Number': '110176999', 'Type of Property': 'House', 'Listing Date': '08 July 2021', 'Erf Size': '368 m²', 'Rates and Taxes': 'R 450', 'Bedrooms': '3', 'Bathrooms': '1', 'Kitchens': '1', 'Lounges': '1', 'Education': ['0.27km', '0.42km', '0.53km', '0.56km', '0.59km', '0.81km', '0.81km', '0.90km', '0.93km', '1.02km', '1.04km', '1.19km', '1.32km', '1.33km', '1.41km', '1.42km', '1.44km', '1.45km', '1.45km', '1.46km', '1.61km', '1.71km', '1.73km', '1.75km', '1.75km', '1.80km', '1.82km', '1.83km', '1.89km', '1.91km']}
# ==>Property link:  /for-sale/lonehill/sandton/gauteng/5247/110197949
# {'name': '3 Bedroom Apartment / Flat for Sale in Lonehill', 'price': 'R 1 350 000', 'province': 'gauteng', 'city': 'sandton', 'address': 'Lonehill, Sandton', 'Listing Number': '110197949', 'Type of Property': 'Apartment / Flat', 'Listing Date': '14 July 2021', 'Floor Size': '93 m²', 'Price per m²': 'R 14 516', 'Levies': 'R 2 152', 'Rates and Taxes': 'R 1 022', 'Bedrooms': '3', 'Bathrooms': '2', 'Reception Rooms': '1', 'Lounge': '1 Lounge', 'Pool': 'Yes', 'Education': ['0.61km', '0.86km', '1.36km', '1.66km', '2.01km', '2.12km'], 'Food and Entertainment': ['1.14km', '1.41km', '1.44km', '1.47km', '1.51km', '1.53km', '1.54km', '1.56km', '1.64km', '1.68km', '2.06km', '2.11km', '2.21km'], 'Sports and Leisure': ['1.19km', '1.98km', '2.00km', '2.06km'], 'Transport and Public Services': ['1.40km', '1.58km', '2.16km'], 'Health': ['1.53km', '1.70km', '2.12km'], 'Shopping': ['1.63km']}
# ==>Property link:  /for-sale/bryanston/sandton/gauteng/5176/110162147
# {'name': '4 Bedroom House for Sale in Bryanston', 'price': 'R 10 000 000', 'province': 'gauteng', 'city': 'sandton', 'address': 'Bryanston, Sandton', 'Listing Number': '110162147', 'Type of Property': 'House', 'Listing Date': '05 July 2021', 'Erf Size': '3 012 m²', 'Floor Size': '600 m²', 'Rates and Taxes': 'R 3 251', 'Coverage': '19 %', 'Bedrooms': '4', 'Bathrooms': '4', 'Kitchens': '1', 'Office/studies': '1', 'Domestic Rooms': '1', 'Lounges': '1', 'Dining Rooms': '1', 'Family/TV Rooms': '1', 'Entrance Halls': '1', 'Garage': '3', 'Pools': '1', 'Outbuilding': 'Staff Quarters/Domestic Rooms', 'Security': '1', 'Food and Entertainment': ['0.58km', '0.61km', '0.73km', '0.74km', '0.74km', '0.75km', '0.75km', '0.81km', '0.87km', '0.88km', '0.91km', '1.84km', '1.84km', '1.90km'], 'Education': ['0.62km', '1.15km', '1.17km', '1.18km', '1.23km', '1.66km', '1.71km', '1.76km', '1.86km'], 'Shopping': ['0.75km', '0.82km', '0.83km', '1.11km', '1.84km', '1.85km', '1.90km']}
# ==>Property link:  /for-sale/brits-rural/brits/north-west/25369/108883958
# {'name': '3 Bedroom Townhouse for Sale in Brits Rural', 'price': 'R 850 000', 'province': 'north-west', 'city': 'brits', 'address': 'Brits Rural, Brits', 'Listing Number': '108883958', 'Type of Property': 'Townhouse', 'Listing Date': '17 July 2020', 'Erf Size': '375 m²', 'Floor Size': '142 m²', 'Bedrooms': '3', 'Bathrooms': '2', 'Reception Rooms': '1', 'Garage': '1', 'Transport and Public Services': ['4.11km'], 'Education': ['9.16km', '9.50km']}
# ==>Property link:  /for-sale/northshore/hout-bay/western-cape/10126/109182997
# {'name': '3 Bedroom House for Sale in Northshore', 'price': 'R 4 100 000', 'province': 'western-cape', 'city': 'hout-bay', 'address': 'Northshore, Hout Bay', 'Listing Number': '109182997', 'Type of Property': 'House', 'Listing Date': '02 October 2020', 'Erf Size': '172 m²', 'Floor Size': '150 m²', 'Levies': 'R 600', 'Rates and Taxes': 'R 1 800', 'Pets Allowed': 'No', 'Bedrooms': '3', 'Bathrooms': '2', 'Kitchens': '1', 'Lounges': '1', 'Dining Rooms': '1', 'Garage': '2', 'Food and Entertainment': ['0.38km', '0.45km', '0.46km', '0.47km', '0.53km', '0.56km', '0.58km', '0.75km', '0.84km', '1.02km', '1.06km', '1.11km', '1.12km'], 'Health': ['0.40km', '0.44km', '0.95km'], 'Transport and Public Services': ['0.46km', '0.94km', '1.01km', '1.05km', '1.12km', '1.14km', '1.17km', '1.19km', '1.20km', '1.20km', '1.21km', '1.21km'], 'Education': ['0.67km', '1.03km']}
# ==>Property link:  /for-sale/greenstone-hill/edenvale/gauteng/11700/109994232
# ====> Page not found !!
# ==>Property link:  /for-sale/sasolburg-central/sasolburg/free-state/25189/110179036
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     664             # Make the request on the httplib connection object.
# --> 665             httplib_response = self._make_request(
#     666                 conn,
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                     # Otherwise it looks like a bug in the code.
# --> 421                     six.raise_from(e, None)
#     422         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# /usr/lib/python3/dist-packages/six.py in raise_from(value, from_value)
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     415                 try:
# --> 416                     httplib_response = conn.getresponse()
#     417                 except BaseException as e:
#
# /usr/lib/python3.8/http/client.py in getresponse(self)
#    1343             try:
# -> 1344                 response.begin()
#    1345             except ConnectionError:
#
# /usr/lib/python3.8/http/client.py in begin(self)
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#
# /usr/lib/python3.8/http/client.py in _read_status(self)
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#
# /usr/lib/python3.8/socket.py in readinto(self, b)
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     718
# --> 719             retries = retries.increment(
#     720                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# /usr/lib/python3/dist-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     399             if read is False or not self._is_method_retryable(method):
# --> 400                 raise six.reraise(type(error), error, _stacktrace)
#     401             elif read is not None:
#
# /usr/lib/python3/dist-packages/six.py in reraise(tp, value, tb)
#     701             if value.__traceback__ is not tb:
# --> 702                 raise value.with_traceback(tb)
#     703             raise value
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     664             # Make the request on the httplib connection object.
# --> 665             httplib_response = self._make_request(
#     666                 conn,
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                     # Otherwise it looks like a bug in the code.
# --> 421                     six.raise_from(e, None)
#     422         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# /usr/lib/python3/dist-packages/six.py in raise_from(value, from_value)
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     415                 try:
# --> 416                     httplib_response = conn.getresponse()
#     417                 except BaseException as e:
#
# /usr/lib/python3.8/http/client.py in getresponse(self)
#    1343             try:
# -> 1344                 response.begin()
#    1345             except ConnectionError:
#
# /usr/lib/python3.8/http/client.py in begin(self)
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#
# /usr/lib/python3.8/http/client.py in _read_status(self)
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#
# /usr/lib/python3.8/socket.py in readinto(self, b)
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#
# ProtocolError: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-9-205986050037> in <module>
#       3     dc.crawl_properties()
#       4 except:
# ----> 5     dc.crawl_properties()
#
# <ipython-input-8-d02316b46623> in crawl_properties(self)
#     184
#     185             print('==>Property link: ', prop_link)
# --> 186             check_property_crawl = self.get_property_data(prop_link)
#     187             if check_property_crawl:
#     188                 self.__urls= self.__urls.drop(self.__urls.index[i])
#
# <ipython-input-8-d02316b46623> in get_property_data(self, link)
#     135
#     136         #points_interest
# --> 137         interest_soup= crawl_page(self.__url_to_open+'/ListingReadOnly/PointsOfInterestForListing?ListingNumber=P24-'+estate_id)
#     138         # points_interest_panel=prop_soup.select_one('#accordian-points-of-interest')
#     139         # print(points_interest_panel)
#
# <ipython-input-1-b8a731ce11c6> in crawl_page(link)
#      28     #         raise
#      29     try:
# ---> 30         response = requests.get(
#      31             url='http://api.scraperapi.com', #scrapeapi
#      32             params={
#
# ~/.local/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/.local/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/.local/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~/.local/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~/.local/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     496
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#     500         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
